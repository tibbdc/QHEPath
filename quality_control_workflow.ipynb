# %%
import cobra
import re
import math
import json
import pandas as pd
from cobra import Model, Reaction, Metabolite
from cobra.io.dict import model_to_dict
from script.quality_control_function import *

# %%
# initial universal model from BiGG database
model = cobra.io.load_json_model('data/universal_model.json')

# %%
model
# Out:
# <Model bigg_universal at 0x7f7dadbc59e8>

# %% [markdown]
# # 1. Model preprocessing

# %% [markdown]
# ## 1.1 Adding charge and formula for metabolites

# %%
met_108_df = pd.read_excel('data/met.xlsx',index_col='id')

model_dic = model_to_dict(model, sort=False)  
for met in model.metabolites:
    for met_dic in model_dic['metabolites']:  
        if met_dic['id'] == met.id:
            met_dic['charge'] = met_108_df.loc[met.id]['charge']
            met_dic['formula'] = met_108_df.loc[met.id]['formula']  
model = cobra.io.dict.model_from_dict(model_dic)

# %% [markdown]
# ## 1.2 Determining the direction of reaction

# %%
# exchange reactions
for rxn in model.reactions:
    if not exchange_rxn(model,rxn.id):
        model.reactions.get_by_id(rxn.id).bounds = (0,1000)
model.reactions.get_by_id('EX_glc__D_e').bounds = (-10,1000) # glucose
medium_rxn = ['EX_co2_e','EX_o2_e','EX_h_e','EX_h2o_e','EX_nh4_e','EX_pi_e','EX_so4_e','EX_fe3_e', 'EX_mn2_e','EX_fe2_e','EX_zn2_e', 'EX_mg2_e', 'EX_ca2_e', 'EX_ni2_e', 'EX_cu2_e', 'EX_cobalt2_e', 'EX_sel_e','EX_mobd_e', 'EX_k_e', 'EX_na1_e','EX_cl_e', 'EX_tungs_e', 'EX_slnt_e']
for ri in medium_rxn:
    rxn = model.reactions.get_by_id(ri)
    rxn.bounds = (-1000,1000)

# %% [markdown]
# ###  1.2.1  directions in 108 GEMs

# %%
# Reaction directions were initially determined based on the maximum count among the three directions (forward, backward, and reversible) in the GEMs

rxn_109_bounds_df=pd.read_excel('data/bigg_108_models_rxn_bounds.xlsx',index_col='id')

# Except for exchange reactions, each reaction direction is determined based on the number of counts in 108 GEMs
no_direction_rxn=[] 
for r in model.reactions:
    direction_number=[]
    if not exchange_rxn(model,r.id):
        reversible=rxn_109_bounds_df.loc[r.id]['reversible']
        forword=rxn_109_bounds_df.loc[r.id]['forword direction']
        backword=rxn_109_bounds_df.loc[r.id]['reverse direction']
        direction_number.append(reversible)
        direction_number.append(forword)
        direction_number.append(backword)
        
        max_index=direction_number.index(max(direction_number))
        
        if max_index==1 and direction_number[1]==direction_number[2]:
            model.reactions.get_by_id(r.id).bounds=(-1000,1000)
        
        if max_index==0: # reversible
            model.reactions.get_by_id(r.id).bounds=(-1000,1000)
        
        if max_index==1:# forward
            model.reactions.get_by_id(r.id).bounds=(0,1000)
            
        if max_index==2:# backward
            model.reactions.get_by_id(r.id).bounds=(-1000,0)   
            
        if reversible==0 and forword==0 and backword==0:
            model.reactions.get_by_id(r.id).bounds=(-1000,1000)
            no_direction_rxn.append(r.id)

# %% [markdown]
# ### 1.2.2 thermodynamic

# %%
# the frequency of reaction directions
rxn_108_except_exchange_df=pd.read_excel('data/bigg_108_models_rxn_bounds_except_exchange_rxn.xlsx',index_col='id')
unrealiable_rxn = []
for ri in rxn_108_except_exchange_df.index:
    if rxn_108_except_exchange_df.loc[ri,'sum'] <= 10:
        unrealiable_rxn.append(ri)
    if rxn_108_except_exchange_df.loc[ri,'sum'] > 10 and rxn_108_except_exchange_df.loc[ri,'max_direction_frequency'] < 0.7:
        unrealiable_rxn.append(ri)  

# detaG 
detaG_correct = []
detaG_df = pd.read_excel('data/bigg_equilibrator3.0_select.xlsx',index_col = 'id')
for ri in detaG_df.index:
    if ri.startswith('icw-'):
        detaG_df.drop(ri,inplace=True)
for ri in detaG_df.index:
    if ri in unrealiable_rxn and not transport_rxn(model,ri):
        rxn = model.reactions.get_by_id(ri)
        g1 = str(detaG_df.loc[ri,'G1']).split(') ')[0].split('(')[1].split(' +')[0]
        g2 = str(detaG_df.loc[ri,'G2']).split(') ')[0].split('(')[1].split(' +')[0]
        if float(g1) < 0 and float(g2) < 0:
            if rxn.bounds!=(0,1000):
                rxn.bounds=(0,1000)
                detaG_correct.append(ri)
                
        if float(g1) > 0 and float(g2) > 0:
            if rxn.bounds!=(-1000,0):
                rxn.bounds=(-1000,0)
                detaG_correct.append(ri)

# %% [markdown]
# ### 1.2.3 heuristic rules

# %%
# for reactions containing oxygen, their directions were assumed to be that of the oxygen consumption
O2_rxn = o2_rule(model,detaG_correct)

# most reactions cannot proceed in the direction of CO2 fixation, except for naturally known carbon fixation reactions and reactions utilizing CO2 and high-energy substrates such as phosphoenolpyruvate (PEP) and ATP
co2_rule_rxn = co2_rule(model,detaG_correct)

# atp 规则
ATP_pi = atp_rule(model,detaG_correct)

# most reactions produced  NH3/NH4+, except when it reacted with ATP, 2-oxoglutarate, chorismate, 5-phospho-alpha-D-ribose-1-diphosphate, and UDP-N-acetyl-beta-L-fucosamine
nh4_rule_rxn = nh4_rule(model,detaG_correct,O2_rxn)

# the direction of reactions with different compartment is same

rxnc_direction = modify_direction_compartment(model)
# print(len(rxnc_direction))

# %%
# check_model
model_dic = model_to_dict(model, sort=False)
with open('results/check_model.json', 'w') as f:
    json.dump(model_dic,f)

# %% [markdown]
# # 2. Error elimination

# %% [markdown]
# ## 2.1  infinite generation of metabolites

# %%
# penalizing reactions
rxn_grate_df = pd.read_excel('data/rxn_grate.xlsx',index_col='id')
rxn_grate={}
for rxn in model.reactions:
    if rxn.id in list(rxn_grate_df.index):
        rxn_grate[rxn.id]=rxn_grate_df.loc[rxn.id,'grate']

# unbalance reaction
balance_rxn,chargenan_rxn,H_balance_rxn,H2O_balance_rxn,unbalance_rxn = check_rxn_balance_number(model)

model.reactions.get_by_id('EX_glc__D_e').bounds = (0,1000)

# %%
check_model = cobra.io.load_json_model('results/check_model.json')
outputfile = 'results/quality_control/met/'

# %%
# metabolites containing carbon
element_id = 'co2'
c_met = check_carbon_production(model,element_id,rxn_grate,check_model,outputfile,unbalance_rxn)
# Out:
# 4crsol_c 1000.0
# 1
# BIOMASS_SA_nuc_only: 3.11 amp_c + 2.2 cmp_c + 0.76 damp_c + 0.53 dcmp_c + 0.6 dgmp_c + 0.73 dtmp_c + 4.01 gmp_c + 2.39 ump_c --> h2o_c 5
# SULRSI: 3.0 h2o_c + 3.0 nadp_c + slnt_c --> 4.0 h_c + 3.0 nadph_c + sel_c 5
# BIOMASS_SA_only_AA: 6.6 ala__L_c + 3.88 arg__L_c + 4.48 asn__L_c + 4.48 asp__L_c + 0.79 cys__L_c + 8.72 gln__L_c + 8.72 glu__L_c + 3.51 gly_c + 1.45 his__L_c + 4.06 ile__L_c + 5.21 leu__L_c + 5.45 lys__L_c + 1.94 met__L_c + 3.33 phe__L_c + 2.12 pro__L_c + 2.6 ser__L_c + 2.54 thr__L_c + 1.27 trp__L_c + 2.3 tyr__L_c + 4.12 val__L_c --> h2o_c 5
# P5CDEG: e4hglu_c + nad_c --> 4hglusa_c + nadh_c 5
# 2
# SFRR: h_c + so3_c --> h2o_c + h2s_c 5
# FPRA: fdxrd_c + h_c + nadp_c --> fdxox_c + nadph_c 5
# SIRA2: 6.0 fdxox_c + 3.0 h2o_c + h2s_c --> 6.0 fdxrd_c + 8.0 h_c + so3_c 5
# GLGE: malt1p_c --> 2.0 14glucan_c + pi_c 5
# ACCOAS: aacoa_c + coa_c --> accoa_c 5
# 3
# CYTK2_2: atp_c + ctp_c + dcmp_c --> adp_c + cdp_c + dcdp_c 5
# PPS2: air_c + amet_c --> 2mahmp_c + co_c + dad_2_c + for_c + met__L_c 5
# FACT: 2obut_c + coa_c --> for_c + 2.0 ppcoa_c 5
# G3POACTF: 0.041 bhdodec_c + 0.015 decacp_c + 0.048 dodecacp_c + glyc3p_c + 0.017 hepacp_c + 0.016 hepeacp_c + 0.281 hexacp_c + 0.192 hexeacp_c + 0.008 octacp_c + 0.375 octeacp_c + 0.003 penacp_c + 0.003 tetacp_c --> 0.958 ACP_c + aglp_c 5
# AGLPACTF: aglp_c + 0.041 bhdodec_c + 0.015 decacp_c + 0.048 dodecacp_c + 0.017 hepacp_c + 0.016 hepeacp_c + 0.281 hexacp_c + 0.192 hexeacp_c + 0.008 octacp_c + 0.375 octeacp_c + 0.003 penacp_c + 0.003 tetacp_c --> 0.958 ACP_c + 0.958 pa160_c 5
# 4
# NAR_syn_2: fdxo_2_2_c + h2o_c + no2_c --> fdxrd_c + 2.0 h_c + no3_c 5
# DGUO: glc__D_c + q8h2_c --> dgo15lac_c + 4.0 h_c + q8_c 5
# 5
# THIH: trdrd_c --> 2.0 h_c + trdox_c 5
# SULR_syn_1: fdxo_2_2_c + h2o_c + h2s_c --> fdxrd_c + h_c + so3_c 5
# AHSERL3: acser_c + seln_c --> ac_c + scys__L_c 5
# SLGTH: gthrd_c + h_c + slnt_c --> dgslnt_c + gthox_c + h2o_c 5
# 6
# ARTCOAL3: Rtotal3_c + coa_c --> Rtotal3coa_c 5
# 7
# AAMYL: 14glucan_c --> malthx_c 4
# 8
# SUCptspp_1: pep_c --> pyr_c + suc6p_c 5
# GLYOX_2: h2o_c + lgt__S_c --> gthrd_c + h_c + lac__D_c + mthgxl_c 5
# GLGB: 14glucan_c --> glycogen_c 5
# NALN6_1: akg_c + nal2a6o_c --> glu__L_c + n6all26d_c 5
# 9
# CYOO_HP: 4.0 focytcc553_c + 5.98 h_c + o2_c --> 4.0 ficytcc553_c + 1.99 h2o_c + 2.0 h_e + 0.005 o2s_c 5
# epo_degradation: 26.0 h2o_c + peptide_c --> ala__L_c + cys__L_c + glu__L_c + 3.0 gly_c + his__L_c + 10.0 leu__L_c + met__L_c + 3.0 pro__L_c + 2.0 ser__L_c + 2.0 trp__L_c + 2.0 val__L_c 5
# GLYTRS_1: atp_c + gly_c + trnagly_c --> amp_c + glytrna_c + h_c + ppi_c 5
# GLUSfx: akg_c + 2.0 fdxrd_c + gln__L_c + 2.0 h_c --> 2.0 fdxox_c + 2.0 glu__L_c 5
# CYOOum: 7.6 h_c + o2_c + 4.0 pcrd_u --> 2.0 h2o_c + 3.6 h_u + 4.0 pcox_u 5
# GLTS_h: akg_h + 2.0 fdxrd_h + gln__L_h + 2.0 h_h --> 2.0 fdxox_h + 2.0 glu__L_h 5
# SO3R_h: 6.0 fdxrd_h + 7.0 h_h + so3_h --> 6.0 fdxox_h + 3.0 h2o_h + h2s_h 5
# MG1_c: g3m8masn_c + h2o_c --> g2m8masn_c + glc__D_c 5
# FNOR2_h: 2.0 fdxox_h + nadph_h --> 2.0 fdxrd_h + h_h + nadp_h 5
# AMYL2: adpglc_c --> 14glucan_c + adp_c + h_c 5
# ACCDH: btcoa_c + fad_c --> 3mb2coa_c + fadh2_c 5
# HPOXR: 2.0 h2o2_c --> 2.0 h2o_c + 2.0 o2_c 5
# PYAS: aspsa_c + pyr_c --> h2o_c + h_c + thdp_c 5
# THDPS_2: h2o_c + succoa_c + thdp_c --> coa_c + sl26da_c 5
# PS_asn__L_c: asn__L_c --> Asn_X_Ser_Thr_c + h2o_c 5
# CYOR3m: 2.0 ficytcc_c + h_c + mql7_c --> 2.0 focytcc_c + 3.0 h_e + mqn7_c 5
# NDH_1_1_um: 2.0 fdxrd_c + 5.0 h_c + pq_um --> 2.0 fdxox_c + 3.0 h_u + pqh2_um 5
# SDPDS_2: h2o_c + sl2a6o_c --> 26dap_LL_c + succ_c 5
# PEPTIDEsyn: 0.748399 alatrna_c + 0.130805 argtrna_c + 0.272689 asntrna_c + 0.374015 asptrna_c + 0.017197 cystrna_c + 0.200228 glntrna_c + 0.256058 glutrna_c + 1.498961 glytrna_c + 0.067143 histrna_c + 0.087361 iletrna_c + 0.206491 leutrna_c + 0.311404 lystrna_c + 0.104726 mettrna_c + 0.13874 phetrna_c + 0.256971 protrna_c + 0.317225 sertrna_c + 0.349831 thrtrna_c + 0.087887 trptrna_c + 0.040246 tyrtrna_c + 0.284577 valtrna_c --> peptide_c + 0.748399 trnaala_c + 0.130805 trnaarg_c + 0.272689 trnaasn_c + 0.374015 trnaasp_c + 0.017197 trnacys_c + 0.200228 trnagln_c + 0.256058 trnaglu_c + 1.498961 trnagly_c + 0.067143 trnahis_c + 0.087361 trnaile_c + 0.206491 trnaleu_c + 0.311404 trnalys_c + 0.104726 trnamet_c + 0.13874 trnaphe_c + 0.256971 trnapro_c + 0.317225 trnaser_c + 0.349831 trnathr_c + 0.087887 trnatrp_c + 0.040246 trnatyr_c + 0.284577 trnaval_c 5
# 10
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# RTOT4: R4coa_hs_c --> Rtotalcoa_c 5
# SPMDAT1_2: accoa_c + sprm_c --> N1aspmd_c + coa_c 5
# GLYFEM: glyclt_c + h_c --> ac_c + co2_c + h2o_c + succ_c 5
# ARTFR46: fadh2_m + od2coa_c --> 1.125 R4coa_hs_c + fad_m 5
# PTGFS: prostgh2_c + trdox_c --> prostgf2_c + trdrd_c 5
# 11
# AHMMPS: air_c + 2.0 h_c --> 4ahmmp_c + gcald_c + pi_c 5
# ARTFR52: hexccoa_c --> 1.625 R5coa_hs_c 5
# ARTPLM1m: Rtotalcoa_m --> pmtcoa_m 5
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# RTOT3: R3coa_hs_c --> Rtotalcoa_c 5
# RTOT_3: R1coa_hs_c + R2coa_hs_c --> 2.0 Rtotal3coa_c 5
# CY_focytb5_c: ficytb5_c --> focytb5_c 5
# RE3477C: h2o_r + txa2_r --> CE1447_c + 2.0 h_c 5
# ABAH: 2ommbl_c + amet_c --> ahcys_c + h_c + q8_c 5
# MECDPDH4E: 2mecdp_c + fdxrd_c + h_c --> fdxo_2_2_c + h2mb4p_c + h2o_c 5
# AH5L: 5aop_c --> h2o_c + pbng_c 5
# FRDO3r: adfdRD_c + 2.0 nad_c --> adfdOX_c + 2.0 nadh_c 5
# GLA: nad_c + udpgalur_c --> 2.0 h_c + nadh_c + udpglcur_c 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTFR11: pmtcoa_c --> R1coa_hs_c 5
# ARTFR205: dlnlcgcoa_c + 2.0 fadh2_m + h_m + nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + nadp_m 5
# ARTFR31: stcoa_c --> 1.125 R3coa_hs_c 5
# ARTPLM3: Rtotal3coa_c --> pmtcoa_c 5
# RTOT2: R2coa_hs_c --> Rtotalcoa_c 5
# RTOT5: R5coa_hs_c --> Rtotalcoa_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# LCAT23e: chsterol_e + pchol_hs_e --> lpchol_hs_e + xolest183_hs_e 5
# FDR: nadph_c + rdxo_c --> h_c + nadp_c + rdxr_c 5
# MRF: fdxrd_c + 3.0 h_c + mlthf_c --> 5mthf_c + fdxo_2_2_c 5
# FNRR2: fdxrd_c + h_c + nadp_c --> fdxo_2_2_c + nadph_c 5
# PGAL: h2o_c + pbng_c --> hmbil_c + nh4_c 5
# 12
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTFR45: fadh2_m + nrvnccoa_c --> 1.5 R4coa_hs_c + fad_m 5
# RTOT_2: R2coa_hs_c + R4coa_hs_c --> 2.0 Rtotal2coa_c 5
# GBEZY: 14glun_c --> glycogen_c 5
# ARTFR207: arachcoa_c --> 1.25 R2coa_hs_c 5
# ARTPLM2m: Rtotal2coa_m --> pmtcoa_m 5
# FAD_9: coa_c + dodcoa_c + fad_c + nad_c --> accoa_c + decoa_c + fadh2_c + nadh_c 5
# FAD_10: coa_c + decoa_c + fad_c + nad_c --> accoa_c + fadh2_c + nadh_c + occoa_c 5
# BGLK_1: cellb_c + h2o_c --> g6p_c + glc__D_c 5
# SRK: 3php_c + atp_c --> adp_c + h_c + pser__L_c 5
# ASPA1: Lcyst_c + akg_c --> ac_c + glu__L_c 5
# DAPAL_1: 23dappa_c + h2o_c --> nh4_c + pyr_c 5
# 13
# NDH_1_4_um: co2_c + 2.0 fdxrd_c + h2o_c + 4.0 h_c + pq_um --> 2.0 fdxox_c + 3.0 h_u + hco3_c + pqh2_um 5
# r0698: dcholcoa_x + 4.0 h_x + ppcoa_x --> coa_x + dhcholestancoa_x + h2o_x 5
# NP1_2: nicrns_c + pi_c --> h_c + ncam_c + r1p_c 5
# DKMD3M: 12d3k5m_c + o2_c --> 3mtp_c + co_c + for_c 5
# HMR_9726: 5fthf_c + glu__L_c --> forglu_c + thf_c 5
# P5CCD: glu__L_c + h_c + nadh_c --> glu5sa_c + nad_c + pi_c 5
# DM1PE_2: 5mdru1p_c --> 2h3k5m_c 5
# CPS_1: atp_c + h_c + hco3_c + nh4_c --> adp_c + cbp_c + pi_c 5
# SULRR: h_c + nadh_c + so3_c --> h2o_c + h2s_c + nad_c 5
# 14
# PPS5: air_c + amet_c --> 2mahmp_c + co_c + dad_5_c + for_c + met__L_c 5
# KGD2: co2_c + 2.0 fdxrd_c + h_c + succoa_c --> akg_c + coa_c + 2.0 fdxox_c 5
# 15
# THMPP: h2o_c + thmmp_c --> ppi_c + thm_c 5
# THPPP: h2o_c + thmpp_c --> ppi_c + thmmp_c 5
# 16
# FRDO: fdxrd_c + nadp_c --> fdxox_c + h_c + nadph_c 4
# HYDA: 2.0 fdxrd_c --> 2.0 fdxox_c + h2_c + 2.0 h_c 4
# BTSr: dtbt_c + s_c --> btn_c + 2.0 h_c 4
# GULNLR: guln__L_c + 2.0 nad_c --> fruur_c + 2.0 nadh_c 4
# 17
# BTS2: cys__L_c + dtbt_c --> ala__L_c + btn_c + 2.0 h_c 4
# UNK2: 2kmb_c + gln__L_c + h_c --> glu__L_c + met__L_c 4
# 18
# ACOAD23f: fad_c + hdcoa_c --> fadh2_c + hd2coa_c 5
# 19
# HMR_2611: M00129_c + crn_c + 2.0 h_c --> coa_c + ttdcrn_c 5
# 20
# HDECH: 1hdecg3p_c + h2o_c --> glyc3p_c + 3.0 h_c + hdcea_c 5
# PLCC: pc160_c --> 12dgr160_c + cholp_c 5
# PLCE: pe160_c --> 12dgr160_c + ethamp_c 5
# 21
# OGMG: 4izp_c + 3.0 h2o_c + h_c + 2.0 nad_c --> 4ogm_c + for_c + 2.0 nadh_c + nh4_c 5
# 22
# UNK2_cho: 2kmb_c + gln__L_c + 2.0 h_c --> glu__L_c + met__L_c 4
# 23
# GLCS1: adpglc_c --> adp_c + glycogen_c + h_c 3
# 24
# GLCS2: udpg_c --> glycogen_c + h_c + udp_c 4
# 25
# GBEZ: 14glun_c --> glycogen_c + h2o_c 5
# BIOMASS_SA_nuc_only 1
# BIOMASS_SA_nuc_only: 3.11 amp_c + 2.2 cmp_c + 0.76 damp_c + 0.53 dcmp_c + 0.6 dgmp_c + 0.73 dtmp_c + 4.01 gmp_c + 2.39 ump_c --> h2o_c unbalance {'charge': 28.66, 'C': -138.18, 'H': -168.29999999999998, 'N': -56.83, 'O': -110.27000000000001, 'P': -14.33}
# SULRSI 2
# BIOMASS_SA_only_AA 3
# BIOMASS_SA_only_AA: 6.6 ala__L_c + 3.88 arg__L_c + 4.48 asn__L_c + 4.48 asp__L_c + 0.79 cys__L_c + 8.72 gln__L_c + 8.72 glu__L_c + 3.51 gly_c + 1.45 his__L_c + 4.06 ile__L_c + 5.21 leu__L_c + 5.45 lys__L_c + 1.94 met__L_c + 3.33 phe__L_c + 2.12 pro__L_c + 2.6 ser__L_c + 2.54 thr__L_c + 1.27 trp__L_c + 2.3 tyr__L_c + 4.12 val__L_c --> h2o_c unbalance {'charge': 3.87, 'C': -396.03000000000003, 'H': -764.4400000000002, 'N': -112.03000000000002, 'O': -201.18, 'S': -2.73}
# P5CDEG 4
# SFRR 5
# FPRA 6
# SIRA2 7
# GLGE 8
# ACCOAS 9
# ACCOAS: aacoa_c + coa_c --> accoa_c unbalance {'charge': 4.0, 'C': -23.0, 'H': -34.0, 'N': -7.0, 'O': -17.0, 'P': -3.0, 'S': -1.0}
# CYTK2_2 10
# PPS2 11
# FACT 12
# FACT: 2obut_c + coa_c --> for_c + 2.0 ppcoa_c unbalance {'charge': -4.0, 'C': 24.0, 'H': 36.0, 'O': 17.0, 'N': 7.0, 'P': 3.0, 'S': 1.0}
# G3POACTF 13
# AGLPACTF 14
# AGLPACTF: aglp_c + 0.041 bhdodec_c + 0.015 decacp_c + 0.048 dodecacp_c + 0.017 hepacp_c + 0.016 hepeacp_c + 0.281 hexacp_c + 0.192 hexeacp_c + 0.008 octacp_c + 0.375 octeacp_c + 0.003 penacp_c + 0.003 tetacp_c --> 0.958 ACP_c + 0.958 pa160_c unbalance {'charge': nan, 'C': 15.177000000000003, 'H': 33.349999999999994, 'N': 0.029999999999999707, 'O': -2.2270000000000003, 'P': -0.027000000000000128, 'R': 0.014999999999999854, 'S': 0.014999999999999854, 'X': -0.015}
# NAR_syn_2 15
# DGUO 16
# THIH 17
# SULR_syn_1 18
# AHSERL3 19
# SLGTH 20
# SLGTH: gthrd_c + h_c + slnt_c --> dgslnt_c + gthox_c + h2o_c unbalance {'charge': -2.0, 'C': 30.0, 'H': 45.0, 'N': 9.0, 'O': 16.0, 'S': 3.0}
# ARTCOAL3 21
# AAMYL 22
# AAMYL: 14glucan_c --> malthx_c unbalance {'C': 30.0, 'H': 51.0, 'O': 26.0, 'R': -1.0}
# SUCptspp_1 23
# SUCptspp_1: pep_c --> pyr_c + suc6p_c unbalance {'C': 12.0, 'H': 22.0, 'O': 11.0}
# GLYOX_2 24
# GLYOX_2: h2o_c + lgt__S_c --> gthrd_c + h_c + lac__D_c + mthgxl_c unbalance {'C': 3.0, 'H': 4.0, 'O': 2.0}
# GLGB 25
# GLGB: 14glucan_c --> glycogen_c unbalance {'C': 6.0, 'H': 10.0, 'O': 5.0}
# NALN6_1 26
# CYOO_HP 27
# epo_degradation 28
# GLYTRS_1 29
# GLUSfx 30
# CYOOum 31
# GLTS_h 32
# SO3R_h 33
# MG1_c 34
# FNOR2_h 35
# AMYL2 36
# ACCDH 37
# ACCDH: btcoa_c + fad_c --> 3mb2coa_c + fadh2_c unbalance {'C': 1.0, 'H': 2.0}
# HPOXR 38
# PYAS 39
# THDPS_2 40
# PS_asn__L_c 41
# PS_asn__L_c: asn__L_c --> Asn_X_Ser_Thr_c + h2o_c unbalance {'X': 1.0}
# CYOR3m 42
# NDH_1_1_um 43
# SDPDS_2 44
# PEPTIDEsyn 45
# PEPTIDEsyn: 0.748399 alatrna_c + 0.130805 argtrna_c + 0.272689 asntrna_c + 0.374015 asptrna_c + 0.017197 cystrna_c + 0.200228 glntrna_c + 0.256058 glutrna_c + 1.498961 glytrna_c + 0.067143 histrna_c + 0.087361 iletrna_c + 0.206491 leutrna_c + 0.311404 lystrna_c + 0.104726 mettrna_c + 0.13874 phetrna_c + 0.256971 protrna_c + 0.317225 sertrna_c + 0.349831 thrtrna_c + 0.087887 trptrna_c + 0.040246 tyrtrna_c + 0.284577 valtrna_c --> peptide_c + 0.748399 trnaala_c + 0.130805 trnaarg_c + 0.272689 trnaasn_c + 0.374015 trnaasp_c + 0.017197 trnacys_c + 0.200228 trnagln_c + 0.256058 trnaglu_c + 1.498961 trnagly_c + 0.067143 trnahis_c + 0.087361 trnaile_c + 0.206491 trnaleu_c + 0.311404 trnalys_c + 0.104726 trnamet_c + 0.13874 trnaphe_c + 0.256971 trnapro_c + 0.317225 trnaser_c + 0.349831 trnathr_c + 0.087887 trnatrp_c + 0.040246 trnatyr_c + 0.284577 trnaval_c unbalance {'charge': -5.56309, 'C': 14.13093, 'H': 18.38021699999999, 'N': 0.8501369999999999, 'O': 10.081791, 'R': -0.27268900000000096, 'P': -0.272689, 'S': -0.121923}
# ARTPLM1 46
# RTOT4 47
# RTOT4: R4coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# SPMDAT1_2 48
# SPMDAT1_2: accoa_c + sprm_c --> N1aspmd_c + coa_c unbalance {'charge': -2.0, 'C': -3.0, 'H': -9.0, 'N': -1.0}
# GLYFEM 49
# GLYFEM: glyclt_c + h_c --> ac_c + co2_c + h2o_c + succ_c unbalance {'charge': -3.0, 'C': 5.0, 'H': 5.0, 'O': 6.0}
# ARTFR46 50
# PTGFS 51
# AHMMPS 52
# ARTFR52 53
# ARTPLM1m 54
# ARTPLM2 55
# RTOT3 56
# RTOT3: R3coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# RTOT_3 57
# RTOT_3: R1coa_hs_c + R2coa_hs_c --> 2.0 Rtotal3coa_c unbalance {'X': -2.0, 'R': 6.0}
# CY_focytb5_c 58
# RE3477C 59
# ABAH 60
# MECDPDH4E 61
# AH5L 62
# FRDO3r 63
# GLA 64
# ARTCOAL1 65
# ARTFR11 66
# ARTFR205 67
# ARTFR31 68
# ARTPLM3 69
# RTOT2 70
# RTOT2: R2coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# RTOT5 71
# RTOT5: R5coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# FNOR_1 72
# LCAT23e 73
# LCAT23e: chsterol_e + pchol_hs_e --> lpchol_hs_e + xolest183_hs_e unbalance {'C': 17.0, 'H': 29.0, 'R': -2.0}
# FDR 74
# MRF 75
# FNRR2 76
# PGAL 77
# PGAL: h2o_c + pbng_c --> hmbil_c + nh4_c unbalance {'charge': -7.0, 'H': 26.0, 'O': 12.0, 'C': 30.0, 'N': 3.0}
# ARTCOAL2 78
# ARTFR45 79
# RTOT_2 80
# RTOT_2: R2coa_hs_c + R4coa_hs_c --> 2.0 Rtotal2coa_c unbalance {'X': -2.0, 'R': 4.0}
# GBEZY 81
# GBEZY: 14glun_c --> glycogen_c unbalance {'C': 6.0, 'H': 11.0, 'O': 5.0, 'R': 1.0}
# ARTFR207 82
# ARTPLM2m 83
# FAD_9 84
# FAD_10 85
# BGLK_1 86
# SRK 87
# ASPA1 88
# ASPA1: Lcyst_c + akg_c --> ac_c + glu__L_c unbalance {'charge': 1.0, 'C': -1.0, 'H': 1.0, 'O': -4.0, 'S': -1.0}
# DAPAL_1 89
# NDH_1_4_um 90
# r0698 91
# NP1_2 92
# DKMD3M 93
# HMR_9726 94
# P5CCD 95
# DM1PE_2 96
# CPS_1 97
# SULRR 98
# PPS5 99
# KGD2 100
# THMPP 101
# THPPP 102
# FRDO 103
# HYDA 104
# BTSr 105
# GULNLR 106
# BTS2 107
# UNK2 108
# ACOAD23f 109
# HMR_2611 110
# HDECH 111
# PLCC 112
# PLCE 113
# OGMG 114
# UNK2_cho 115
# GLCS1 116
# GLCS1: adpglc_c --> adp_c + glycogen_c + h_c unbalance {'C': 6.0, 'H': 11.0, 'O': 5.0, 'R': 1.0}
# GLCS2 117
# GLCS2: udpg_c --> glycogen_c + h_c + udp_c unbalance {'C': 6.0, 'H': 11.0, 'O': 5.0, 'R': 1.0}
# GBEZ 118
# GBEZ: 14glun_c --> glycogen_c + h2o_c unbalance {'C': 6.0, 'H': 13.0, 'O': 6.0, 'R': 1.0}
# aacald_c -5.684341886080801e-13
# amob_c -0.0
# 10fthf_c 0.0
# 2ohph_c 9.663381206337363e-13
# ala__L_c -0.0
# amet_c -0.0
# arg__L_c -0.0
# asn__L_c -1.1368683772161603e-12
# asp__L_c -1.1226575225009583e-12
# atp_c -1.9895196601282805e-13
# bmocogdp_c -0.0
# btn_c -0.0
# coa_c -0.0
# ctp_c -0.0
# cys__L_c -0.0
# datp_c -0.0
# dctp_c -0.0
# dgtp_c -0.0
# dttp_c -5.115907697472721e-13
# fad_c -0.0
# gln__L_c -0.0
# glu__L_c -1.1368683772161603e-13
# gly_c 2.8421709430404007e-12
# gtp_c 0.0
# his__L_c 3.489311403917292e-12
# ile__L_c -1.6203840437455942e-12
# leu__L_c -0.0
# lys__L_c -0.0
# met__L_c -0.0
# mlthf_c 0.0
# nad_c -5.684341886080801e-13
# nadp_c 0.0
# pe160_c -0.0
# pe161_c -0.0
# phe__L_c -1.2505552149377763e-12
# pheme_c -0.0
# pro__L_c -0.0
# pydx5p_c -0.0
# ribflv_c -0.0
# ser__L_c 1.7053025658242404e-12
# sheme_c -0.0
# thf_c 0.0
# thmpp_c -0.0
# thr__L_c -0.0
# trp__L_c -0.0
# tyr__L_c 0.0
# udcpdp_c 2.3921605437256705e-13
# utp_c 1.7053025658242404e-13
# val__L_c 1.7053025658242404e-13
# kdo2lipid4_e -0.0
# murein5px4p_p -0.0
# pe160_p 1.833546864473624e-13
# pe161_p -0.0
# adp_c 0.0
# 12ppd__S_e -0.0
# 15dap_e -0.0
# 23dappa_e -0.0
# 26dap__M_e -0.0
# 34dhpac_e 1.9895196601282803e-13
# 3amp_e -0.0
# 3gmp_e -0.0
# 3hcinnm_e -0.0
# 3hpp_e -0.0
# 3ump_e -0.0
# 5dglcn_e -0.0
# LalaDglu_e -0.0
# LalaDgluMdap_e -0.0
# acgal_e -0.0
# acgal1p_e 0.0
# acgam_e -0.0
# acmana_e -0.0
# ade_e -1.8568850161197284e-12
# adn_e -0.0
# agm_e -0.0
# ala_B_e -2.0463630789890885e-12
# alaala_e 7.958078640513122e-13
# all__D_e -0.0
# amp_e 1.1368683772161603e-13
# anhgm_e -2.8421709430404e-13
# arab__L_e -0.0
# arbt_e -0.0
# arbtn_e -0.0
# arbtn_fe3_e -0.0
# ascb__L_e -0.0
# asn__L_e -0.0
# asp__L_e -0.0
# btn_e -0.0
# chtbs_e -0.0
# cmp_e -0.0
# co2_e -0.0
# colipa_e -0.0
# cpgn_e 0.0
# cpgn_un_e -0.0
# crn__D_e -0.0
# cyan_e -0.0
# cys__D_e -0.0
# cys__L_e -0.0
# cytd_e 3.410605131648481e-13
# dad_2_e -0.0
# damp_e 0.0
# ddca_e 5.613287612504791e-13
# dgsn_e -0.0
# dha_e 1.7053025658242404e-13
# din_e -0.0
# dmso_e -0.0
# doxrbcn_e 0.0
# dump_e -0.0
# enlipa_e -0.0
# enter_e -0.0
# ethso3_e -0.0
# fald_e -0.0
# fe3dcit_e -0.0
# fe3hox_e 0.0
# fecrm_e 0.0
# fecrm_un_e -0.0
# feenter_e -0.0
# frulys_e -0.0
# g3pc_e -0.0
# g3ps_e -0.0
# g6p_e -0.0
# gal_e -1.077182787412312e-12
# gal_bD_e 0.0
# gal1p_e -0.0
# galct__D_e -0.0
# galctn__L_e -0.0
# gam_e -0.0
# gam6p_e -0.0
# gbbtn_e 0.0
# gdp_e -0.0
# glcr_e -0.0
# glyald_e -0.0
# glyc__R_e -0.0
# glyc3p_e 2.8421709430404023e-13
# gmp_e -0.0
# gsn_e 1.1723955140041653e-13
# gthox_e 1.293187779083382e-13
# gua_e -0.0
# hacolipa_e -0.0
# halipa_e -0.0
# hdca_e -0.0
# idon__L_e -0.0
# indole_e 6.252776074688882e-13
# inost_e -2.0961010704922955e-13
# ins_e -1.966782292583957e-12
# isetac_e -0.0
# lac__L_e -0.0
# lipoate_e -0.0
# lyx__L_e -0.0
# malthx_e -0.0
# malttr_e -0.0
# maltttr_e -0.0
# melib_e -0.0
# met__L_e -0.0
# metsox_S__L_e -0.0
# mnl_e -0.0
# mso3_e 0.0
# nac_e -0.0
# o16a4colipa_e -0.0
# ocdcea_e -0.0
# orot_e -0.0
# pacald_e -4.547473508864641e-13
# pheme_e -0.0
# pnto__R_e 1.4210854715202004e-12
# ppa_e -0.0
# ppal_e -0.0
# pppn_e -0.0
# progly_e -0.0
# pser__L_e 3.410605131648481e-13
# ptrc_e -0.0
# pydam_e -0.0
# pydx_e -0.0
# pyr_e -0.0
# rmn_e -0.0
# sbt__D_e -0.0
# ser__D_e 3.240074875066057e-12
# skm_e -1.7053025658242404e-13
# spmd_e -0.0
# sulfac_e -0.0
# taur_e -0.0
# thm_e -0.0
# thr__L_e -9.663381206337363e-13
# tmao_e -0.0
# ttdca_e -0.0
# ttrcyc_e 0.0
# tym_e -0.0
# tyr__L_e -0.0
# tyrp_e -0.0
# udpacgal_e -0.0
# udpg_e -0.0
# urea_e -0.0
# uri_e -0.0
# val__L_e -0.0
# xan_e 1.1368683772161603e-13
# xmp_e -0.0
# xtsn_e -0.0
# xyl__D_e -0.0
# 12dgr120_p -0.0
# 12dgr120_c -0.0
# 12dgr140_p -0.0
# 12dgr140_c -0.0
# 12dgr161_p 7.010688326166319e-13
# 12dgr161_c -0.0
# 12dgr180_p -0.0
# 12dgr180_c -0.0
# 12dgr181_p -0.0
# 12dgr181_c -0.0
# 12ppd__S_p 6.963318810448982e-13
# 14glucan_p -0.0
# 14glucan_c -2.2737367544323206e-12
# 23ccmp_e -0.0
# 23ccmp_p 0.0
# 23cgmp_e -0.0
# 23cgmp_p 0.0
# 23cump_p -0.0
# 3ump_p -0.0
# 3gmp_p -0.0
# 2ddecg3p_p -0.0
# 2ddecg3p_c -0.0
# 2tdecg3p_p 1.6910917111090384e-12
# 2tdecg3p_c -1.1084466677857563e-12
# 2odecg3p_p -0.0
# 2odecg3p_c -0.0
# 2odec11eg3p_p -0.0
# 2odec11eg3p_c -0.0
# 2agpe140_p -0.0
# 2agpe140_c -0.0
# 2agpe141_p -0.0
# 2agpe141_c -0.0
# ttdcea_c -0.0
# amp_c -2.2737367544323206e-13
# pe141_c -0.0
# 2agpg160_p -0.0
# 2agpg160_c -0.0
# 2agpg161_p -0.0
# 2agpg161_c -0.0
# 2agpg180_p -0.0
# 2agpg180_c -0.0
# 2agpg181_p -0.0
# 2agpg181_c -0.0
# 2agpg120_c -1.3855583347321954e-13
# ddca_c -0.0
# pg120_c 2.3447910280083306e-13
# 2agpg141_c -0.0
# pg141_c -0.0
# hdca_c -0.0
# pg160_c -0.0
# ocdca_c -0.0
# pg180_c -0.0
# 2dhguln_c -0.0
# nadh_c 0.0
# glcn_c -0.0
# idon__L_c -0.0
# 2mahmp_c -0.0
# 4ampm_c -0.0
# 3amp_p -0.0
# 3hcddec5eACP_c -0.0
# t3c5ddeceACP_c 0.0
# 3hpalmACP_c -0.0
# tpalm2eACP_c -0.0
# 3hcpalm9eACP_c -0.0
# t3c9palmeACP_c -0.0
# 3hoctaACP_c -0.0
# toctd2eACP_c 0.0
# 3hoctACP_c -0.0
# toct2eACP_c -0.0
# 3hpp_p -0.0
# 3hpp_c 0.0
# 3dhguln_c -0.0
# 3dhgulnp_c -0.0
# uri_p 1.4802973661668733e-13
# gsn_p -9.094947017729282e-13
# 3oddecACP_c -0.0
# nadph_c 0.0
# 3hddecACP_c -0.0
# 3ocddec5eACP_c -0.0
# 3ocmrs7eACP_c -0.0
# 3hcmrs7eACP_c -0.0
# 3opalmACP_c -0.0
# 3ocpalm9eACP_c -0.0
# 3ooctdACP_c -0.0
# malACP_c -0.0
# ocACP_c -0.0
# 3odecACP_c -0.0
# ACP_c -0.0
# co2_c -3.183231456205249e-12
# dcaACP_c -0.0
# ddcaACP_c -0.0
# 3omrsACP_c -0.0
# tdeACP_c -0.0
# butACP_c -0.0
# 3ohexACP_c -0.0
# LalaDgluMdap_p -0.0
# LalaDgluMdap_c 5.115907697472721e-13
# phthr_c 4.547473508864641e-13
# 4hthr_c -6.821210263296962e-13
# 5dglcn_p -0.0
# 5dglcn_c 0.0
# dad_5_c -3.268496584496461e-13
# 5drib_c 2.2737367544323206e-13
# ade_c 0.0
# 5mtr_e -1.1368683772161603e-13
# 5mtr_p -1.1368683772161603e-13
# 5mtr_c -0.0
# ru5p__D_c 0.0
# ara5p_c -0.0
# ocdcea_c -0.0
# octeACP_c -0.0
# ocdcaACP_c -0.0
# octa_c 1.1368683772161603e-13
# malthx_p -0.0
# 4abut_c -0.0
# akg_c 1.7053025658242404e-13
# sucsal_c -0.0
# 4abut_p -0.0
# accoa_c -2.5579538487363607e-13
# btcoa_c -0.0
# 3ohcoa_c -0.0
# hxcoa_c -0.0
# 3oocoa_c -1.8947806286936003e-13
# occoa_c 3.552713678800501e-13
# 3odcoa_c -1.1368683772161603e-13
# dcacoa_c -0.0
# 3oddcoa_c -0.0
# acac_e -0.0
# acac_p -0.0
# acald_e -0.0
# acald_p -3.0127011996228248e-12
# acald_c -3.0127011996228248e-12
# adocbip_c -0.0
# agdpcbi_c -0.0
# ppa_c -0.0
# ppcoa_c -4.547473508864641e-13
# acgam1p_p -0.0
# acgam_p -0.0
# pep_c -0.0
# acgam6p_c -0.0
# pyr_c 2.5579538487363607e-13
# acglu_c -0.0
# alac__S_c -0.0
# uacmamu_c -0.0
# unaga_c -0.0
# udp_c -0.0
# unagamu_c -0.0
# acmana_p -3.836930773104541e-13
# acmum_e -0.0
# acmum_p 0.0
# acnam_p -0.0
# acnam_c -0.0
# acmana_c -2.5011104298755527e-12
# b2coa_c -0.0
# fadh2_c -0.0
# ddcacoa_c 1.3460230081527234e-13
# dd2coa_c 2.2101483284421963e-13
# pmtcoa_c 1.1368683772161603e-13
# hdd2coa_c -0.0
# stcoa_c -0.0
# od2coa_c -0.0
# acACP_c -0.0
# acorn_c -0.0
# ac_c -0.0
# orn_c -0.0
# acolipa_p -0.0
# acolipa_e -0.0
# acon_T_c -0.0
# acon_C_c -0.0
# aconm_c -0.0
# ahcys_c -0.0
# acg5sa_c 3.069544618483633e-12
# ttdceap_c -1.3831898589463282e-13
# hdeACP_c -0.0
# hdceap_c -0.0
# ocdcap_c -9.80548975348938e-13
# acser_c -1.5916157281026244e-12
# acser_p -1.5916157281026244e-12
# ac_p -0.0
# ac_e -0.0
# 4adcho_c -0.0
# 4abz_c -0.0
# chor_c 1.846435858240903e-12
# hxan_c -0.0
# ade_p 2.2737367544323206e-13
# gdp_c -0.0
# camp_c -0.0
# adn_c -0.0
# rib__D_c -5.684341886080802e-14
# adn_p -0.0
# rdmbzi_c 4.547473508864641e-13
# adocbl_c -0.0
# gmp_c -0.0
# adocbl_p -0.0
# adocbl_e -0.0
# prpp_c 0.0
# aps_c -3.410605131648481e-13
# paps_c -0.0
# imp_c -0.0
# dcamp_c -0.0
# anhgm3p_c -1.1368683772161603e-13
# anhgm_c -0.0
# acgam_c 9.094947017729282e-13
# anhm3p_c -1.1368683772161603e-13
# anhgm4p_c -0.0
# ala__D_c -0.0
# anhgm4p_p -0.0
# ala__D_p -0.0
# anhgm3p_p -0.0
# agm_c 1.1368683772161603e-13
# ptrc_c -0.0
# urea_c -0.0
# anhgm_p 1.1368683772161603e-13
# agm_p -0.0
# 1hdec9eg3p_c -0.0
# pa161_c -0.0
# 1odecg3p_c -0.0
# pa180_c -0.0
# air_c -0.0
# hco3_c -0.0
# 5caiz_c 1.7053025658242404e-13
# alaala_c -0.0
# alaala_p -0.0
# pyam5p_c -0.0
# alatrna_c -0.0
# ala__L_p -0.0
# etoh_c -0.0
# all__D_c -0.0
# all6p_c -0.0
# alltt_c -1.1368683772161603e-12
# urdglyc_c -0.0
# alltn_e 1.6200374375330284e-11
# alltn_p 1.6200374375330284e-11
# 2agpe160_p -0.0
# lpp_p -0.0
# acetol_c -9.094947017729282e-13
# 12ppd__R_c -0.0
# altrn_c -0.0
# 2ddglcn_c -1.7479351299698463e-12
# anhm4p_c -2.4158453015843406e-13
# LalaDgluMdapDala_c 5.351121844482962e-13
# anhm_c -0.0
# malt_c 0.0
# maltpt_c 0.0
# glc__D_c 0.0
# malthx_c 1.1368683772161603e-13
# acmanap_c -0.0
# 8aonn_c -0.0
# dann_c -0.0
# for_c 0.0
# r5p_c 0.0
# amp_p -0.0
# anth_c 1.1368683772161603e-13
# pran_c -3.524291969370097e-12
# ap4a_c -0.0
# ap5a_c -0.0
# glyc3p_c -0.0
# ttdcap_c -2.2737367544323206e-13
# 1tdecg3p_c -0.0
# 1tdec7eg3p_c -0.0
# ttdca_c 1.827109891954541e-13
# hdcap_c -3.410605131648481e-13
# hdcea_c 1.9895196601282805e-13
# arab__L_c -0.0
# rbl__L_c -0.0
# arbtn_fe3_c -0.0
# arbtn_c -0.0
# arbtn_p -0.0
# arab__L_p 0.0
# arg__L_p 1.7053025658242404e-13
# co2_p -3.410605131648481e-13
# citr__L_c -8.526512829121202e-13
# argsuc_c -0.0
# argtrna_c -0.0
# arg__L_e 5.684341886080801e-13
# aspsa_c -0.0
# 4pasp_c -0.0
# ascb6p_c -2.2737367544323206e-13
# ascb__L_p -2.2737367544323206e-13
# asn__L_p -0.0
# q8_c -0.0
# iasp_c -0.0
# q8h2_c -0.0
# mqn8_c 2.5579538487363607e-13
# mql8_c 1.9895196601282805e-13
# fum_c -0.0
# oaa_c 1.0231815394945443e-12
# asptrna_c -1.1368683772161603e-13
# asp__L_p -0.0
# succoa_c -0.0
# sucarg_c -0.0
# athr__L_c -0.0
# 2aobut_c -0.0
# itp_c -0.0
# ala_B_p -0.0
# ala_B_c 6.821210263296962e-13
# betald_c -0.0
# glyb_c 1.6768808563938364e-12
# moco_c -0.0
# mptamp_c -0.0
# bmoco_c -0.0
# but_c 3.893774191965349e-13
# butso3_p -0.0
# butso3_c -0.0
# but_p -0.0
# but_e -0.0
# bwco_c -0.0
# bwco1gdp_c -0.0
# wco_c -0.0
# cbi_e 0.0
# cbi_p -0.0
# cbi_c -0.0
# cbl1_p 0.0
# cbl1_c 0.0
# cbp_c -1.0487610779819079e-11
# cdg_c -0.0
# preq0_c -0.0
# cdpdtdecg_c -0.0
# cmp_c -0.0
# pa140_c -0.0
# cdpdtdec7eg_c -0.0
# pa141_c -0.0
# cdpdodecg_c -1.285708381864855e-13
# preq1_c -0.0
# 4c2me_c -0.0
# 2p4c2me_c -0.0
# cpe160_c -0.0
# pe181_c 1.894342022066588e-13
# cpe180_c 1.63034099059185e-13
# cgly_p -5.115907697472721e-13
# cgly_c -0.0
# cgly_e -0.0
# chol_p -0.0
# chol_c -0.0
# pphn_c 1.230630717605122e-13
# 4hbz_c 1.7053025658242404e-13
# chtbs_p -0.0
# chtbs6p_c -0.0
# cinnm_c -0.0
# cenchddd_c -0.0
# cit_c -0.0
# cit_e -0.0
# cit_p -0.0
# lipa_cold_p 1.2922996006636822e-13
# lipa_cold_e 1.2922996006636822e-13
# clpn140_p -2.945671586930179e-13
# pa140_p -0.0
# pg140_p -0.0
# clpn160_p -0.0
# pa160_p -0.0
# pg160_p -0.0
# clpn161_p -0.0
# pa161_p -0.0
# pg161_p -0.0
# clpn181_p -0.0
# pa181_p -0.0
# pg181_p 5.684341886080801e-13
# pg141_p -0.0
# clpn141_p -0.0
# glyc_p -0.0
# pg180_p -0.0
# clpn180_p -0.0
# csn_c -0.0
# colipap_p -0.0
# colipap_e -0.0
# colipa_c -0.0
# colipa_p -0.0
# cpgn_c -0.0
# cpgn_un_c -0.0
# fmnh2_c -0.0
# fmn_c -0.0
# cpgn_un_p -0.0
# cpgn_p -0.0
# cpmp_c -0.0
# bbtcoa_c -0.0
# crn_c 1.178209045478566e-12
# crncoa_c -0.0
# gbbtn_c -0.0
# crn__D_c -0.0
# crnDcoa_c -1.9895196601282805e-13
# crn__D_p -0.0
# crn_p -0.0
# crn_e -0.0
# ura_c 1.1937117960769683e-12
# csn_p -4.547473508864641e-13
# ctbt_p -6.252776074688882e-13
# ctbt_c -6.252776074688882e-13
# tdecoa_c -0.0
# td2coa_c -0.0
# hdcoa_c -0.0
# odecoa_c -0.0
# cyan_c 0.0
# tcynt_c -0.0
# cynt_c -0.0
# cynt_e 0.0
# cynt_p 0.0
# cys__D_p -0.0
# cys__D_c 5.684341886080801e-13
# cyst__L_c -0.0
# hcys__L_c -0.0
# cystrna_c -0.0
# cys__L_p -5.684341886080801e-13
# cytd_c -0.0
# uri_c -0.0
# cytd_p -2.8421709430404007e-13
# lac__D_p -6.821210263296962e-13
# lac__D_c -4.547473508864641e-13
# lac__D_e -4.547473508864641e-13
# dad_2_p 1.1368683772161603e-13
# dad_2_c -1.1368683772161603e-13
# 12dgr160_c -2.1967612913916437e-13
# pa160_c -0.0
# damp_p -0.0
# 26dap__M_c -0.0
# 26dap__M_p 0.0
# 15dap_p -3.410605131648481e-13
# cdpdhdec9eg_c -0.0
# ditp_c -0.0
# dca_e -0.0
# dca_p -0.0
# dcmp_e -0.0
# dcmp_p -0.0
# dutp_c -0.0
# dcyt_c -0.0
# duri_c 2.2737367544323206e-13
# dcyt_p -0.0
# ddca_p 2.6211132030261476e-13
# 2ddglcn_p -2.984279490192421e-13
# 2ddglcn_e -1.3642420526593924e-12
# 2ddg6p_c -4.547473508864641e-13
# dgmp_c -2.8421709430404007e-13
# dgdp_c -0.0
# dgmp_e -0.0
# dgmp_p 0.0
# 23dhacoa_c 1.6895127272517938e-13
# 3hadpcoa_c -0.0
# 23dhmb_c -1.9895196601282805e-12
# 3mob_c -0.0
# dha_p -0.0
# 23ddhb_c -0.0
# 23dhb_c 1.1368683772161603e-13
# dhcinnm_c -0.0
# hkntd_c 0.0
# dhf_c -1.5631940186722204e-13
# dhpt_c -0.0
# dhna_c 4.0323300254385686e-13
# octdp_c 1.0658141036401503e-12
# 2dmmql8_c -0.0
# 14dhncoa_c -0.0
# dhnpt_c -0.0
# dhmpt_c -0.0
# dhor__S_c -0.0
# orot_c -0.0
# 25drapp_c -0.0
# 5apru_c -0.0
# dhptdn_c 0.0
# thptdn_c 0.0
# ahdt_c 0.0
# dhmptp_c -0.0
# 2dda7p_c -0.0
# 3dhq_c -0.0
# 25dkglcn_c -0.0
# dmpp_c -0.0
# ipdp_c -0.0
# grdp_c -0.0
# dmso_c -0.0
# dms_c -0.0
# dmso_p -0.0
# dms_p 0.0
# 2dmmq8_c -0.0
# doxrbcn_p 0.0
# 2dhp_c 0.0
# pant__R_c -0.0
# gthrd_p -0.0
# gthox_p -0.0
# ser__D_c -9.094947017729282e-13
# 2amsa_c -9.094947017729282e-13
# dtmp_c -0.0
# dtdp_c -0.0
# dtmp_e 1.5276668818842154e-13
# dtmp_p 1.5276668818842154e-13
# dump_c -0.0
# duri_p -6.465938895416912e-13
# duri_e -0.0
# dxyl5p_c -2.0463630789890885e-12
# 2me4p_c -2.0463630789890885e-12
# e4p_c 0.0
# 4per_c 1.1368683772161603e-13
# tdec2eACP_c -0.0
# tddec2eACP_c -0.0
# tmrs2eACP_c -0.0
# myrsACP_c -0.0
# t3c7mrseACP_c -0.0
# t3c11vaceACP_c -0.0
# but2eACP_c -0.0
# thex2eACP_c -0.0
# hexACP_c -0.0
# eca4und_p -0.0
# eca4colipa_p -0.0
# udcpdp_p -0.0
# eca2und_p -0.0
# unagamuf_p -0.0
# eca3und_p -0.0
# unagamuf_c -0.0
# 3hbcoa_c 2.1316282072803006e-13
# 3hhcoa_c -1.9353830707370347e-13
# hx2coa_c 2.734584047672952e-13
# 3hdcoa_c -1.0162681507141754e-13
# dc2coa_c -2.6744362644347393e-13
# 3htdcoa_c 2.3540512340884117e-13
# 3hodcoa_c -0.0
# kdo2lipid4_c -0.0
# kdo2lipid4L_c -1.9509272399681847e-13
# kdo2lipid4p_c -0.0
# lipa_cold_c -0.0
# enter_c 2.930594039046102e-13
# 23dhbzs_c -0.0
# feenter_c -0.0
# epmeACP_c -0.0
# pmeACP_c -0.0
# etha_c 1.7621459846850485e-12
# etha_p 1.7621459846850485e-12
# etha_e 1.7621459846850485e-12
# etoh_e 1.4982301114027256e-12
# etoh_p -0.0
# f6p_c 0.0
# dha_c -0.0
# g3p_c 0.0
# dca_c -1.0800249583553523e-12
# palmACP_c -0.0
# tdcoa_c -0.0
# hxa_c -0.0
# hdcea_p -0.0
# ocdca_p -0.0
# hmgth_c 3.410605131648481e-13
# Sfglutth_c -0.0
# fdp_c 0.0
# dhap_c 0.0
# fuc__L_c -0.0
# fcl__L_c -0.0
# fc1p_c -0.0
# ppp9_c -0.0
# for_p -0.0
# mso3_c 3.865352482534945e-12
# fald_c 5.002220859751105e-12
# ethso3_c -0.0
# fe3dhbzs_c -0.0
# fe3dhbzs_e -0.0
# fe3dhbzs_p -0.0
# fe3hox_c -0.0
# fe3hox_un_c -0.0
# fe3hox_un_p -0.0
# fe3hox_un_e -0.0
# fe3hox_p -0.0
# fecrm_c -0.0
# fecrm_un_c -0.0
# rbflvrd_c 1.5631940186722204e-13
# fecrm_un_p -0.0
# fecrm_p -0.0
# enter_p -0.0
# feoxam_c -0.0
# feoxam_un_c -0.0
# feoxam_un_p -0.0
# feoxam_p -0.0
# forcoa_c 3.694822225952521e-13
# oxa_c -0.0
# oxalcoa_c -0.0
# for_e -0.0
# succ_c -1.7053025658242404e-13
# frulys_c -0.0
# frulysp_c -4.192202140984591e-13
# frulys_p -0.0
# fruur_p -0.0
# fruur_c -0.0
# fru_p -0.0
# f1p_c -0.0
# fuc__L_p -0.0
# mal__L_c -0.0
# fusa_e 0.0
# fusa_p 0.0
# gam1p_c 1.1937117960769683e-12
# acgam1p_c -0.0
# g1p_p -0.0
# glc__D_p -0.0
# g1p_c 0.0
# dtdpglu_c -4.547473508864641e-13
# glu1sa_c -0.0
# 5aop_c -0.0
# 1hdecg3p_c -0.0
# g3pe_e -0.0
# g3pe_p -0.0
# g3pi_p -0.0
# g3pi_c 0.0
# g3pi_e 0.0
# g3ps_p -0.0
# g3ps_c -0.0
# glyc_c -0.0
# gam6p_c -0.0
# g6p_c -0.0
# 6pgl_c -0.0
# g6p_p -0.0
# gal1p_p -0.0
# galct__D_c -0.0
# 5dh4dglc_c -0.0
# galctn__L_p -0.0
# galctn__D_e -0.0
# galctn__D_p 0.0
# gal_bD_p -0.0
# gal_p -0.0
# gicolipa_c -0.0
# udpg_c -0.0
# gagicolipa_c -0.0
# galt_p -0.0
# galt1p_c -1.5916157281026244e-12
# galur_p -0.0
# galur_c -0.0
# galur_e 0.0
# gal_c -0.0
# gam6p_p -0.0
# gam_p -0.0
# gar_c 3.410605131648481e-13
# fgam_c -1.4712414293385605e-13
# gbbtn_p -0.0
# gdpddman_c -0.0
# gdpofuc_c -0.0
# gdpmann_c -1.2789769243681803e-13
# man1p_c -0.0
# gdp_p -0.0
# gg4abut_c -0.0
# glcn_p -0.0
# glycogen_c -0.0
# bglycogen_c -0.0
# 2h3oppan_c 1.0231815394945443e-12
# glcr_c -0.0
# glcr_p 0.0
# adpglc_c 0.0
# icolipa_c -0.0
# ggagicolipa_c -0.0
# gggagicolipa_c -0.0
# glcur1p_e -0.0
# glcur1p_p 0.0
# glcur_e -0.0
# glcur_p -0.0
# gln__L_e -0.0
# gln__L_p -0.0
# glucys_c -0.0
# glu__L_p -0.0
# pram_c -0.0
# glu__D_c -4.092726157978177e-12
# glutrna_c -0.0
# glu__L_e -0.0
# glx_c 1.1368683772161603e-13
# glyald_p 4.320099833421409e-12
# glyald_c 4.320099833421409e-12
# glyb_p -0.0
# glyb_e -0.0
# glyc3p_p 2.8421709430404007e-12
# glyc__R_p 3.410605131648481e-13
# glyc__R_c 3.410605131648481e-13
# 3pg_c -0.0
# 2pg_c -4.547473508864641e-13
# glyclt_c 3.410605131648481e-13
# glyclt_p 3.410605131648481e-13
# glyclt_e 3.410605131648481e-13
# glyc_e 7.958078640513122e-13
# lgt__S_c -0.0
# gthrd_c -2.8421709430404007e-13
# mthgxl_c -1.1368683772161603e-13
# gly_p 2.2737367544323206e-13
# gmhep1p_c -0.0
# adphep_DD_c -0.0
# gmhep7p_c -0.0
# gmhep17bp_c -0.0
# xmp_c -2.8421709430404007e-13
# 6pgc_c -0.0
# gp4g_c -0.0
# g3pc_p -4.689582056016661e-13
# g3pe_c 6.821210263296962e-13
# ser__L_p -2.2737367544323206e-13
# g3pg_c -0.0
# g3pg_p 5.684341886080801e-13
# inost_c -0.0
# inost_p -0.0
# frdp_c 3.5745765322085034e-13
# gthox_c 6.042702570203287e-13
# gsn_c -0.0
# gtspmd_c 1.7053025658242404e-13
# spmd_c 3.410605131648481e-13
# gthrd_e -0.0
# gdptp_c -0.0
# xtp_c -0.0
# gtp_e -0.0
# gtp_p 0.0
# gua_c -0.0
# gua_p -0.0
# glcur_c -0.0
# tagur_c -0.0
# 3hddcoa_c -0.0
# 3ohdcoa_c -0.0
# 3hhdcoa_c -0.0
# 3ophb_c 1.3207735558834802e-13
# 3hcinnm_p -0.0
# 3hcinnm_c 0.0
# mmet_c -0.0
# hdcea_e -4.941004870208696e-13
# hemeO_c -0.0
# adphep_LD_c -0.0
# hlipa_c -0.0
# hhlipa_c -0.0
# man_c -0.0
# man6p_c 1.7053025658242404e-13
# histd_c 1.4210854715202004e-12
# his__L_p -0.0
# his__L_e -0.0
# ppbng_c -0.0
# hmbil_c -0.0
# 4h2opntn_c -0.0
# dhpppn_c -0.0
# hkndd_c 0.0
# 3hpppn_p -0.0
# 3hpppn_c 0.0
# hpyr_c -1.7053025658242404e-12
# hom__L_c -0.0
# phom_c -0.0
# suchms_c -0.0
# imacp_c -3.581135388230905e-12
# hisp_c 1.1368683772161603e-13
# pydam_c -0.0
# hxan_e -0.0
# hxan_p -0.0
# ichor_c -0.0
# prlp_c -6.821210263296962e-13
# aicar_c -0.0
# eig3p_c -5.89547458470666e-13
# 2cpr5p_c -5.115907697472721e-13
# 3ig3p_c -0.0
# 3mop_c 1.6402771397031648e-12
# ile__L_e 1.6650384774645015e-12
# ile__L_p 1.6650384774645015e-12
# imp_e -2.5579538487363607e-13
# imp_p -0.0
# indole_c 1.7053025658242404e-13
# indole_p -0.0
# ins_c -0.0
# ins_p -0.0
# h2mb4p_c -0.0
# 3c2hmp_c -0.0
# 3c4mop_c -0.0
# 2ippm_c 1.7621459846850485e-12
# 3c3hmp_c -1.3073986337985843e-12
# isetac_p -0.0
# 2ahbut_c 1.8092981283541363e-12
# 23dhmp_c -0.0
# kdo8p_c -0.0
# kdo_c -0.0
# lac__L_c -0.0
# lcts_c -0.0
# LalaLglu_e -0.0
# LalaLglu_p 0.0
# LalaLglu_c 1.1302070390684096e-13
# lald__L_c -0.0
# lcts_p -1.4210854715202004e-13
# lcts_e -1.4210854715202004e-13
# 4mop_c -0.0
# leutrna_c 0.0
# leu__L_p 0.0
# lipoate_c -0.0
# lipoamp_c -0.0
# lipa_c -1.886167989472266e-13
# lipa_p -0.0
# octapb_c 3.0488742843524297e-13
# lipoate_p -0.0
# 1tdecg3p_p 1.7621459846850485e-12
# ttdca_p -0.0
# 1tdec7eg3p_p -0.0
# ttdcea_p -0.0
# 1hdec9eg3p_p -0.0
# 1odec11eg3p_p 2.722322506657807e-13
# ocdcea_p -0.0
# 1agpe140_p -0.0
# 1agpe141_p -0.0
# 1agpe180_p -1.1368683772161603e-13
# 1agpe181_p -0.0
# 1agpg141_p -0.0
# 1agpg161_p -0.0
# 1agpg180_p -5.430531398493371e-13
# 1agpg181_p -4.2109752236479793e-13
# 2agpe120_c -0.0
# apg120_c -0.0
# 2agpe161_c -0.0
# pg161_c -0.0
# apg161_c -0.0
# apg141_c 1.6105635343895603e-13
# apg160_c 2.267815564967653e-13
# 2agpe160_c -2.352685947294554e-13
# 2agpe180_c -0.0
# 2agpg140_c -0.0
# lystrna_c -0.0
# lys__L_p -0.0
# lys__L_e -0.0
# lyx__L_p -0.0
# lyx__L_c 0.0
# malcoa_c -0.0
# malcoame_c -0.0
# maltpt_e -0.0
# maltpt_p 0.0
# malttr_p -0.0
# maltttr_p -0.0
# maltttr_c -0.0
# malt_p -0.0
# mal__L_p -0.0
# mal__L_e -0.0
# man6p_p -0.0
# man6p_e -0.0
# man6pglyc_c -0.0
# murein4px4p_p -0.0
# murein5px4px4p_p -0.0
# murein4px4px4p_p -0.0
# murein5p4p_p -0.0
# murein4p4p_p -0.0
# murein5p3p_p -0.0
# murein4p3p_p -0.0
# 2mecdp_c -0.0
# melib_c -0.0
# melib_p -5.684341886080801e-13
# met__D_p -0.0
# met__D_c -0.0
# met__D_e 0.0
# metsox_S__L_p -0.0
# mettrna_c -0.0
# met__L_p -0.0
# mincyc_e 0.0
# mincyc_p 0.0
# minohp_e -0.0
# minohp_p 0.0
# murein5px3p_p -0.0
# murein3px3p_p -1.8000415972589204e-13
# murein3p3p_p -1.8000415972589204e-13
# malttr_c -4.831690603168681e-13
# malthp_c -2.0842586915629605e-13
# mmcoa__S_c -0.0
# mmet_e -0.0
# mmet_p 0.0
# mnl_p -0.0
# mnl1p_c -0.0
# moadamp_c -0.0
# moadcosh_c -0.0
# ckdo_c -0.0
# lipidA_c 1.545430450278218e-13
# kdolipid4_c -0.0
# phphhlipa_c -0.0
# kphphhlipa_c -0.0
# mocogdp_c -0.0
# uaagmda_c -0.0
# murein5p5p_p -0.0
# murein5p5p5p_p -0.0
# moadcoo_c -0.0
# msa_c -0.0
# mso3_p -0.0
# 5mta_c -0.0
# 5mthf_c -4.547473508864641e-13
# glu5sa_c -0.0
# nac_p -0.0
# cdp_c -0.0
# dudp_c -0.0
# nmn_c -0.0
# nicrnt_c -0.0
# ncam_c -0.0
# nmn_p -0.0
# nac_c -0.0
# dnad_c -2.2737367544323206e-13
# xtsn_c -0.0
# xmp_p -0.0
# xtsn_p -0.0
# ump_c -0.0
# cmp_p -0.0
# thymd_c -0.0
# damp_c -0.0
# dgsn_c -0.0
# dgsn_p -0.0
# gmp_p -0.0
# idp_c -0.0
# dcmp_c -0.0
# o16a4colipa_p -0.0
# o16aund_p -0.0
# o16a2und_p -0.0
# aragund_c -4.405364961712621e-13
# garagund_c 1.849102881394737e-13
# 2obut_c -0.0
# 2omph_c -3.410605131648481e-13
# 2ommbl_c -0.0
# 2omhmbl_c -5.684341886080801e-13
# 2ombzl_c -8.562039965909207e-13
# op4en_c -0.0
# 2oph_c -0.0
# gmeACP_c -0.0
# opmeACP_c -0.0
# orn_p 6.821210263296962e-13
# orn_e 6.821210263296962e-13
# orot_p -0.0
# 2oxpaccoa_c -2.8421709430404007e-13
# 3oxdhscoa_c -0.0
# 1pyr5c_c 1.9722194891706435e-13
# pa141_p 4.121147867408581e-13
# pacald_p -0.0
# pacald_c 0.0
# phaccoa_c -0.0
# rephaccoa_c -1.0421293457814804e-13
# pnto__R_c -0.0
# pa120_p -0.0
# 12dgr141_p -0.0
# pa180_p -0.0
# pap_c -0.0
# 35cgmp_c 1.1368683772161603e-13
# pdx5p_c -5.115907697472721e-13
# pe141_p -0.0
# peamn_e -0.0
# peamn_p 0.0
# pe181_p -0.0
# enlipa_p -0.0
# pg120_p -4.316198500195963e-13
# pg140_c -0.0
# pg181_c -1.6776703483224587e-13
# 3php_c -0.0
# 2pglyc_c -1.1368683772161593e-12
# pgp160_c -0.0
# pgp160_p 1.4988010832439603e-13
# pgp161_c 3.268496584496461e-13
# pgp161_p -0.0
# pgp180_c -0.0
# pgp180_p -0.0
# pgp181_c -0.0
# pgp181_p -0.0
# pgp120_p -0.0
# pgp140_c -0.0
# pgp140_p -0.0
# pgp141_p -1.127396193789289e-13
# pgp141_c -0.0
# cdpdhdecg_c -0.0
# cdpdodec11eg_c -0.0
# pheme_p -0.0
# phpyr_c -0.0
# pe120_p -0.0
# 2agpe120_p -0.0
# pe140_p -0.0
# hdca_p -0.0
# 2agpg140_p -0.0
# 2agpg141_p -4.714296585956144e-13
# 1ddecg3p_p 1.9895196601282805e-13
# 1odecg3p_p -0.0
# 1agpe160_p -0.0
# 1agpe161_p -3.410605131648481e-13
# pe180_p -0.0
# 1agpg120_p -0.0
# 1agpg140_p -0.0
# 5aprbu_c -0.0
# 4r5au_c 3.2297397080004553e-13
# meoh_c -0.0
# pimACP_c -0.0
# 4ppan_c -0.0
# pnto__R_p -0.0
# poaac_c 3.410605131648481e-13
# 3amac_c 3.410605131648481e-13
# ppal_p -0.0
# ppal_c -0.0
# 4ppcys_c -0.0
# pan4p_c -2.2737367544323206e-13
# pppg9_c -0.0
# pppn_c -0.0
# cechddd_c -0.0
# pppn_p -0.0
# fpram_c -0.0
# prbatp_c -0.0
# prbamp_c -0.0
# progly_p -0.0
# progly_c 0.0
# pro__L_e -0.0
# pro__L_p -0.0
# psclys_p -0.0
# psclys_c -0.0
# skm5p_c -0.0
# 3psme_c -1.0658141036401504e-13
# ps120_c -0.0
# pe120_c -1.9895196601282805e-13
# ps160_c -0.0
# ps181_c -3.694822225952521e-13
# pser__L_c -0.0
# ps140_c -0.0
# ps180_c -0.0
# ppap_c -0.0
# actp_c 6.394884621840902e-13
# thrp_p -0.0
# thr__L_p -0.0
# ptrc_p -0.0
# r1p_c -0.0
# 2dr1p_c -0.0
# pydxn_e -0.0
# pydxn_p -0.0
# pydx_p -0.0
# pyr_p -0.0
# quin_e -0.0
# quin_p 0.0
# quin_c 0.0
# r15bp_c 0.0
# r5p_e -0.0
# r5p_p 0.0
# ru5p__L_c -0.0
# xu5p__D_c 0.0
# rfamp_e 0.0
# rfamp_p 0.0
# rhcys_c -0.0
# dhptd_c 2.2470914018413163e-13
# rib__D_p 2.2737367544323206e-13
# rib__D_e 2.2737367544323206e-13
# rml_c -0.0
# rml1p_c -0.0
# dadp_c -4.831690603168681e-13
# dcdp_c -0.0
# sucorn_c -0.0
# sbt6p_c -0.0
# sl26da_c -6.201100239360874e-13
# sl2a6o_c -6.201100239360874e-13
# dgslnt_c -0.0
# gslnt_c -0.0
# seramp_c -0.0
# ser__L_e -0.0
# scl_c -0.0
# 3dhsk_c -0.0
# skm_c 1.8474111129762605e-13
# skm_p 1.7053025658242404e-13
# sucgsa_c 1.1368683772161603e-13
# N1aspmd_c -0.0
# n8aspmd_c 4.547473508864641e-13
# ametam_c -0.0
# 2shchc_c 1.1368683772161603e-13
# sucbz_c 1.1368683772161603e-13
# succ_p -0.0
# succ_e -1.0800249583553523e-12
# sucr_e -0.0
# sucr_p 0.0
# suc6p_c -0.0
# sulfac_p -0.0
# cdec3eACP_c -0.0
# s7p_c 0.0
# tartr__L_e -0.0
# tartr__L_p 0.0
# tartr__D_p -0.0
# tartr__D_c 0.0
# taur_p -0.0
# dtdp4d6dg_c -0.0
# dtdp4d6dm_c -0.0
# lipidAds_c -0.0
# methf_c -3.410605131648481e-13
# 5fthf_c -2.2737367544323206e-13
# thymd_e -0.0
# thymd_p -0.0
# thm_p -0.0
# thm_c -0.0
# thrp_e -0.0
# thrtrna_c -0.0
# thym_c -0.0
# thym_p 0.0
# thym_e -0.0
# tmao_c -0.0
# tma_c -0.0
# tma_e 0.0
# tma_p 0.0
# tre_c -0.0
# tre_p -0.0
# tre_e -0.0
# trptrna_c 0.0
# trp__L_p 1.1627062948801642e-13
# trp__L_e 1.1627062948801642e-13
# dhgly_c -0.0
# tym_p 3.410605131648481e-13
# 4hoxpacd_p -0.0
# tyr__L_p -1.8189894035458565e-12
# uamag_c -0.0
# ugmd_c -0.0
# uacgam_e -0.0
# uacgam_p 0.0
# uacmam_c -0.0
# uacgam_c -0.0
# 3hmrsACP_c -0.0
# u3aga_c -1.0401879721865074e-13
# uama_c -0.0
# uamr_c -0.0
# uaccg_c 3.126388037344441e-13
# udpacgal_p -0.0
# udpgal_c -0.0
# udpgalfur_c -0.0
# udpgal_p -0.0
# ump_p -0.0
# udpgal_e -0.0
# udpglcur_c -0.0
# udpLa4o_c -0.0
# udpg_p -0.0
# udpLa4n_c -0.0
# gal1p_c -0.0
# ugmda_c -0.0
# um4p_c -0.0
# uLa4fn_c 1.9539925233402755e-13
# uLa4n_c -0.0
# uppg3_c -0.0
# dscl_c -0.0
# cpppg3_c -0.0
# uracp_c -0.0
# cbm_c -0.0
# u23ga_c 2.4241266854510084e-13
# lipidX_c -0.0
# valtrna_c 0.0
# val__L_p 5.728067592896807e-13
# xan_p -3.410605131648481e-13
# xan_c -3.410605131648481e-13
# fru_c -0.0
# xylu__L_p -0.0
# xylu__L_c 0.0
# xyl__D_p 1.1368683772161603e-13
# xyl__D_c 1.1368683772161603e-13
# 2dhglcn_c -0.0
# dtbt_c -2.2737367544323206e-13
# hmfurn_c -0.0
# dkmpp_c -2.689911785377522e-13
# 2kmb_c -0.0
# 4hba_c -3.061033304429608e-13
# eca4colipa_e -0.0
# aacoa_c -9.094947017729282e-13
# 3otdcoa_c -0.0
# kdo2lipid4_p 2.5579538487363607e-13
# lipa_e -0.0
# 5mdru1p_c -6.821210263296962e-13
# 5mdr1p_c -0.0
# sbzcoa_c 3.979039320256561e-13
# ssaltpp_c -0.0
# 4mpetz_c -0.0
# 13BDglcn_c -0.0
# 16BDglcn_c -0.0
# 2dhp_m -0.0
# 2doxg6p_c -0.0
# 2dglc_c -0.0
# 2hb_c -0.0
# 2hpmhmbq_m -0.0
# amet_m -0.0
# ahcys_m -0.0
# q6_m -3.884300288821881e-13
# 2hp6mp_m -0.0
# 2hp6mbq_m -0.0
# 2mbac_c -0.0
# 2mbac_e -0.0
# 2mbald_c 0.0
# 2mbald_e -0.0
# 2oxoadp_m -0.0
# 2oxoadp_c -0.0
# 2phetoh_e -0.0
# 2phetoh_c 0.0
# 34hpp_c -3.957769636418351e-13
# 34hpp_x -6.117935245297701e-13
# 3c3hmp_e -0.0
# 3c3hmp_m 0.0
# 3dh5hpb_c -0.0
# 3dh5hpb_m -0.0
# 3dsphgn_c -0.0
# sphgn_c -0.0
# 3mbald_c 2.192531870345451e-12
# 3mbald_e 2.192531870345451e-12
# 3mbald_m 2.192531870345451e-12
# 3mop_m -0.0
# 4abut_m -0.0
# 4abz_m -1.9895196601282805e-12
# 4h2oglt_c -0.0
# 4h2oglt_x -0.0
# coa_m -8.498784332115929e-13
# coucoa_m -0.0
# nad_m -0.0
# 4hbzcoa_m -0.0
# accoa_m -0.0
# nadh_m -0.0
# 4hbz_m -0.0
# 4hpro_LT_c -0.0
# 4hpro_LT_m -0.0
# 5aop_m -0.0
# 6pgl_r -0.0
# 4aabutn_c -0.0
# L2aadp_c -0.0
# 3odcoa_x -0.0
# coa_x -0.0
# accoa_x -0.0
# occoa_x -1.0885173775308493e-13
# 3oddcoa_x -0.0
# dcacoa_x -0.0
# 3otdcoa_x -0.0
# ddcacoa_x -4.902744876744691e-13
# 3ohdcoa_x -2.2737367544323206e-13
# tdcoa_x -0.0
# 3ohodcoa_x -0.0
# pmtcoa_x 1.009549407369554e-13
# actn__R_c 2.8421709430404007e-13
# atp_m 2.842170943040401e-14
# hco3_m -0.0
# adp_m -8.526512829121202e-14
# malcoa_m -0.0
# accoa_n -0.0
# 2obut_m -0.0
# pyr_m -0.0
# 2ahbut_m -0.0
# co2_m 5.115907697472721e-13
# aces_c 2.2737367544323206e-13
# alac__S_m -0.0
# td2coa_x -2.2737367544323206e-13
# hdd2coa_x -0.0
# hexccoa_x -0.0
# hxc2coa_x -0.0
# icit_c -0.0
# acrn_x 1.8758328224066645e-12
# acrn_c 1.8758328224066645e-12
# ac_m -0.0
# ade_m -0.0
# 1agly3p_SC_c -0.0
# 1ag3p_SC_c -0.0
# amp_m -0.0
# gtp_m 2.2737367544323206e-13
# gdp_m -0.0
# itp_m 0.0
# idp_m -0.0
# acg5p_m -3.410605131648481e-13
# nadph_m -0.0
# acg5sa_m -1.3880621519915404e-12
# nadp_m -0.0
# 4ahmmp_c 2.1316282072803006e-13
# gcald_c -1.9895196601282805e-12
# achms_c -1.7053025658242404e-13
# ch4s_c -0.0
# 5aizc_c -1.1368683772161603e-13
# akg_m 3.410605131648481e-13
# lpam_m -0.0
# sdhlam_m -0.0
# akg_e -0.0
# 2mbtoh_c -0.0
# 2mppal_c -0.0
# ibutoh_c -0.0
# iamoh_c -0.0
# id3acald_m -6.252776074688882e-13
# ind3eth_m -4.575895218295046e-13
# ind3ac_m -0.0
# alltt_e -0.0
# allphn_c -2.5579538487363607e-13
# pad_c 1.1368683772161603e-13
# pac_c 2.2737367544323206e-13
# amp_n 1.1368683772161603e-13
# Dara14lac_c -2.2737367544323206e-13
# ertascb__D_c -3.410605131648481e-13
# arab__D_c 0.0
# arab__D_e -0.0
# NPmehis_c -0.0
# asn__L_v -0.0
# asp__L_m -0.0
# glu__L_m 1.1368683772161603e-12
# glu__L_x -0.0
# asp__L_x -0.0
# oaa_m -0.0
# asp__L_n -0.0
# btd_RR_c -0.0
# btd_RR_e -0.0
# ergtrol_c -0.0
# ergtetrol_c -0.0
# ergtetrol_r -0.0
# nadph_r -0.0
# ergst_r -0.0
# nadp_r -0.0
# 4mzym_int1_c -0.0
# 4mzym_int2_c -0.0
# 4mzym_c -0.0
# zym_int1_c -0.0
# epist_c -5.02947910739196e-13
# cbp_n -0.0
# cdpdag_SC_m -0.0
# glyc3p_m 1.1368683772161603e-13
# cmp_m -0.0
# pgp_SC_m -0.0
# cer2_24_c -0.0
# cer2_24_r -0.0
# cer1_26_r -0.0
# coa_r -0.0
# hexccoa_r -0.0
# sphgn_r 1.1675739740115076e-12
# psphings_r -0.0
# ttccoa_r -0.0
# cer1_24_c -0.0
# cer1_26_c -0.0
# cer2_26_c -0.0
# ttccoa_c -0.0
# cer1_24_r -0.0
# hexccoa_c -0.0
# psphings_c -0.0
# cholp_c -0.0
# cdpchol_c -0.0
# zymst_c -0.0
# chitin_c -3.410605131648481e-13
# chitos_c -0.0
# udpacgal_c -0.0
# cit_x -0.0
# mal__L_x -0.0
# icit_m 4.547473508864641e-13
# cit_m -5.684341886080801e-13
# co2_g 1.1368683772161603e-12
# co2_x -2.0321522242738865e-12
# co2_v -2.0321522242738865e-12
# pan4p_x -0.0
# pap_x -3.800634650671773e-13
# coa_n 0.0
# T4hcinnm_m -1.7053025658242404e-13
# crn_m 2.5579538487363607e-13
# acrn_m -0.0
# csn_e -2.2737367544323206e-13
# oaa_x -0.0
# ctp_m -1.1368683772161603e-13
# cyst__L_x -0.0
# hcys__L_x -0.0
# pyr_x -0.0
# dadp_n 6.821210263296962e-13
# pa_SC_m -0.0
# dcdp_n 7.705441223353975e-13
# dgdp_n -0.0
# 6dg_c -0.0
# 23dhmb_m -1.1368683772161603e-12
# 3mob_m 8.810729923425242e-13
# 23dhmp_m 1.7053025658242404e-13
# dhf_m -0.0
# thf_m 1.1368683772161603e-13
# sprm_c 1.7053025658242404e-13
# N1sprm_c -0.0
# din_c -0.0
# caphis_c -0.0
# cmaphis_c -0.0
# dolmanp_r -0.0
# dolp_r -0.0
# mannan_r -0.0
# dolp_c -0.0
# pant__R_m -0.0
# drib_c -0.0
# 2dr5p_c -0.0
# dttp_e -0.0
# dump_n -0.0
# ficytc_m -0.0
# lac__D_m -0.0
# focytc_m -0.0
# 3hxccoa_x -0.0
# 3hdcoa_x 2.5579538487363607e-13
# dc2coa_x 2.5579538487363607e-13
# 3htdcoa_x -1.1328081330118168e-12
# 3hhdcoa_x -0.0
# e4hglu_c -0.0
# e4hglu_m -0.0
# 4h2oglt_m -9.094947017729282e-13
# akg_x -0.0
# e4hglu_x -0.0
# pectin_e -0.0
# epistest_SC_e -0.0
# epist_e -0.0
# hexc_e -0.0
# ocdca_e 5.613287612504791e-13
# ergstest_SC_e -0.0
# ergst_e -0.0
# ergst_c -0.0
# ergst3glc_c -3.943853790553056e-13
# ethamp_c -6.252776074688882e-13
# 2hb_e -0.0
# 2mbtoh_e -0.0
# 3mop_e -0.0
# 4abz_e -2.2737367544323206e-13
# 8aonn_e -0.0
# Nbfortyr_e -0.0
# aces_e -0.0
# amet_e -0.0
# fmn_e 1.1368683772161603e-13
# glx_e 1.4210854715202004e-12
# iamac_e -0.0
# iamoh_e -0.0
# ibutoh_e -0.0
# id3acald_e -0.0
# oaa_e -2.1316282072803006e-12
# ocdcya_e -0.0
# pc_SC_e -0.0
# pepd_e 0.0
# pheac_e -8.753886504564434e-13
# ptd1ino_SC_e -0.0
# sbt__L_e -0.0
# sprm_e -0.0
# thmpp_e 0.0
# zymst_e -0.0
# dca_x -0.0
# ddcaACP_m -0.0
# atp_x -2.2737367544323206e-13
# adp_x -0.0
# tdecoa_x -2.5884056802689365e-13
# ttdcea_x -0.0
# palmACP_m -0.0
# hdeACP_m -0.0
# ocdcaACP_m -0.0
# ocdcyaACP_m -0.0
# ocdcyaACP_c -5.048709793414476e-29
# ocdycacoa_c -2.1823812598345932e-13
# ocdycacoa_x -2.1823812598345932e-13
# ttc_c 5.098144129078719e-13
# ttc_x -0.0
# hexc_c -0.0
# hexc_x -0.0
# octa_x -0.0
# ttdca_x -0.0
# amp_x -0.0
# hdca_x -0.0
# hdcea_x -0.0
# hdcoa_x -0.0
# nad_x -0.0
# nadh_x -0.0
# dcaACP_m -0.0
# malACP_m -0.0
# ACP_m -0.0
# myrsACP_m -0.0
# tdeACP_m -0.0
# octeACP_m -0.0
# acACP_m -0.0
# ocACP_m -0.0
# ppp9_m -0.0
# pheme_m -0.0
# q6h2_m 2.301784494001798e-13
# fecostest_SC_c -0.0
# fecost_c -0.0
# fecostest_SC_e -0.0
# fecost_e -0.0
# Lfmkynr_c -0.0
# Lkynr_c -0.0
# for_m -3.979039320256561e-13
# frdp_m -0.0
# fadh2_m -0.0
# fad_m -0.0
# 10fthf_m -0.0
# 4fumacac_c -0.0
# acac_c -0.0
# dhap_m 9.094947017729282e-13
# glu5sa_m -0.0
# 1pyr5c_m -0.0
# g6p_r -0.0
# g6p_B_c 0.0
# 1Dgali_c 1.0717352931048178e-13
# gcald_e -3.183231456205249e-12
# gly_m 2.2737367544323206e-13
# alpam_m -0.0
# dhlam_m -0.0
# gdp_n -0.0
# ggdp_c -0.0
# pendp_c -0.0
# ser__L_m 5.684341886080802e-14
# mlthf_m -0.0
# glycogen_v -0.0
# glc__D_v -0.0
# glc__D_e 0.0
# gln__L_n -0.0
# gln__L_v -0.0
# glp_c -0.0
# tglp_c -0.0
# glutrna_m -0.0
# glu__L_v -0.0
# gly_e 1.8189894035458565e-12
# gsn_m -0.0
# gthox_m -0.0
# gthrd_m -0.0
# gua_m -0.0
# hcit_m -0.0
# akg_n 8.526512829121202e-13
# hcit_n 1.1510792319313623e-12
# co2_n 9.094947017729282e-13
# hco3_n -0.0
# hemeO_m -0.0
# hexdp_c -0.0
# hexdp_m -0.0
# hgentis_c -0.0
# 4mlacac_c -0.0
# mev__R_c -0.0
# hmgcoa_c 4.547473508864641e-13
# 2ahhmp_m -0.0
# 2ahhmd_m -0.0
# 1p3h5c_c -0.0
# iamoh_m -0.0
# ibutoh_m -0.0
# icit_x -0.0
# nadp_x -0.0
# nadph_x -0.0
# id3acald_c 5.897504706808832e-13
# ile__L_m -0.0
# iletrna_m -0.0
# ind3ac_c -1.7053025658242404e-13
# ind3eth_c 1.8474111129762605e-13
# ind3eth_e 1.8474111129762605e-13
# ipc126_SC_c -0.0
# mi1p__D_c -0.0
# ipc224_SC_c -0.0
# ipc226_SC_c -0.0
# ptd1ino_SC_c -0.0
# 12dgr_SC_c -0.0
# ipdp_m -0.0
# itacon_m -0.0
# itaccoa_m -0.0
# hLkynr_c -0.0
# leu__L_v -0.0
# lanost_c -0.0
# 44mctr_c -0.0
# 1agpc_SC_c -0.0
# pc_SC_c -1.7053025658242404e-15
# dagpy_SC_c -0.0
# pa_SC_c 1.4210854715202005e-15
# lys__L_m -0.0
# lystrna_m -0.0
# lys__L_v -0.0
# lac__L_m -0.0
# malt_e -0.0
# man_e -0.0
# micit_m -0.0
# succ_m -0.0
# ppcoa_m -0.0
# 2mcit_m -0.0
# mal__L_m 1.1368683772161603e-13
# melt_c -0.0
# sbt__D_c -0.0
# met__L_m 5.755396159656812e-13
# mettrna_m -0.0
# 5pmev_c -0.0
# ptdmeeta_SC_c -0.0
# ptd2meeta_SC_c 1.4119171781555542e-15
# mhpglu_c -0.0
# hpglu_c -0.0
# atp_n -0.0
# mi13456p_n -0.0
# adp_n -0.0
# minohp_n -0.0
# mi1456p_n -0.0
# mi145p_n -0.0
# mi1345p_n -0.0
# mi145p_c -0.0
# minohp_c -0.0
# mip2c126_SC_c -0.0
# man2mi1p__D_c -0.0
# mip2c224_SC_c -0.0
# mip2c326_SC_c -0.0
# cer3_26_c -0.0
# mipc124_SC_c -0.0
# mip2c124_SC_c -0.0
# mipc224_SC_c -0.0
# mipc324_SC_c -1.4210854715202005e-15
# mip2c324_SC_c -0.0
# manmi1p__D_c -0.0
# cer3_24_c -0.0
# mipc226_SC_c -0.0
# ipc324_SC_c -0.0
# nmn_x -0.0
# dnad_n -0.0
# nad_n -0.0
# nac_m -6.821210263296962e-13
# prpp_m -0.0
# nicrnt_m -0.0
# gdp_g -0.0
# gmp_g -0.0
# Nfortyr_c -0.0
# Nbfortyr_c -0.0
# dnad_m -1.5573539413920006e-13
# quln_m -0.0
# 1mncam_c -3.8978344361696937e-13
# acybut_c -0.0
# ibutac_c -1.5631940186722212e-13
# oxag_m -2.2595258997171186e-12
# oxag_c -0.0
# triglyc_SC_c -0.0
# 35cimp_c -0.0
# 35ccmp_c -0.0
# pe_SC_c -0.0
# pe_SC_m -0.0
# pg_SC_m -0.0
# 1p3h5c_m 3.0316490059097606e-13
# 4hglusa_m -0.0
# ptd135bp_SC_c -0.0
# ptd3ino_SC_c -0.0
# ptd134bp_SC_c -0.0
# ptd145bp_SC_c -0.0
# ptd1ino_SC_n -0.0
# ptd4ino_SC_n -0.0
# cdpdag_SC_c -0.0
# g3pc_c 1.5158245029548803e-13
# ocdcya_c 4.5395785895784176e-13
# 5dpmev_c -0.0
# ppmi12346p_c -0.0
# ppmi1346p_c -0.0
# mi13456p_c -0.0
# aproa_c -0.0
# pendp_m -0.0
# pro__L_m -0.0
# ps_SC_g -0.0
# pe_SC_g -0.0
# ps_SC_m -0.0
# ps_SC_v -0.0
# pe_SC_v -0.0
# ps_SC_c 1.7053025658242404e-15
# psph1p_c -0.0
# psph1p_r -0.0
# 2hhxdal_c -0.0
# ddca_x 5.797471435382214e-13
# ttccoa_x -0.0
# stcoa_x -0.0
# ocdca_x 5.623040159858362e-13
# pan4p_m -1.1510792319313623e-12
# dpcoa_m -0.0
# r1p_m -3.410605131648481e-13
# pydx_c -1.9895196601282805e-13
# L2aadp6sa_c -0.0
# saccrp__L_c -0.0
# sbt__L_c -0.0
# srb__L_c -1.0263395072090339e-13
# sph1p_c -0.0
# hxdcal_c -0.0
# sql_r -0.0
# Ssq23epx_r -0.0
# sql_c -0.0
# srb__L_e -1.1368683772161603e-13
# fum_m -0.0
# succoa_m 1.3117712044801848e-13
# fru_e -0.0
# taur_c -0.0
# tchola_c -0.0
# atp_v 0.0
# adp_v -0.0
# tchola_v -0.0
# methf_m -9.094947017729282e-13
# 5fthf_m -0.0
# thfglu_c -0.0
# thmpp_m -0.0
# thr__L_m -0.0
# thrtrna_m -0.0
# thmtp_c -2.8421709430404007e-13
# 4mhetz_c -0.0
# tyr__L_m 0.0
# tyrtrna_m 0.0
# tyr__L_x -0.0
# tyr__L_v 7.958078640513122e-13
# udpgal_g -0.0
# ump_n -0.0
# ura_e -0.0
# dudp_n -0.0
# val__L_m 8.772192012333169e-13
# valtrna_m 0.0
# xylt_c 1.1368683772161603e-13
# xylu__D_c 1.1368683772161603e-13
# zymstest_SC_c -0.0
# mannan_c -0.0
# lpam_c -0.0
# 3mbdhl_c -0.0
# lac6p_c -0.0
# dgal6p_c -0.0
# acnam_e -0.0
# oc2coa_c -0.0
# ala__L_e -0.0
# cdpdag_SA_c -0.0
# pa_SA_c -3.0924190039776702e-15
# pime_c -0.0
# pmcoa_c -0.0
# chol_e -1.0610771520684161e-12
# Cit_Mg_e 0.0
# Cit_Mg_c 0.0
# pg_SA_c -0.0
# clpn_SA_c -0.0
# 12dgr_SA_c -0.0
# ala__D_e -0.0
# 25dhpp_c -0.0
# ncam_e -1.1368683772161603e-13
# salcn_e -0.0
# cdpglyc_c -0.0
# tag6p__D_c -1.1368683772161603e-13
# alpro_c -0.0
# glcn_e -0.0
# hepdp_c -0.0
# urcan_c -0.0
# ibcoa_c 2.7711166694643907e-13
# fa1_c 7.958078640513122e-13
# ivcoa_c -0.0
# fa11_c 3.126388037344441e-13
# fa3_c -3.126388037344441e-13
# 2mbcoa_c -0.0
# fa4_c -0.0
# fa5_c -1.0160761121369433e-12
# fa6_c -1.0160761121369433e-12
# leu__L_e -0.0
# bgly_c -0.0
# bz_c -0.0
# octp_c -0.0
# pala_SA2_c -0.0
# pgly_SA2_c -8.720090374095046e-15
# ps_SA_c -0.0
# pe_SA_c -0.0
# 6pthp_c 1.1013412404281553e-13
# raffin_c -0.0
# Stmyn_c 0.0
# 3AStmyn_c -0.0
# fa12_c -0.0
# gtca3_c -0.0
# decdp_c -0.0
# 3g12dgr_SA2_c -0.0
# dgdcg_SA2_c -0.0
# 4izp_c -0.0
# 2ombz_c -0.0
# 2ommb_c -0.0
# 12dgr_EC_c -0.0
# ...
# xolest183_hs_c -0.0
# Lhcystin_c -0.0
# dsT_antigen_e -0.0
# galam_c -0.0
# s2l2n2m2m_e -0.0
# xol7aone_e 1.6892805237433756e-13
# 7klitchol_e -1.6492422720216626e-13
# CE4968_c -0.0
# actyr_c 1.7053025658242404e-13
# actyr_e 1.7053025658242404e-13
# CE2176_m -0.0
# nacvanala_m 5.432919071888765e-13
# 2hiv_c -0.0
# 2hiv_e 0.0
# 2m3ovac_c -0.0
# 2m3hvac_c -0.0
# tiggly_e -5.337735673514899e-13
# 3ohglutac_m -0.0
# 3ohglutac_c 0.0
# glutacoa_m 1.7053025658242404e-13
# 3hadicoa_x -0.0
# 3hadpac_x -0.0
# 3ohsebcoa_x -0.0
# 3ohsubcoa_x -0.0
# 3ohsubac_x -0.0
# 5ohhexa_c -0.0
# 5ohhexa_e -0.0
# subgly_e -0.0
# 4ohbut_m -0.0
# 4ohbut_c 0.0
# 4ohbut_e 0.0
# 2hydog_c 0.0
# 2hydog_e 0.0
# thexdd_m -0.0
# hexdtr_m -3.6730879775645655e-13
# hexdtr_c -3.6730879775645655e-13
# 5eipenc_m -2.8410006373579734e-13
# 5eipenc_c -2.8410006373579734e-13
# 5eipenc_e 6.040114813539038e-13
# andrstandn_e -0.0
# CE5072_e -0.0
# C03681_e -0.0
# CE2006_e -1.9868128306587176e-12
# CE4890_e -0.0
# C09642_e -0.0
# CE7090_e 3.3575356744455087e-13
# CE1447_e -0.0
# CE6205_e 3.623767952376511e-13
# 1a25dhvitd3_e -0.0
# CE4969_c -0.0
# sucsal_e -0.0
# egme_e -0.0
# 18harachd_c -0.0
# estrone_e 1.9477230286129802e-13
# C05298_e -0.0
# HC02020_c -0.0
# HC02020_e -0.0
# 3ityr__L_e -0.0
# 13_cis_retn_e -0.0
# ppbng_e -0.0
# sphings_e 4.768531248878893e-13
# aact_e 1.1368683772161603e-13
# CE2047_e 0.0
# fdp_e -0.0
# dopa3glcur_c -2.3256860118460734e-13
# dopa3glcur_e 1.866728993604738e-13
# CE5026_e -0.0
# dhcrm_hs_r -1.1191048088221578e-13
# gd1a_hs_e -0.0
# gt1b_hs_e -0.0
# gd2_hs_e -0.0
# sphings_n -0.0
# M00241_e 0.0
# M00510_e -0.0
# M00003_e -0.0
# M00115_e -0.0
# M00117_e -0.0
# M02560_e -0.0
# M02561_e -0.0
# M02909_e 0.0
# M03134_c -0.0
# M02108_c -0.0
# M02107_c -0.0
# M03050_c -0.0
# M00117_c -3.0316490059097606e-13
# HC10784_c -0.0
# M00341_c -0.0
# HC02050_c -0.0
# HC02056_c -0.0
# HC02070_c -0.0
# galgluside_hs_r -0.0
# M02197_c -1.0658141036401503e-13
# acglcgalacglcgal14acglcgalgluside_hs_c -0.0
# M00961_c -0.0
# M00962_c -0.0
# M00958_c 1.1131836193574902e-13
# M00954_c 1.1131836193574902e-13
# M00966_c 3.446132268436486e-13
# M01083_c -0.0
# M01080_c -0.0
# M00746_m -0.0
# M00743_x -0.0
# M02760_c -0.0
# M02761_c -4.032534204385626e-13
# hestratriol_l -0.0
# CE5253_l -0.0
# M00054_c -0.0
# M00873_c -0.0
# M00778_c -0.0
# M00044_c -0.0
# M00802_c -0.0
# M00879_c -0.0
# M00707_c -0.0
# M03018_c -0.0
# M00839_c 3.7989922921906544e-13
# M00871_c -0.0
# M00704_c -0.0
# CE4791_c -0.0
# M03005_c 5.182746397636756e-13
# M00712_c 5.460596513969111e-13
# M01729_c -1.5631940186722204e-13
# M01729_m -0.0
# M02973_c -0.0
# M02102_c -0.0
# M02103_c -0.0
# M02611_c -0.0
# M01776_c -0.0
# M01776_m -0.0
# M00018_m -0.0
# M01775_c -0.0
# M00123_m -0.0
# M00100_c -0.0
# M02051_m -0.0
# M01727_c -0.0
# M01727_m -0.0
# M01726_c -0.0
# M01726_m -0.0
# M00012_m -0.0
# M00343_m -0.0
# M00022_c -0.0
# M00022_m -0.0
# M00023_m -0.0
# stcrn_r -0.0
# tmndnccrn_r -0.0
# M00129_r -0.0
# M00004_r -0.0
# M00003_r -0.0
# M00020_r -0.0
# lneldccoa_r -0.0
# M02613_r -0.0
# M00123_r -0.0
# M01207_r -0.0
# doco13ac_r -0.0
# M00006_r -0.0
# M01582_r -0.0
# M03153_r -0.0
# clpndcoa_r -0.0
# tetpent3coa_r -0.0
# tetpent3_r -0.0
# M00010_r -0.0
# M00343_r -0.0
# M03047_x -0.0
# M00049_x -0.0
# HC01415_x -0.0
# HC01405_x -0.0
# HC01407_x -0.0
# CE2243_m -3.611925573447176e-13
# CE2248_m -0.0
# M00873_m -0.0
# M00054_m -0.0
# M00046_m -0.0
# M00056_m -0.0
# M00792_m -0.0
# CE5144_m -1.1368683772161603e-13
# M00172_m -0.0
# M03014_m -0.0
# M00702_m -0.0
# M00843_m -0.0
# M03016_x -0.0
# CE5156_x 2.392160543725671e-13
# CE5148_x -0.0
# CE5144_x -0.0
# HC10858_x -2.2698942936295126e-13
# M01191_x -0.0
# M00849_x -0.0
# M01141_x -0.0
# CE2437_m 1.1368683772161603e-13
# CE2440_m -1.9184653865522705e-13
# M01501_r -0.0
# M01479_r -0.0
# M01477_r -0.0
# M01495_r -0.0
# M01454_r -0.0
# M01481_r -0.0
# M01491_r -0.0
# M01462_r -0.0
# M01457_r -0.0
# M01509_r -0.0
# M01482_r -0.0
# M01466_r -0.0
# M01490_r -0.0
# M01476_r -0.0
# M01467_r -0.0
# dsT_antigen_c -0.0
# Ntmelys_c -0.0
# sTn_antigen_c -0.0
# ditp_e -0.0
# HC02057_r -0.0
# M02446_c -0.0
# M01966_c -0.0
# M01966_e -0.0
# M02035_c 0.0
# M02035_e 0.0
# n5m2masn_c -0.0
# mem2emgacpail_prot_hs_e -0.0
# dolichol__L_e -0.0
# cdca24g_r -0.0
# cdca3g_e -0.0
# coprost_e 0.0
# dca24g_e -0.0
# dca3g_r 0.0
# dca3s_e -0.0
# hca6g_c -1.8947806286936003e-13
# tdca3s_c -0.0
# tudca3s_c -0.0
# hca6g_e -4.547473508864641e-13
# uchol_e -0.0
# hdca6g_r -0.0
# 12htacr_c -0.0
# 13dmt_r -0.0
# 1331tacr_r -0.0
# 31dmt_r -0.0
# 13dmt_c 0.0
# 14hmdz_e -0.0
# 1513tacr_r -0.0
# 1513tacr_c 0.0
# 1513tacr_e 0.0
# 1hibup__S_e -0.0
# 1hmdgluc_r -0.0
# 2hatvlac_r -0.0
# 2hatvlacgluc_r -0.0
# 2hatvlacgluc_c 0.0
# 2hatvlacgluc_e -0.0
# 2hibupglu__S_c -0.0
# 2hibup__R_c -0.0
# 2hibup__R_e 0.0
# 31dmt_c -0.0
# 31dmt_e 0.0
# 35dsmv_r -0.0
# 3hibup__R_c 0.0
# 3hibup__R_e 0.0
# 3hpvscoa_x -0.0
# 3hpvstetcoa_x -0.0
# 3hpvstet_c -0.0
# 3hpvstet_e 0.0
# 3hpvs_r -0.0
# 5ohfvsglu_r -0.0
# 5ohfvsglu_c 0.0
# 5ohfvsglu_e 0.0
# 5ohfvs_e -0.0
# 6ahglz_c -0.0
# 6ahglz_e 0.0
# 6bhglz_r 0.0
# 6hlvst_c -0.0
# 6hmsmv_c -0.0
# 6ohfvs_e -0.0
# 7ahglz_r 0.0
# 7bhglz_c 0.0
# 7bhglz_e 0.0
# 7bhglz_r 0.0
# 7bhglzglc_r -0.0
# am1csa_r -0.0
# am1a4ncs_c -0.0
# am1alcs_r -0.0
# am1alcs_c 0.0
# am1alcs_e 0.0
# am1c9cs_c -0.0
# am1c9cs_e 0.0
# am1cglc_c -0.0
# am1cglc_e -0.0
# am4n9cs_r -0.0
# atvethgluc_r -0.0
# caribupglu__S_e -0.0
# caribup__R_c -0.0
# caribup__R_e 0.0
# caribup_s_r -0.0
# crvsm1_r -0.0
# crvsm1_e -0.0
# cvm1gluc_r -0.0
# csasulp_c -0.0
# csasulp_e 0.0
# deoxfvs_e -0.0
# dspvs_e -0.0
# epoxtac_c -0.0
# epoxtac_e 0.0
# fvstet_e 0.0
# gtacmp_e -0.0
# oxy1rb_e -0.0
# tlacfvs_e -0.0
# tmdm3_e -0.0
# glc3meacp_c -0.0
# gtacmp_c -0.0
# ibupcoa__R_c -0.0
# 3hibup__R_r -0.0
# ibupcoa__S_c -0.0
# lstn1gluc_r -0.0
# lstnm1_r -0.0
# lstnm2_r 0.0
# lstnm2_c 0.0
# lstnm4_c -0.0
# 6hlvst_r 0.0
# 6melvst_r 0.0
# mdz_c -0.0
# ndersv_c -0.0
# profvscoa_c -0.0
# ptvstm13_r -0.0
# s3meacmp_c -0.0
# tmacmp_c -0.0
# tlacfvs_c -0.0
# tmdm1_c -0.0
# tsacmgluc_r -0.0
# tsacmsul_c -0.0
# ptvstm13_c 0.0
# ptvstm13_e 0.0
# cysacmp_r 0.0
# hexscoa_c -0.0
# tetscoa_c -0.0
# doscoa_c -0.0
# eiscoa_c -0.0
# trdcalcoa_c -0.0
# undcoa_c -0.0
# nndccoa_c -0.0
# hepcoa_c -0.0
# LAM_c -0.0
# hla_c -0.0
# c78mycolatepp_c -0.0
# hipecoa_c -5.643739444037366e-13
# hipohcoa_c -5.281325053945972e-13
# chol4en3one_c -0.0
# hcholc8coa_c -0.0
# ocholc8coa_c -0.0
# hipocoa_c -0.0
# hcholc3coa_c -0.0
# hchol_c -0.0
# cchol_c -0.0
# ochol_c -0.0
# cysOcys__L_c -0.0
# isotbsinol_13R_c -0.0
# ergoth_c 8.242295734817162e-13
# pc_TB_c -0.0
# pc_TB_e 0.0
# 10m3uACP_c -0.0
# 10m3ouACP_c 0.0
# 13mttd2eACP_c -0.0
# 14m3ohdACP_c -0.0
# 16m3opACP_c -0.0
# 16m3hpACP_c -0.0
# 17mthdeACP_c -0.0
# dattoo_c -0.0
# isobutACP_c -0.0
# 3hocACP_c -0.0
# isovACP_c -0.0
# 5m3hhACP_c -0.0
# 3ovegACP_c -0.0
# 4m3hhexACP_c -0.0
# 4m3hpAPC_c -0.0
# 4mtpACP_c -0.0
# 4m3opACP_c -0.0
# 4mpACP_c -0.0
# 5m3hACP_c -0.0
# 6mth2eACP_c -0.0
# 6mhACP_c -0.0
# 8m3oxACP_c -0.0
# 8mdACP_c -0.0
# 8mcACP_c -0.0
# 9mdACP_c -0.0
# alagly_c 3.410605131648481e-13
# alagly_e 0.0
# gly_gln_c -0.0
# arsbet_c 0.0
# arsbet_e 0.0
# carP_c -0.0
# pmlmeACP_c -0.0
# citdapp_c -0.0
# coa2s_c -0.0
# cystine__L_c -0.0
# cystine__L_e -0.0
# 13mtdACP_e 0.0
# 14mhdACP_e 0.0
# 14mpACP_e 0.0
# 16mpACP_e 0.0
# 17mhdACP_e 0.0
# hemoglobin_e -0.0
# stfrnA_e -0.0
# stfrnB_e -0.0
# gly_met_e -0.0
# gly_tyr_e -0.0
# hedACP_e -0.0
# myrsACP_e 0.0
# vegACP_e 0.0
# fapnt_c -0.0
# gly_gln_e -0.0
# gly_leu_e -0.0
# gly_tyr_c -0.0
# gsno_c -0.0
# rgsno_c -0.0
# guatrna_c -0.0
# 3hgmeACP_c -0.0
# xNA_c -4.888534022029489e-13
# 3hpmeACP_c -0.0
# osuc_c 1.1368683772161603e-13
# btbet_c -0.0
# skgmeACP_c -0.0
# pepm_c -0.0
# LTA_ala_w -0.0
# LTAglcnac_w -0.0
# lysglugly_e -0.0
# malttr6p_c -0.0
# updpamaglaa_c -0.0
# PG__L_w -0.0
# pep_met_LRS_c 0.0
# pep_met__L_c -0.0
# prohisglu_e -0.0
# l23uo_c 2.2737367544323206e-13
# serglugly_e -0.0
# stfrnB_c -0.0
# pg_MRSA_ala_c -0.0
# stp_c -0.0
# rbl_B_e 0.0
# rbl_B_c 0.0
# dcaACP_e -0.0
# salc_e -0.0
# chms_c -1.1368683772161603e-13
# chm_c -0.0
# opet_c -0.0
# 14denlipidA_LptA_p -0.0
# 14denlipidA_e -0.0
# lipidA_core_p -0.0
# lipidA_core_LptA_p -0.0
# lipaB_c -0.0
# lipa_LptA_p -0.0
# hlipaB_c -0.0
# o6a3und_p -0.0
# o6a4und_p -0.0
# uaagmda_p -0.0
# 4cnbt_c 0.0
# cm3ac_c -0.0
# nagg_c -0.0
# naggn_c -0.0
# dtdpgal_c -0.0
# hibut_c -0.0
# aibut_c -0.0
# h5p_c -0.0
# cvn_c -0.0
# aeioh_c -0.0
# mot_c -0.0
# gglusem_c 0.0
# smscys_c -0.0
# gln__D_c 0.0
# apn3_c 0.0
# ggapn3_c 0.0
# ppeptido_c 1.1368683772161603e-13
# peptido_c -0.0
# a23op_c 1.4210854715202004e-13
# apocarb_c -0.0
# holocarb_c 0.0
# dhi562_c -0.0
# nhlys_c -0.0
# 3hivcoa_c -1.4210854715202004e-13
# ppad_c -0.0
# nonacp_c -0.0
# undacp_c -0.0
# triacp_c -0.0
# nonaacp_c -0.0
# ag160_c 3.517186542012496e-13
# aglp2_c -2.8421709430404007e-13
# pyrr_c -0.0
# chlac_c -0.0
# Lara14lac_c -0.0
# idt_c -0.0
# e11_p -0.0
# hco3_x -1.1368683772161603e-13
# h2co3_x -0.0
# 12mgdg181_c -0.0
# 12mgdg181_9_c -0.0
# 12mgdg183_9_12_15_c -0.0
# 12mgdg184_6_9_12_15_c -0.0
# dhlprot_c 0.0
# dnacyt_c 0.0
# enz_c 0.0
# enz_S_c -0.0
# hdeceACP_c -0.0
# nicnt_c -0.0
# 2m6solbzq_c -0.0
# 5drib_e -0.0
# udpacmana_c -0.0
# hcn_c -0.0
# aptrc_c 1.7053025658242404e-13
# 78dhptn_c -0.0
# thptn_c -0.0
# ian_c -0.0
# 3haACP_h -0.0
# 4nphp_c -0.0
# gpail_pf_18_0_18_1_c -0.0
# pa_pf_18_1_18_2_c -2.3092638912203256e-13
# 2dmmq4_c -0.0
# mqn4_c -0.0
# dol11manp_c -0.0
# dolichol12_c -0.0
# dpcoa_h -0.0
# hivcoa_c -0.0
# ethamp_g -1.4210854715202004e-12
# mlthf_h -0.0
# dag_pf_16_0_18_2_r 2.4263419556353427e-13
# pe_pf_18_2_18_2_r 2.5579538487363607e-13
# dag_pf_18_2_18_2_r 1.2079226507921703e-13
# lpe_pf_18_1_c 4.321322272536695e-13
# lpe_pf_18_2_c 4.831690603168681e-13
# 5mti_c -0.0
# p4a_c -0.0
# pail45p_pf_18_0_18_1_c 2.4881461413634386e-13
# pail4p_pf_16_0_18_1_c -0.0
# pail4p_pf_18_0_18_1_c 2.2638054904474438e-13
# impyr_c -0.0
# up4u_c -0.0
# dag_pf_16_0_18_2_g 2.918628195812291e-13
# dag_pf_18_0_16_0_c 0.0
# dag_pf_18_0_16_0_g 0.0
# dag_pf_18_0_18_0_g -0.0
# dag_pf_18_0_20_4_c 0.0
# dag_pf_18_0_20_4_g 0.0
# dag_pf_18_1_16_0_c 0.0
# dag_pf_18_1_16_0_g 0.0
# dag_pf_18_1_20_4_c 0.0
# dag_pf_18_1_20_4_g 0.0
# dag_pf_18_2_16_0_c 0.0
# dag_pf_18_2_16_0_g 0.0
# dag_pf_18_2_18_0_c 0.0
# dag_pf_18_2_18_0_g 0.0
# dag_pf_18_2_18_1_c 0.0
# dag_pf_18_2_18_1_g 0.0
# dag_pf_18_2_20_4_c 0.0
# dag_pf_18_2_20_4_g 0.0
# dag_pf_20_4_16_0_c 0.0
# dag_pf_20_4_16_0_g 0.0
# dag_pf_20_4_18_0_c 0.0
# dag_pf_20_4_18_0_g 0.0
# dag_pf_20_4_18_1_c 0.0
# dag_pf_20_4_18_1_g 0.0
# naglc2p_L_dolp11_c 2.1140213762544803e-13
# naglc2p_L_dolp12_c -0.0
# chito2pdol_L_dolp11_c -0.0
# dhcrm_pf_18_0_16_0_c -3.339550858072471e-13
# dhcrm_pf_18_0_24_0_c -2.5579538487363607e-13
# gluside_18_0_18_1_c -0.0
# gluside_18_1_18_0_c -0.0
# pglyc_pf_16_0_18_1_c 2.9309887850104133e-13
# pglyc_pf_16_0_18_1_m -0.0
# crm_pf_18_1_16_0_c -0.0
# gluside_18_1_16_0_c -0.0
# dag_pf_20_4_20_4_g -0.0
# e4p_x -0.0
# 6pgl_x 2.8421709430404007e-13
# ru5p__D_x -0.0
# 2theACP_m -0.0
# 3hhACP_m -0.0
# 2toceACP_m -0.0
# 3hocACP_m -0.0
# 2tdeACP_m -0.0
# 3hdeACP_m -0.0
# 2tddACP_m -0.0
# 3htdACP_m -0.0
# 3hpaACP_m -0.0
# 2tocdACP_m -0.0
# 3hocdacp_m -0.0
# 3hbutcoa_m 3.518878310430972e-13
# 3oxtdACP_m -0.0
# 3oxhdACP_m -0.0
# ddcoa_m -0.0
# ddd2coa_m -0.0
# dccoa_m -0.0
# dcd2coa_m -0.0
# hxd2coa_m -4.666213094929435e-13
# gdpman_c -0.0
# udpg_x -0.0
# udpgal_x -0.0
# mag_LM_c -0.0
# pe_LM_m -0.0
# ps_LM_m -0.0
# CDPdag_LM_c -0.0
# pe_LM_c -0.0
# trpox_c -0.0
# trprd_c -0.0
# trpox_m -0.0
# trprd_m 0.0
# 1ag3p_LM_x -0.0
# 5a4icam_c -0.0
# adn_r -0.0
# dgdp_r -0.0
# dgmp_r -0.0
# 12dgr_LM_r -0.0
# 3mbutdhla_m -0.0
# hibcoa_m -0.0
# d12h5mtp_c -5.684341886080801e-13
# a53oh_c -0.0
# a45imzc_c 1.0231815394945443e-12
# u45imzc_c -0.0
# a4imz_c -0.0
# p1p3b5adtp_c -0.0
# lacgth_c -0.0
# isobutp_c -0.0
# pyr5carb_c -0.0
# m2bcoa_c -0.0
# ival_c -0.0
# ival_e -0.0
# escut_e 0.0
# dtbt_e -0.0
# m4po_e -0.0
# acap_c -0.0
# acb_c -0.0
# acacp_c -0.0
# sracp_c -0.0
# srcoa_c -0.0
# 25dkglcn_e 0.0
# 4hpro_DC_c -0.0
# 4hpro_DC_p 0.0
# 6atha_p -0.0
# 6hnac_p -0.0
# 6hnac_e -0.0
# pdcacoa_c -0.0
# pb2coa_c -0.0
# pbcoa_c -0.0
# cinmcoa_c -0.0
# 6athcoa_c -0.0
# ode2coa_c -0.0
# ptsla2coa_c -0.0
# lnlc2coa_c -0.0
# pald_c -0.0
# alaleu_p -0.0
# alatrp_e -0.0
# prealginate_G_p -0.0
# algac_MG_41_p -1.9173722438818706e-13
# dmanur_p -0.0
# prealg_MG_41_e -0.0
# prealginate_G_e -0.0
# algac_MG_41_e -0.0
# algac_MG_32_e -0.0
# lpp161_p -0.0
# lpp180_p -0.0
# apc_e 0.0
# 3hasp__L_c -0.0
# balabala_e -0.0
# balagly_c -0.0
# balagly_p 0.0
# balagly_e 0.0
# mthd_c -0.0
# tde_2Z_coa_c -2.1316282072803006e-13
# tyr__D_c -0.0
# dgudbutn_e -0.0
# dmgly_p -0.0
# dmso2_c -0.0
# dmso2_p 0.0
# dmso2_e 0.0
# C101PAH_c -0.0
# tyr__D_p -0.0
# tyr__D_e 0.0
# 3hphxacoa_c -0.0
# 3hptslacoa_c -0.0
# 3hhd710coa_c -0.0
# ecto__L_c -0.0
# ecto__L_p -0.0
# ecto__L_e 0.0
# lipidA_kt_c -0.0
# 3h4atb_e 0.0
# R_3h4atba_e -0.0
# R_3hdd6e_e -0.0
# R_3hdda_e 3.410605131648481e-13
# R_3hphxa_e -0.0
# R_3hppta_e -0.0
# R_3hpt_e -0.0
# R_3htd58e_e -0.0
# fe3pyovd_kt_e -0.0
# gudptn_e -0.0
# hpta_e -0.0
# nona_e -0.0
# phehxa_e -0.0
# pheocta_e -0.0
# sheme_e 0.0
# phept_p -0.0
# phehpa_p -0.0
# fbac_kt_c -0.0
# n5horn_c -0.0
# fbac_kt_p 1.4210854715202004e-13
# fe3pyovd_kt_p -0.0
# ggbdapal_c -0.0
# gg15dap_c -0.0
# ggala_B_c -0.0
# bglyg4n_c -0.0
# glyg4n_c -0.0
# dhcrncoa_c -0.0
# glybcoa_c -0.0
# glymet_p -0.0
# 3opoctacoa_c -0.0
# 3ophxacoa_c -0.0
# 3optslacoa_c -0.0
# 3h4atb_p -0.0
# galagalicore_kt_c -0.0
# ggalagalicore_kt_c -0.0
# 5mcsn_p -0.0
# kdolipid4_kt_c -0.0
# o_xyl_c 0.0
# phnac_c -0.0
# phpyr_p -0.0
# pe181e11_p -0.0
# clpn161e9_p -0.0
# clpn181e11_p 2.1515590084195407e-13
# lpspput_p -0.0
# pqqAc_kt_c -0.0
# trnatyrq_c -0.0
# trnaaspq_c -0.0
# R_3hdda_p -1.3263464400855202e-13
# R_3hdd6e_p -0.0
# R_3hdd5ea_p -3.2779704876399293e-13
# R_3hcmrs7e_p 3.0316490059097606e-13
# R_3hhdca_p -0.0
# R_3hpt_p -0.0
# R_3hpdeca_p -0.0
# R_3hphxa_p -0.0
# R_3hpocta_p -0.0
# rhma13unaga_c -0.0
# 3_rhma13unaga_c -0.0
# u3dcga_c -0.0
# u3dcaga_c 2.8421709430404007e-13
# hpac_c 0.0
# n2one_c 0.0
# d4one_c 0.0
# hxbut_c -0.0
# pptrn_c 0.0
# pptrn_p 0.0
# rephac_c -0.0
# und2one_p 0.0
# 6cthydptn_c -0.0
# colipamin_c -0.0
# 23dhb_e 0.0
# 23dhb_p 0.0
# OA3_10__L_p -0.0
# LPS17_ST_e -0.0
# LPS48__L_e -0.0
# OA21__L_p -0.0
# OA2_VL_p -0.0
# LPS55_ST_p -0.0
# LPS16__L_e -0.0
# udcpdpgalnac_a1_3_fucnam_a2_3_neu5acOac_c -0.0
# LPS8__L_e -0.0
# OA3_10_ST_p 1.1368683772161603e-13
# LPS57__L_e -0.0
# LPS3_10_VL_e -0.0
# LPS51__L_e -0.0
# OA57_ST_p -0.0
# LPS50_ST_e -0.0
# LPS50_ST_p -0.0
# LPS57__L_p -0.0
# LPS53__L_e -0.0
# OA50_VL_p -0.0
# udcdpgalnac_b1_3_man_a1_2_man_a1_2_man_p -0.0
# OA4_VL_p -0.0
# LPS2_VL_p -0.0
# OA62_ST_p -0.0
# LPS43_ST_e -0.0
# LPS43_ST_p -0.0
# LPS58_ST_e -0.0
# LPS58_ST_p -0.0
# LPS28ab_VL_e -0.0
# LPS67_p -0.0
# LPS62_VL_e -0.0
# udcdpgalnac_a1_3_b1_3_glc_a1_4_gal_a1_6_gal_c -0.0
# udcdpglcnac_b1_4_glcnac_a1_3_man_b1_4_man_c -0.0
# OA9_VL_p -0.0
# LPS7__L_e -0.0
# OA39_VL_p -0.0
# OA1_3_19__L_p -0.0
# LPS1_3_19_VL_e -0.0
# udcdpgal_a1_3_rmn_a1_4_man_a1_3_abe_p -0.0
# LPS65__L_p -0.0
# LPS28ac_ST_e -0.0
# OA56_ST_p -0.0
# OA39__L_p -0.0
# LPS8_VL_p -0.0
# udcdpglcnac_b1_3_glc_a1_4_fuc_a1_3_acper_c -0.0
# OA13_VL_p -0.0
# OA60_ST_p -0.0
# OA17__L_p -0.0
# udcdpglcnac_a1_3_rmn_b1_4_galnac_a1_4_galf_p -0.0
# LPS13_VL_p -0.0
# OA59_ST_p -0.0
# LPS41_VL_p -0.0
# LPS45_ST_p -0.0
# udcdpglcnac_b1_6_mannac_b1_3_mannac_b1_4_10_c -0.0
# udcdpglcnac_b1_6_mannac_c -0.0
# udcdpglcnac_a1_3_rmn_b1_4_galnac_a1_4_galf_c -0.0
# udcdpglcnac_a1_3_rmn_a1_4_glcnac_b1_3_gal_c 2.0842586915629605e-13
# udcdpglcnac_a1_3_quinac_a1_3_glcnac_b1_6_quinac_c -0.0
# LPS38_VL_p -0.0
# OA38_VL_p -0.0
# LPS55_ST_e -0.0
# OA41_VL_p -0.0
# LPS21__L_p -0.0
# OA40_VL_p -0.0
# udcdpgalnac_b1_3_glc_b1_4_man_b1_2_glcnac_a1_3_galnac_p -1.8677123339979773e-13
# OA4_ST_p -0.0
# LPS9_46_VL_e -0.0
# LPS9_46_VL_p -0.0
# OA55_ST_p -0.0
# OA8_ST_p -0.0
# OA7_VL_p -0.0
# LPS9_46_ST_e -0.0
# OA50_ST_p -0.0
# LPS59_VL_e -0.0
# LPS60_ST_p -0.0
# OA6_14_VL_p -0.0
# LPS65__L_e -0.0
# OA58__L_p -0.0
# OA43_VL_p -0.0
# OA17_VL_p -0.0
# LPS16_VL_e -0.0
# LPS8_VL_e -0.0
# OA42_ST_p -0.0
# udcdpglcnac_b1_3_glc_c -0.0
# LPS57_VL_p -0.0
# udcdpgalnac_b1_3_man_a1_2_man_a1_2_man_c -0.0
# LPS45_ST_e -0.0
# OA66_VL_p -0.0
# LPS55_VL_p -0.0
# LPS53_ST_e -0.0
# LPS53_ST_p -0.0
# OA9_46_VL_p -0.0
# LPS11__L_p -0.0
# LPS16_ST_e -0.0
# udcdpglcnac_a1_3_galnac_b1_3_gal_a1_3_gal_a1_2_fuc_c -0.0
# udcdpglcnac_a1_3_fucnam_a1_3_gal_O_6_ribt_c -0.0
# udcdpgalnac_b1_3_glc_b1_4_man_b1_2_glcnac_a1_3_galnac_c -0.0
# OA9_46_27_VL_p -0.0
# LPS53_VL_e -0.0
# LPS43_VL_p -0.0
# LPS8__L_p -0.0
# LPS44_ST_p -0.0
# LPS2_ST_e -1.7053025658242404e-13
# LPS4_ST_p -0.0
# OA11_VL_p -0.0
# LPS45__L_e -0.0
# OA60__L_p -0.0
# OA63_VL_p -0.0
# OA21_VL_p -0.0
# LPS16_ST_p -0.0
# OA53_ST_p -0.0
# LPS59_VL_p -0.0
# LPS51_VL_p -0.0
# LPS1_3_19_ST_e -0.0
# LPS60_ST_e -0.0
# ['BIOMASS_SA_nuc_only', 'BIOMASS_SA_only_AA', 'ACCOAS', 'FACT', 'AGLPACTF', 'SLGTH', 'AAMYL', 'SUCptspp_1', 'GLYOX_2', 'GLGB', 'ACCDH', 'PS_asn__L_c', 'PEPTIDEsyn', 'RTOT4', 'SPMDAT1_2', 'GLYFEM', 'RTOT3', 'RTOT_3', 'RTOT2', 'RTOT5', 'LCAT23e', 'PGAL', 'RTOT_2', 'GBEZY', 'ASPA1', 'GLCS1', 'GLCS2', 'GBEZ', 'BIOMASS_SA_nuc_only', 'BIOMASS_SA_only_AA', 'ACCOAS', 'FACT', 'AGLPACTF', 'SLGTH', 'AAMYL', 'SUCptspp_1', 'GLYOX_2', 'GLGB', 'ACCDH', 'PS_asn__L_c', 'PEPTIDEsyn', 'RTOT4', 'SPMDAT1_2', 'GLYFEM', 'RTOT3', 'RTOT_3', 'RTOT2', 'RTOT5', 'LCAT23e', 'PGAL', 'RTOT_2', 'GBEZY', 'ASPA1', 'GLCS1', 'GLCS2', 'GBEZ']

# %%
# etabolites containing phosphorus
element_id = 'pi'
pi_met = check_other_elment_production(model,element_id,rxn_grate,check_model,outputfile,unbalance_rxn)
# Out:
# pi_c 1000.0
# 1
# BIOMASS_SA_nuc_only: 3.11 amp_c + 2.2 cmp_c + 0.76 damp_c + 0.53 dcmp_c + 0.6 dgmp_c + 0.73 dtmp_c + 4.01 gmp_c + 2.39 ump_c --> h2o_c 5
# CYTK2_2: atp_c + ctp_c + dcmp_c --> adp_c + cdp_c + dcdp_c 5
# kaasIII: accoa_c + h_c + malacp_c --> aaacp_c + co2_c + coa_c 5
# GLUSfx: akg_c + 2.0 fdxrd_c + gln__L_c + 2.0 h_c --> 2.0 fdxox_c + 2.0 glu__L_c 5
# SULRSI: 3.0 h2o_c + 3.0 nadp_c + slnt_c --> 4.0 h_c + 3.0 nadph_c + sel_c 5
# ALAB: akg_c + ala_B_c --> glu__L_c + octdp_c 5
# DECACP: acACP_c + 4.0 malACP_c + 8.0 nadph_c --> 4.0 ACP_c + 4.0 co2_c + decacp_c + 8.0 nadp_c 5
# OCTEACP: acACP_c + 8.0 malACP_c + 15.0 nadph_c --> 8.0 ACP_c + 8.0 co2_c + 15.0 nadp_c + octeacp_c 5
# PEPHL: pe160_c --> 2agpe160_c + 0.041 bhdodec_c + 0.015 decacid_c + 0.048 dodecacid_c + 0.017 hepadecacid_c + 0.016 hepedecacid_c + 0.281 hexadecacid_c + 0.192 hexedecacid_c + 0.008 octadecacid_c + 0.375 octedecacid_c + 0.003 pendecacid_c + 0.003 tetdecacid_c 5
# PLCG: pg160_c --> 12dgr160_c + glyc3p_c 5
# CAV: 0.163 coa_c + 0.159 fad_c + 0.274 fmn_c + 0.405 mqn8_c + 0.188 nad_c + 0.168 nadp_c + 0.739 pydxn_c + 0.281 thf_c --> cav_c 5
# LIPIDS: 0.157 bhdodec_c + 0.058 decacp_c + 0.185 dodecacp_c + 0.067 hepacp_c + 0.06 hepeacp_c + 1.082 hexacp_c + 0.74 hexeacp_c + 0.032 octacp_c + 1.443 octeacp_c + 0.012 penacp_c + 0.013 tetacp_c --> 3.692 ACP_c + lipids_c 5
# LPS_1: 0.079 bhdodec_c + 0.071 bhtetdec_c + 0.037 dodecacp_c + 0.018 dtdprmn_c + 0.821 glc__bD_c + 0.014 hexacp_c + 0.182 kdo_c + 0.009 octacp_c + 0.008 octeacp_c + 0.255 uacgala_c + 0.365 uacgam_c + 0.656 udpgal_c --> 0.068 ACP_c + 0.068 dtdp_c + lps_c + 1.276 udp_c 5
# DHPS2_2: 4abz_c + 6hmhpt_c --> dhpt_c + ppi_c 5
# PYAS: aspsa_c + pyr_c --> h2o_c + h_c + thdp_c 5
# MCOATA_2: hacp_c + malcoa_c --> coa_c + malacp_c 5
# SFRR: h_c + so3_c --> h2o_c + h2s_c 5
# T2ORX: h_c + nadph_c + t2eacp_c --> hexacp_c + nadp_c 5
# BIOMASS_SA_only_AA: 6.6 ala__L_c + 3.88 arg__L_c + 4.48 asn__L_c + 4.48 asp__L_c + 0.79 cys__L_c + 8.72 gln__L_c + 8.72 glu__L_c + 3.51 gly_c + 1.45 his__L_c + 4.06 ile__L_c + 5.21 leu__L_c + 5.45 lys__L_c + 1.94 met__L_c + 3.33 phe__L_c + 2.12 pro__L_c + 2.6 ser__L_c + 2.54 thr__L_c + 1.27 trp__L_c + 2.3 tyr__L_c + 4.12 val__L_c --> h2o_c 5
# AHSERL3: acser_c + seln_c --> ac_c + scys__L_c 5
# BTMAT1: 2beacp_c + h_c + nadh_c --> butacp_c + nad_c 5
# FPRA: fdxrd_c + h_c + nadp_c --> fdxox_c + nadph_c 5
# GLGE: malt1p_c --> 2.0 14glucan_c + pi_c 5
# BGLK_1: cellb_c + h2o_c --> g6p_c + glc__D_c 5
# FACT: 2obut_c + coa_c --> for_c + 2.0 ppcoa_c 5
# P5CCD: glu__L_c + h_c + nadh_c --> glu5sa_c + nad_c + pi_c 5
# PEPTIDO: ala__D_c + ppeptido_c --> 0.8 ala__D_e + 0.9208 peptido_c 5
# DODECACP: acACP_c + 5.0 malACP_c + 10.0 nadph_c --> 5.0 ACP_c + 5.0 co2_c + dodecacp_c + 10.0 nadp_c 5
# TAM2: dodecacp_c + fadh2_c + o2_c --> ACP_c + bhdodec_c + fad_c 5
# TAM4: fadh2_c + o2_c + tetacp_c --> ACP_c + bhtetdec_c + fad_c 5
# G3POACTF: 0.041 bhdodec_c + 0.015 decacp_c + 0.048 dodecacp_c + glyc3p_c + 0.017 hepacp_c + 0.016 hepeacp_c + 0.281 hexacp_c + 0.192 hexeacp_c + 0.008 octacp_c + 0.375 octeacp_c + 0.003 penacp_c + 0.003 tetacp_c --> 0.958 ACP_c + aglp_c 5
# AGLPACTF: aglp_c + 0.041 bhdodec_c + 0.015 decacp_c + 0.048 dodecacp_c + 0.017 hepacp_c + 0.016 hepeacp_c + 0.281 hexacp_c + 0.192 hexeacp_c + 0.008 octacp_c + 0.375 octeacp_c + 0.003 penacp_c + 0.003 tetacp_c --> 0.958 ACP_c + 0.958 pa160_c 5
# CLS: cdpdhdecg_c + pg160_c --> clpn160_c + cmp_c 5
# PLCE: pe160_c --> 12dgr160_c + ethamp_c 5
# PROTEIN: 0.488 ala__L_c + 0.281 arg__L_c + 0.229 asn__L_c + 0.229 asp__L_c + 40.0 atp_c + 0.087 cys__L_c + 0.25 gln__L_c + 0.25 glu__L_c + 0.582 gly_c + 0.09 his__L_c + 0.276 ile__L_c + 0.428 leu__L_c + 0.326 lys__L_c + 0.146 met__L_c + 0.176 phe__L_c + 0.21 pro__L_c + 0.205 ser__L_c + 0.241 thr__L_c + 0.054 trp__L_c + 0.131 tyr__L_c + 0.402 val__L_c --> 40.0 adp_c + 40.0 pi_c + protein_c 5
# RNA: 2.045 atp_c + 0.686 ctp_c + 0.92 gtp_c + 0.689 utp_c --> 1.25 adp_c + 1.25 pi_c + 3.091 ppi_c + rna_c 5
# PHOSPHOLIPID: 0.12 2agpe160_c + 0.168 clpn160_c + 0.548 pe160_c + 0.302 pg160_c --> phospholipid_c 5
# BIOMASS__3: 46.0 atp_c + 0.03 cav_c + 0.02 lipids_c + 0.005 lps_c + 0.027 peptido_c + 0.04 phospholipid_c + 0.6 protein_c + 0.19 rna_c --> 46.0 adp_c + biomass_c + 46.0 pi_c 5
# SDPDS_2: h2o_c + sl2a6o_c --> 26dap_LL_c + succ_c 5
# BMOC: butacp_c + h_c + malacp_c --> co2_c + hacp_c + o3hacp_c 5
# HMCO: h_c + hexacp_c + malacp_c --> co2_c + hacp_c + ox3xooctacp_c 5
# T2ORO: h_c + nadph_c + toct2enacp_c --> nadp_c + octacp_c 5
# ACCOAS: aacoa_c + coa_c --> accoa_c 5
# SLGTH: gthrd_c + h_c + slnt_c --> dgslnt_c + gthox_c + h2o_c 5
# 2
# PPS5: air_c + amet_c --> 2mahmp_c + co_c + dad_5_c + for_c + met__L_c 5
# SIRA2: 6.0 fdxox_c + 3.0 h2o_c + h2s_c --> 6.0 fdxrd_c + 8.0 h_c + so3_c 5
# 3
# CYOOum: 7.6 h_c + o2_c + 4.0 pcrd_u --> 2.0 h2o_c + 3.6 h_u + 4.0 pcox_u 5
# SO3R_h: 6.0 fdxrd_h + 7.0 h_h + so3_h --> 6.0 fdxox_h + 3.0 h2o_h + h2s_h 5
# GLA: nad_c + udpgalur_c --> 2.0 h_c + nadh_c + udpglcur_c 5
# THMPP: h2o_c + thmmp_c --> ppi_c + thm_c 5
# CPS_1: atp_c + h_c + hco3_c + nh4_c --> adp_c + cbp_c + pi_c 5
# 4
# THPPP: h2o_c + thmpp_c --> ppi_c + thmmp_c 5
# P5CDEG: e4hglu_c + nad_c --> 4hglusa_c + nadh_c 5
# 5
# XYLpts: xyl__D_e --> xu5p__D_c 5
# FRDO3r: adfdRD_c + 2.0 nad_c --> adfdOX_c + 2.0 nadh_c 5
# 6
# GLNSCP: atp_c + gln__L_c + h2o_c + hco3_c --> adp_c + cmylphosph_c + glu__L_c + h_c + pi_c 5
# DHNCM: dhor__S_c + h2o_c --> h_c + ncmylasp_c 5
# PTGFS: prostgh2_c + trdox_c --> prostgf2_c + trdrd_c 5
# 7
# SUCptspp_1: pep_c --> pyr_c + suc6p_c 5
# ARTFR52: hexccoa_c --> 1.625 R5coa_hs_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# RTOT4: R4coa_hs_c --> Rtotalcoa_c 5
# PPS2: air_c + amet_c --> 2mahmp_c + co_c + dad_2_c + for_c + met__L_c 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTFR46: fadh2_m + od2coa_c --> 1.125 R4coa_hs_c + fad_m 5
# RTOT5: R5coa_hs_c --> Rtotalcoa_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# DTBTST: 2.0 amet_c + dtbt_c + s_c --> btn_c + 2.0 dad_5_c + 2.0 met__L_c 5
# 8
# ARTFR45: fadh2_m + nrvnccoa_c --> 1.5 R4coa_hs_c + fad_m 5
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# RTOT_2: R2coa_hs_c + R4coa_hs_c --> 2.0 Rtotal2coa_c 5
# RTOT_3: R1coa_hs_c + R2coa_hs_c --> 2.0 Rtotal3coa_c 5
# NAR_syn_2: fdxo_2_2_c + h2o_c + no2_c --> fdxrd_c + 2.0 h_c + no3_c 5
# ARTFR11: pmtcoa_c --> R1coa_hs_c 5
# ARTFR207: arachcoa_c --> 1.25 R2coa_hs_c 5
# ARTPLM3: Rtotal3coa_c --> pmtcoa_c 5
# CYOR3m: 2.0 ficytcc_c + h_c + mql7_c --> 2.0 focytcc_c + 3.0 h_e + mqn7_c 5
# KGD2: co2_c + 2.0 fdxrd_c + h_c + succoa_c --> akg_c + coa_c + 2.0 fdxox_c 5
# SUCD2: fad_c + 2.0 h_c + mqn7_c + succ_c --> fadh2_c + fum_c + mql7_c 5
# FDR: nadph_c + rdxo_c --> h_c + nadp_c + rdxr_c 5
# FNRR2: fdxrd_c + h_c + nadp_c --> fdxo_2_2_c + nadph_c 5
# 9
# ARTFR209: adrncoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m 5
# ARTPLM1m: Rtotalcoa_m --> pmtcoa_m 5
# RTOT3: R3coa_hs_c --> Rtotalcoa_c 5
# ARTFR207_cho: arachcoa_c + 0.25 coa_m --> 1.25 R2coa_cho_c 5
# RTOT_2_cho: R2coa_cho_c + R4coa_cho_c --> 2.0 Rtotal2coa_c 5
# epo_degradation: 26.0 h2o_c + peptide_c --> ala__L_c + cys__L_c + glu__L_c + 3.0 gly_c + his__L_c + 10.0 leu__L_c + met__L_c + 3.0 pro__L_c + 2.0 ser__L_c + 2.0 trp__L_c + 2.0 val__L_c 5
# GLYTRS_1: atp_c + gly_c + trnagly_c --> amp_c + glytrna_c + h_c + ppi_c 5
# ACCDH: btcoa_c + fad_c --> 3mb2coa_c + fadh2_c 5
# MTHFtURAMT: fadh2_c + mlthf_c + trnauri_c --> fad_c + thf_c + trnarib_c 5
# THDPS_2: h2o_c + succoa_c + thdp_c --> coa_c + sl26da_c 5
# GLYOX_2: h2o_c + lgt__S_c --> gthrd_c + h_c + lac__D_c + mthgxl_c 5
# ARTFR31: stcoa_c --> 1.125 R3coa_hs_c 5
# RTOT2: R2coa_hs_c --> Rtotalcoa_c 5
# ARTFR46_cho: 0.125 coa_m + fadh2_m + od2coa_c --> 1.125 R4coa_cho_c + fad_m 5
# CYSTRS_1: atp_c + cys__L_c + trnacys_c --> amp_c + cystrna_c + h_c + ppi_c 5
# PROTRS_1: atp_c + pro__L_c + trnapro_c --> amp_c + h_c + ppi_c + protrna_c 5
# SERTRS_1: atp_c + ser__L_c + trnaser_c --> amp_c + h_c + ppi_c + sertrna_c 5
# THRTRS_1: atp_c + thr__L_c + trnathr_c --> amp_c + h_c + ppi_c + thrtrna_c 5
# FRNDPR_m: 2.0 fdxrd_m + h_m + nadp_m --> 2.0 fdxox_m + nadph_m 5
# LCAT23e: chsterol_e + pchol_hs_e --> lpchol_hs_e + xolest183_hs_e 5
# NALN6_1: akg_c + nal2a6o_c --> glu__L_c + n6all26d_c 5
# GLCD: glc__D_c + nadp_c --> glcn_c + nadph_c 5
# TRNAUMT: amet_c + trnauri_c --> ahcys_c + h_c + trnarib_c 5
# MRF: fdxrd_c + 3.0 h_c + mlthf_c --> 5mthf_c + fdxo_2_2_c 5
# PEPTIDEsyn: 0.748399 alatrna_c + 0.130805 argtrna_c + 0.272689 asntrna_c + 0.374015 asptrna_c + 0.017197 cystrna_c + 0.200228 glntrna_c + 0.256058 glutrna_c + 1.498961 glytrna_c + 0.067143 histrna_c + 0.087361 iletrna_c + 0.206491 leutrna_c + 0.311404 lystrna_c + 0.104726 mettrna_c + 0.13874 phetrna_c + 0.256971 protrna_c + 0.317225 sertrna_c + 0.349831 thrtrna_c + 0.087887 trptrna_c + 0.040246 tyrtrna_c + 0.284577 valtrna_c --> peptide_c + 0.748399 trnaala_c + 0.130805 trnaarg_c + 0.272689 trnaasn_c + 0.374015 trnaasp_c + 0.017197 trnacys_c + 0.200228 trnagln_c + 0.256058 trnaglu_c + 1.498961 trnagly_c + 0.067143 trnahis_c + 0.087361 trnaile_c + 0.206491 trnaleu_c + 0.311404 trnalys_c + 0.104726 trnamet_c + 0.13874 trnaphe_c + 0.256971 trnapro_c + 0.317225 trnaser_c + 0.349831 trnathr_c + 0.087887 trnatrp_c + 0.040246 trnatyr_c + 0.284577 trnaval_c 5
# 10
# ARTFR212: dcsptn1coa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m 5
# r1135: 4mzym_int2_r + 3.0 h_r + nadp_r --> HC02110_r + nadph_r 5
# r1146: HC02110_r + 2.0 h2o_r --> co2_r + 6.0 h_r + zymst_r 5
# HPOXR: 2.0 h2o2_c --> 2.0 h2o_c + 2.0 o2_c 5
# DGUO: glc__D_c + q8h2_c --> dgo15lac_c + 4.0 h_c + q8_c 5
# 11
# ARTFR211: clpndcoa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m 5
# 12
# ARTFR213: c226coa_c + 3.0 fadh2_m + 3.0 h_m + 3.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 3.0 nadp_m 5
# 13
# ARTFR205: dlnlcgcoa_c + 2.0 fadh2_m + h_m + nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + nadp_m 5
# 14
# ARTFR206: arachdcoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m 5
# 15
# ARTFR208: 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + tmndnccoa_c --> 1.25 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m 5
# 16
# ARTFR210: fadh2_m + h_m + lnlccoa_c + nadph_m --> 1.125 R2coa_hs_c + fad_m + nadp_m 5
# 17
# ARTFR203: 2.0 fadh2_m + h_m + lnlncgcoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m 5
# 18
# ARTFR202: 2.0 fadh2_m + h_m + lnlncacoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m 5
# 19
# ARTFR204: 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + strdnccoa_c --> 1.125 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m 5
# BIOMASS_SA_nuc_only 1
# BIOMASS_SA_nuc_only: 3.11 amp_c + 2.2 cmp_c + 0.76 damp_c + 0.53 dcmp_c + 0.6 dgmp_c + 0.73 dtmp_c + 4.01 gmp_c + 2.39 ump_c --> h2o_c unbalance {'charge': 28.66, 'C': -138.18, 'H': -168.29999999999998, 'N': -56.83, 'O': -110.27000000000001, 'P': -14.33}
# CYTK2_2 2
# CYTK2_2: atp_c + ctp_c + dcmp_c --> adp_c + cdp_c + dcdp_c unbalance {'charge': 1.0, 'O': -3.0, 'P': -1.0}
# kaasIII 3
# GLUSfx 4
# SULRSI 5
# ALAB 6
# ALAB: akg_c + ala_B_c --> glu__L_c + octdp_c unbalance {'charge': -2.0, 'C': 37.0, 'H': 62.0, 'O': 4.0, 'P': 2.0}
# DECACP 7
# OCTEACP 8
# PEPHL 9
# PLCG 10
# CAV 11
# LIPIDS 12
# LPS_1 13
# DHPS2_2 14
# DHPS2_2: 4abz_c + 6hmhpt_c --> dhpt_c + ppi_c unbalance {'charge': -3.0, 'H': -1.0, 'O': 6.0, 'P': 2.0}
# PYAS 15
# MCOATA_2 16
# MCOATA_2: hacp_c + malcoa_c --> coa_c + malacp_c unbalance {'charge': -1.0, 'C': 11.0, 'H': 21.0, 'N': 2.0, 'O': 7.0, 'P': 1.0, 'S': 1.0, 'R': 1.0}
# SFRR 17
# T2ORX 18
# BIOMASS_SA_only_AA 19
# AHSERL3 20
# BTMAT1 21
# FPRA 22
# GLGE 23
# BGLK_1 24
# BGLK_1: cellb_c + h2o_c --> g6p_c + glc__D_c unbalance {'charge': -2.0, 'H': -1.0, 'O': 3.0, 'P': 1.0}
# FACT 25
# FACT: 2obut_c + coa_c --> for_c + 2.0 ppcoa_c unbalance {'charge': -4.0, 'C': 24.0, 'H': 36.0, 'O': 17.0, 'N': 7.0, 'P': 3.0, 'S': 1.0}
# P5CCD 26
# P5CCD: glu__L_c + h_c + nadh_c --> glu5sa_c + nad_c + pi_c unbalance {'charge': -1.0, 'O': 3.0, 'P': 1.0}
# PEPTIDO 27
# DODECACP 28
# DODECACP: acACP_c + 5.0 malACP_c + 10.0 nadph_c --> 5.0 ACP_c + 5.0 co2_c + dodecacp_c + 10.0 nadp_c unbalance {'charge': nan, 'H': -2.0}
# TAM2 29
# TAM4 30
# G3POACTF 31
# AGLPACTF 32
# CLS 33
# PLCE 34
# PROTEIN 35
# RNA 36
# PHOSPHOLIPID 37
# BIOMASS__3 38
# SDPDS_2 39
# BMOC 40
# HMCO 41
# T2ORO 42
# ACCOAS 43
# ACCOAS: aacoa_c + coa_c --> accoa_c unbalance {'charge': 4.0, 'C': -23.0, 'H': -34.0, 'N': -7.0, 'O': -17.0, 'P': -3.0, 'S': -1.0}
# SLGTH 44
# PPS5 45
# PPS5: air_c + amet_c --> 2mahmp_c + co_c + dad_5_c + for_c + met__L_c unbalance {'charge': -3.0, 'H': -2.0, 'O': 3.0, 'P': 1.0}
# SIRA2 46
# CYOOum 47
# SO3R_h 48
# GLA 49
# THMPP 50
# THMPP: h2o_c + thmmp_c --> ppi_c + thm_c unbalance {'charge': -1.0, 'O': 3.0, 'P': 1.0}
# CPS_1 51
# CPS_1: atp_c + h_c + hco3_c + nh4_c --> adp_c + cbp_c + pi_c unbalance {'charge': -4.0, 'H': -3.0, 'O': 3.0, 'P': 1.0}
# THPPP 52
# THPPP: h2o_c + thmpp_c --> ppi_c + thmmp_c unbalance {'charge': -2.0, 'H': -1.0, 'O': 3.0, 'P': 1.0}
# P5CDEG 53
# XYLpts 54
# XYLpts: xyl__D_e --> xu5p__D_c unbalance {'charge': -2.0, 'H': -1.0, 'O': 3.0, 'P': 1.0}
# FRDO3r 55
# GLNSCP 56
# DHNCM 57
# DHNCM: dhor__S_c + h2o_c --> h_c + ncmylasp_c unbalance {'charge': 2.0}
# PTGFS 58
# SUCptspp_1 59
# ARTFR52 60
# ARTPLM1 61
# RTOT4 62
# RTOT4: R4coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# PPS2 63
# PPS2: air_c + amet_c --> 2mahmp_c + co_c + dad_2_c + for_c + met__L_c unbalance {'charge': -3.0, 'H': -2.0, 'O': 3.0, 'P': 1.0}
# ARTCOAL1 64
# ARTFR46 65
# RTOT5 66
# RTOT5: R5coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# FNOR_1 67
# DTBTST 68
# ARTFR45 69
# ARTPLM2 70
# RTOT_2 71
# RTOT_3 72
# NAR_syn_2 73
# ARTFR11 74
# ARTFR207 75
# ARTFR207: arachcoa_c --> 1.25 R2coa_hs_c unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# ARTPLM3 76
# CYOR3m 77
# KGD2 78
# SUCD2 79
# FDR 80
# FNRR2 81
# ARTFR209 82
# ARTFR209: adrncoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# ARTPLM1m 83
# RTOT3 84
# RTOT3: R3coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# ARTFR207_cho 85
# RTOT_2_cho 86
# epo_degradation 87
# GLYTRS_1 88
# ACCDH 89
# MTHFtURAMT 90
# THDPS_2 91
# GLYOX_2 92
# ARTFR31 93
# RTOT2 94
# ARTFR46_cho 95
# CYSTRS_1 96
# PROTRS_1 97
# SERTRS_1 98
# THRTRS_1 99
# FRNDPR_m 100
# LCAT23e 101
# NALN6_1 102
# GLCD 103
# TRNAUMT 104
# MRF 105
# PEPTIDEsyn 106
# ARTFR212 107
# ARTFR212: dcsptn1coa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# r1135 108
# r1146 109
# HPOXR 110
# DGUO 111
# ARTFR211 112
# ARTFR211: clpndcoa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# ARTFR213 113
# ARTFR213: c226coa_c + 3.0 fadh2_m + 3.0 h_m + 3.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 3.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# ARTFR205 114
# ARTFR205: dlnlcgcoa_c + 2.0 fadh2_m + h_m + nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + nadp_m unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# ARTFR206 115
# ARTFR206: arachdcoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# ARTFR208 116
# ARTFR208: 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + tmndnccoa_c --> 1.25 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# ARTFR210 117
# ARTFR210: fadh2_m + h_m + lnlccoa_c + nadph_m --> 1.125 R2coa_hs_c + fad_m + nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}
# ARTFR203 118
# ARTFR203: 2.0 fadh2_m + h_m + lnlncgcoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}
# ARTFR202 119
# ARTFR202: 2.0 fadh2_m + h_m + lnlncacoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}
# ARTFR204 120
# ARTFR204: 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + strdnccoa_c --> 1.125 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}

# %%
# metabolites containing nitrogen
element_id = 'nh4'
nh4_met = check_other_elment_production(model,element_id,rxn_grate,check_model,outputfile,unbalance_rxn)
# Out:
# nh4_c 1000.0
# 1
# HPOXR: 2.0 h2o2_c --> 2.0 h2o_c + 2.0 o2_c 5
# SULR_syn_1: fdxo_2_2_c + h2o_c + h2s_c --> fdxrd_c + h_c + so3_c 5
# BIOMASS_SA_only_AA: 6.6 ala__L_c + 3.88 arg__L_c + 4.48 asn__L_c + 4.48 asp__L_c + 0.79 cys__L_c + 8.72 gln__L_c + 8.72 glu__L_c + 3.51 gly_c + 1.45 his__L_c + 4.06 ile__L_c + 5.21 leu__L_c + 5.45 lys__L_c + 1.94 met__L_c + 3.33 phe__L_c + 2.12 pro__L_c + 2.6 ser__L_c + 2.54 thr__L_c + 1.27 trp__L_c + 2.3 tyr__L_c + 4.12 val__L_c --> h2o_c 5
# PROTEIN: 0.488 ala__L_c + 0.281 arg__L_c + 0.229 asn__L_c + 0.229 asp__L_c + 40.0 atp_c + 0.087 cys__L_c + 0.25 gln__L_c + 0.25 glu__L_c + 0.582 gly_c + 0.09 his__L_c + 0.276 ile__L_c + 0.428 leu__L_c + 0.326 lys__L_c + 0.146 met__L_c + 0.176 phe__L_c + 0.21 pro__L_c + 0.205 ser__L_c + 0.241 thr__L_c + 0.054 trp__L_c + 0.131 tyr__L_c + 0.402 val__L_c --> 40.0 adp_c + 40.0 pi_c + protein_c 5
# 2
# NALN6_1: akg_c + nal2a6o_c --> glu__L_c + n6all26d_c 5
# 3
# NP1_2: nicrns_c + pi_c --> h_c + ncam_c + r1p_c 5
# 4
# THDPS_2: h2o_c + succoa_c + thdp_c --> coa_c + sl26da_c 5
# SDPDS_2: h2o_c + sl2a6o_c --> 26dap_LL_c + succ_c 5
# 5
# BIOMASS_SA_nuc_only: 3.11 amp_c + 2.2 cmp_c + 0.76 damp_c + 0.53 dcmp_c + 0.6 dgmp_c + 0.73 dtmp_c + 4.01 gmp_c + 2.39 ump_c --> h2o_c 5
# SFRR: h_c + so3_c --> h2o_c + h2s_c 5
# SIRA2: 6.0 fdxox_c + 3.0 h2o_c + h2s_c --> 6.0 fdxrd_c + 8.0 h_c + so3_c 5
# SRK: 3php_c + atp_c --> adp_c + h_c + pser__L_c 5
# DNA: 4.4 atp_c + 0.987 datp_c + 0.631 dctp_c + 0.631 dgtp_c + 0.987 dttp_c --> 4.4 adp_c + 4.4 pi_c + 3.237 ppi_c 5
# 6
# HMR_9726: 5fthf_c + glu__L_c --> forglu_c + thf_c 5
# 7
# OXPTNDH_1: nad_c + oxptn_c --> glutar_c + nadh_c 5
# AHSERL3: acser_c + seln_c --> ac_c + scys__L_c 5
# NRRH: h2o_c + nicrns_c --> h_c + ncam_c + rib__D_c 5
# SLGTH: gthrd_c + h_c + slnt_c --> dgslnt_c + gthox_c + h2o_c 5
# 8
# epo_degradation: 26.0 h2o_c + peptide_c --> ala__L_c + cys__L_c + glu__L_c + 3.0 gly_c + his__L_c + 10.0 leu__L_c + met__L_c + 3.0 pro__L_c + 2.0 ser__L_c + 2.0 trp__L_c + 2.0 val__L_c 5
# GLYTRS_1: atp_c + gly_c + trnagly_c --> amp_c + glytrna_c + h_c + ppi_c 5
# GLUSfx: akg_c + 2.0 fdxrd_c + gln__L_c + 2.0 h_c --> 2.0 fdxox_c + 2.0 glu__L_c 5
# ATPB: atp_c --> adp_c + pi_c 5
# OGMG: 4izp_c + 3.0 h2o_c + h_c + 2.0 nad_c --> 4ogm_c + for_c + 2.0 nadh_c + nh4_c 5
# CYSTRS_1: atp_c + cys__L_c + trnacys_c --> amp_c + cystrna_c + h_c + ppi_c 5
# PROTRS_1: atp_c + pro__L_c + trnapro_c --> amp_c + h_c + ppi_c + protrna_c 5
# SERTRS_1: atp_c + ser__L_c + trnaser_c --> amp_c + h_c + ppi_c + sertrna_c 5
# THRTRS_1: atp_c + thr__L_c + trnathr_c --> amp_c + h_c + ppi_c + thrtrna_c 5
# NDH_1_1_um: 2.0 fdxrd_c + 5.0 h_c + pq_um --> 2.0 fdxox_c + 3.0 h_u + pqh2_um 5
# CAOPT: aact_c + o2_c --> h2o2_c + mthgxl_c + nh3_c 5
# ACCOAS: aacoa_c + coa_c --> accoa_c 5
# PEPTIDEsyn: 0.748399 alatrna_c + 0.130805 argtrna_c + 0.272689 asntrna_c + 0.374015 asptrna_c + 0.017197 cystrna_c + 0.200228 glntrna_c + 0.256058 glutrna_c + 1.498961 glytrna_c + 0.067143 histrna_c + 0.087361 iletrna_c + 0.206491 leutrna_c + 0.311404 lystrna_c + 0.104726 mettrna_c + 0.13874 phetrna_c + 0.256971 protrna_c + 0.317225 sertrna_c + 0.349831 thrtrna_c + 0.087887 trptrna_c + 0.040246 tyrtrna_c + 0.284577 valtrna_c --> peptide_c + 0.748399 trnaala_c + 0.130805 trnaarg_c + 0.272689 trnaasn_c + 0.374015 trnaasp_c + 0.017197 trnacys_c + 0.200228 trnagln_c + 0.256058 trnaglu_c + 1.498961 trnagly_c + 0.067143 trnahis_c + 0.087361 trnaile_c + 0.206491 trnaleu_c + 0.311404 trnalys_c + 0.104726 trnamet_c + 0.13874 trnaphe_c + 0.256971 trnapro_c + 0.317225 trnaser_c + 0.349831 trnathr_c + 0.087887 trnatrp_c + 0.040246 trnatyr_c + 0.284577 trnaval_c 5
# 9
# CYOOum: 7.6 h_c + o2_c + 4.0 pcrd_u --> 2.0 h2o_c + 3.6 h_u + 4.0 pcox_u 5
# SO3R_h: 6.0 fdxrd_h + 7.0 h_h + so3_h --> 6.0 fdxox_h + 3.0 h2o_h + h2s_h 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# FACT: 2obut_c + coa_c --> for_c + 2.0 ppcoa_c 5
# 10
# ARTFR52: hexccoa_c --> 1.625 R5coa_hs_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# SPMDAT1_2: accoa_c + sprm_c --> N1aspmd_c + coa_c 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# RTOT5: R5coa_hs_c --> Rtotalcoa_c 5
# HMR_4782: 4hpro_LT_c + h_c + o2_c --> 1p3h5c_c + 2.0 h2o_c 5
# 11
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# RTOT3: R3coa_hs_c --> Rtotalcoa_c 5
# RTOT_2: R2coa_hs_c + R4coa_hs_c --> 2.0 Rtotal2coa_c 5
# RTOT_3: R1coa_hs_c + R2coa_hs_c --> 2.0 Rtotal3coa_c 5
# FAD_8: coa_c + fad_c + nad_c + tdcoa_c --> accoa_c + dodcoa_c + fadh2_c + nadh_c 5
# ARTFR11: pmtcoa_c --> R1coa_hs_c 5
# ARTFR207: arachcoa_c --> 1.25 R2coa_hs_c 5
# ARTFR31: stcoa_c --> 1.125 R3coa_hs_c 5
# ARTFR46: fadh2_m + od2coa_c --> 1.125 R4coa_hs_c + fad_m 5
# PTGFS: prostgh2_c + trdox_c --> prostgf2_c + trdrd_c 5
# FAD_9: coa_c + dodcoa_c + fad_c + nad_c --> accoa_c + decoa_c + fadh2_c + nadh_c 5
# FAD_10: coa_c + decoa_c + fad_c + nad_c --> accoa_c + fadh2_c + nadh_c + occoa_c 5
# HEXR: hexcoa_c + nad_c --> h_c + nadh_c + thex2encoa_c 5
# 12
# SUCptspp_1: pep_c --> pyr_c + suc6p_c 5
# ARTFR45: fadh2_m + nrvnccoa_c --> 1.5 R4coa_hs_c + fad_m 5
# ARTPLM1m: Rtotalcoa_m --> pmtcoa_m 5
# RTOT4: R4coa_hs_c --> Rtotalcoa_c 5
# GLA: nad_c + udpgalur_c --> 2.0 h_c + nadh_c + udpglcur_c 5
# CYOR3m: 2.0 ficytcc_c + h_c + mql7_c --> 2.0 focytcc_c + 3.0 h_e + mqn7_c 5
# FNRR2: fdxrd_c + h_c + nadp_c --> fdxo_2_2_c + nadph_c 5
# SULRR: h_c + nadh_c + so3_c --> h2o_c + h2s_c + nad_c 5
# 13
# GLGE: malt1p_c --> 2.0 14glucan_c + pi_c 5
# MRF: fdxrd_c + 3.0 h_c + mlthf_c --> 5mthf_c + fdxo_2_2_c 5
# 14
# AMYL2: adpglc_c --> 14glucan_c + adp_c + h_c 5
# G3POACTF: 0.041 bhdodec_c + 0.015 decacp_c + 0.048 dodecacp_c + glyc3p_c + 0.017 hepacp_c + 0.016 hepeacp_c + 0.281 hexacp_c + 0.192 hexeacp_c + 0.008 octacp_c + 0.375 octeacp_c + 0.003 penacp_c + 0.003 tetacp_c --> 0.958 ACP_c + aglp_c 5
# AGLPACTF: aglp_c + 0.041 bhdodec_c + 0.015 decacp_c + 0.048 dodecacp_c + 0.017 hepacp_c + 0.016 hepeacp_c + 0.281 hexacp_c + 0.192 hexeacp_c + 0.008 octacp_c + 0.375 octeacp_c + 0.003 penacp_c + 0.003 tetacp_c --> 0.958 ACP_c + 0.958 pa160_c 5
# 15
# AAMYL: 14glucan_c --> malthx_c 4
# ACGAL6PISO: acgal6p_c + h2o_c --> galam6p_c + nh4_c 4
# 16
# ARTFR209: adrncoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m 5
# CY_focytb5_c: ficytb5_c --> focytb5_c 5
# ARTFR207_cho: arachcoa_c + 0.25 coa_m --> 1.25 R2coa_cho_c 5
# RTOT_2_cho: R2coa_cho_c + R4coa_cho_c --> 2.0 Rtotal2coa_c 5
# SULRSI: 3.0 h2o_c + 3.0 nadp_c + slnt_c --> 4.0 h_c + 3.0 nadph_c + sel_c 5
# GLYFEM: glyclt_c + h_c --> ac_c + co2_c + h2o_c + succ_c 5
# GLYOX_2: h2o_c + lgt__S_c --> gthrd_c + h_c + lac__D_c + mthgxl_c 5
# RTOT2: R2coa_hs_c --> Rtotalcoa_c 5
# ARTFR46_cho: 0.125 coa_m + fadh2_m + od2coa_c --> 1.125 R4coa_cho_c + fad_m 5
# CHOLESACATc: Rtotalcoa_c + chsterol_c --> coa_c + xolest2_cho_c 5
# LCAT23e: chsterol_e + pchol_hs_e --> lpchol_hs_e + xolest183_hs_e 5
# KGD2: co2_c + 2.0 fdxrd_c + h_c + succoa_c --> akg_c + coa_c + 2.0 fdxox_c 5
# GLGB: 14glucan_c --> glycogen_c 5
# SUCD2: fad_c + 2.0 h_c + mqn7_c + succ_c --> fadh2_c + fum_c + mql7_c 5
# P5CDEG: e4hglu_c + nad_c --> 4hglusa_c + nadh_c 5
# FDR: nadph_c + rdxo_c --> h_c + nadp_c + rdxr_c 5
# GLCD: glc__D_c + nadp_c --> glcn_c + nadph_c 5
# 17
# CYTK2_2: atp_c + ctp_c + dcmp_c --> adp_c + cdp_c + dcdp_c 5
# ARTFR212: dcsptn1coa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m 5
# r1135: 4mzym_int2_r + 3.0 h_r + nadp_r --> HC02110_r + nadph_r 5
# r1146: HC02110_r + 2.0 h2o_r --> co2_r + 6.0 h_r + zymst_r 5
# ACCDH: btcoa_c + fad_c --> 3mb2coa_c + fadh2_c 5
# FRNDPR_m: 2.0 fdxrd_m + h_m + nadp_m --> 2.0 fdxox_m + nadph_m 5
# 18
# ARTFR211: clpndcoa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m 5
# 19
# ARTFR213: c226coa_c + 3.0 fadh2_m + 3.0 h_m + 3.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 3.0 nadp_m 5
# 20
# ARTCOAL3: Rtotal3_c + coa_c --> Rtotal3coa_c 5
# ARTFR205: dlnlcgcoa_c + 2.0 fadh2_m + h_m + nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + nadp_m 5
# 21
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTFR206: arachdcoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m 5
# 22
# ARTFR208: 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + tmndnccoa_c --> 1.25 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m 5
# 23
# ARTFR210: fadh2_m + h_m + lnlccoa_c + nadph_m --> 1.125 R2coa_hs_c + fad_m + nadp_m 5
# GBEZY: 14glun_c --> glycogen_c 5
# ABAH: 2ommbl_c + amet_c --> ahcys_c + h_c + q8_c 5
# NAR_syn_2: fdxo_2_2_c + h2o_c + no2_c --> fdxrd_c + 2.0 h_c + no3_c 5
# 24
# ARTFR203: 2.0 fadh2_m + h_m + lnlncgcoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m 5
# P5CCD: glu__L_c + h_c + nadh_c --> glu5sa_c + nad_c + pi_c 5
# 25
# ARTFR202: 2.0 fadh2_m + h_m + lnlncacoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m 5
# UNGSA1: tetacp_c + uacgam_c --> ACP_c + u3aga_c 5
# 26
# ARTFR204: 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + strdnccoa_c --> 1.125 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m 5
# HPOXR 1
# SULR_syn_1 2
# BIOMASS_SA_only_AA 3
# BIOMASS_SA_only_AA: 6.6 ala__L_c + 3.88 arg__L_c + 4.48 asn__L_c + 4.48 asp__L_c + 0.79 cys__L_c + 8.72 gln__L_c + 8.72 glu__L_c + 3.51 gly_c + 1.45 his__L_c + 4.06 ile__L_c + 5.21 leu__L_c + 5.45 lys__L_c + 1.94 met__L_c + 3.33 phe__L_c + 2.12 pro__L_c + 2.6 ser__L_c + 2.54 thr__L_c + 1.27 trp__L_c + 2.3 tyr__L_c + 4.12 val__L_c --> h2o_c unbalance {'charge': 3.87, 'C': -396.03000000000003, 'H': -764.4400000000002, 'N': -112.03000000000002, 'O': -201.18, 'S': -2.73}
# PROTEIN 4
# NALN6_1 5
# NALN6_1: akg_c + nal2a6o_c --> glu__L_c + n6all26d_c unbalance {'charge': 2.0, 'H': 8.0, 'O': -2.0, 'N': 2.0}
# NP1_2 6
# NP1_2: nicrns_c + pi_c --> h_c + ncam_c + r1p_c unbalance {'charge': 1.0, 'H': 2.0, 'N': 1.0, 'O': -1.0}
# THDPS_2 7
# THDPS_2: h2o_c + succoa_c + thdp_c --> coa_c + sl26da_c unbalance {'charge': 1.0, 'H': 4.0, 'N': 1.0, 'O': -1.0}
# SDPDS_2 8
# SDPDS_2: h2o_c + sl2a6o_c --> 26dap_LL_c + succ_c unbalance {'charge': 1.0, 'H': 4.0, 'N': 1.0, 'O': -1.0}
# BIOMASS_SA_nuc_only 9
# BIOMASS_SA_nuc_only: 3.11 amp_c + 2.2 cmp_c + 0.76 damp_c + 0.53 dcmp_c + 0.6 dgmp_c + 0.73 dtmp_c + 4.01 gmp_c + 2.39 ump_c --> h2o_c unbalance {'charge': 28.66, 'C': -138.18, 'H': -168.29999999999998, 'N': -56.83, 'O': -110.27000000000001, 'P': -14.33}
# SFRR 10
# SIRA2 11
# SRK 12
# SRK: 3php_c + atp_c --> adp_c + h_c + pser__L_c unbalance {'charge': 3.0, 'H': 5.0, 'O': -4.0, 'P': -1.0, 'N': 1.0}
# DNA 13
# HMR_9726 14
# HMR_9726: 5fthf_c + glu__L_c --> forglu_c + thf_c unbalance {'charge': -1.0, 'N': 1.0, 'O': -1.0}
# OXPTNDH_1 15
# AHSERL3 16
# NRRH 17
# NRRH: h2o_c + nicrns_c --> h_c + ncam_c + rib__D_c unbalance {'charge': 1.0, 'H': 2.0, 'O': -1.0, 'N': 1.0}
# SLGTH 18
# SLGTH: gthrd_c + h_c + slnt_c --> dgslnt_c + gthox_c + h2o_c unbalance {'charge': -2.0, 'C': 30.0, 'H': 45.0, 'N': 9.0, 'O': 16.0, 'S': 3.0}
# epo_degradation 19
# GLYTRS_1 20
# GLUSfx 21
# ATPB 22
# OGMG 23
# CYSTRS_1 24
# PROTRS_1 25
# SERTRS_1 26
# THRTRS_1 27
# NDH_1_1_um 28
# CAOPT 29
# ACCOAS 30
# ACCOAS: aacoa_c + coa_c --> accoa_c unbalance {'charge': 4.0, 'C': -23.0, 'H': -34.0, 'N': -7.0, 'O': -17.0, 'P': -3.0, 'S': -1.0}
# PEPTIDEsyn 31
# PEPTIDEsyn: 0.748399 alatrna_c + 0.130805 argtrna_c + 0.272689 asntrna_c + 0.374015 asptrna_c + 0.017197 cystrna_c + 0.200228 glntrna_c + 0.256058 glutrna_c + 1.498961 glytrna_c + 0.067143 histrna_c + 0.087361 iletrna_c + 0.206491 leutrna_c + 0.311404 lystrna_c + 0.104726 mettrna_c + 0.13874 phetrna_c + 0.256971 protrna_c + 0.317225 sertrna_c + 0.349831 thrtrna_c + 0.087887 trptrna_c + 0.040246 tyrtrna_c + 0.284577 valtrna_c --> peptide_c + 0.748399 trnaala_c + 0.130805 trnaarg_c + 0.272689 trnaasn_c + 0.374015 trnaasp_c + 0.017197 trnacys_c + 0.200228 trnagln_c + 0.256058 trnaglu_c + 1.498961 trnagly_c + 0.067143 trnahis_c + 0.087361 trnaile_c + 0.206491 trnaleu_c + 0.311404 trnalys_c + 0.104726 trnamet_c + 0.13874 trnaphe_c + 0.256971 trnapro_c + 0.317225 trnaser_c + 0.349831 trnathr_c + 0.087887 trnatrp_c + 0.040246 trnatyr_c + 0.284577 trnaval_c unbalance {'charge': -5.56309, 'C': 14.13093, 'H': 18.38021699999999, 'N': 0.8501369999999999, 'O': 10.081791, 'R': -0.27268900000000096, 'P': -0.272689, 'S': -0.121923}
# CYOOum 32
# SO3R_h 33
# FNOR_1 34
# FACT 35
# FACT: 2obut_c + coa_c --> for_c + 2.0 ppcoa_c unbalance {'charge': -4.0, 'C': 24.0, 'H': 36.0, 'O': 17.0, 'N': 7.0, 'P': 3.0, 'S': 1.0}
# ARTFR52 36
# ARTPLM1 37
# SPMDAT1_2 38
# SPMDAT1_2: accoa_c + sprm_c --> N1aspmd_c + coa_c unbalance {'charge': -2.0, 'C': -3.0, 'H': -9.0, 'N': -1.0}
# ARTCOAL1 39
# RTOT5 40
# RTOT5: R5coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# HMR_4782 41
# ARTPLM2 42
# RTOT3 43
# RTOT3: R3coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# RTOT_2 44
# RTOT_3 45
# FAD_8 46
# ARTFR11 47
# ARTFR207 48
# ARTFR207: arachcoa_c --> 1.25 R2coa_hs_c unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# ARTFR31 49
# ARTFR46 50
# PTGFS 51
# FAD_9 52
# FAD_10 53
# HEXR 54
# SUCptspp_1 55
# ARTFR45 56
# ARTPLM1m 57
# RTOT4 58
# RTOT4: R4coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# GLA 59
# CYOR3m 60
# FNRR2 61
# SULRR 62
# GLGE 63
# MRF 64
# AMYL2 65
# G3POACTF 66
# AGLPACTF 67
# AAMYL 68
# ACGAL6PISO 69
# ACGAL6PISO: acgal6p_c + h2o_c --> galam6p_c + nh4_c unbalance {'charge': 1.0, 'C': -2.0, 'N': 1.0, 'O': -2.0}
# ARTFR209 70
# ARTFR209: adrncoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# CY_focytb5_c 71
# ARTFR207_cho 72
# RTOT_2_cho 73
# SULRSI 74
# GLYFEM 75
# GLYOX_2 76
# RTOT2 77
# ARTFR46_cho 78
# CHOLESACATc 79
# LCAT23e 80
# KGD2 81
# GLGB 82
# SUCD2 83
# P5CDEG 84
# FDR 85
# GLCD 86
# CYTK2_2 87
# ARTFR212 88
# ARTFR212: dcsptn1coa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# r1135 89
# r1146 90
# ACCDH 91
# FRNDPR_m 92
# ARTFR211 93
# ARTFR211: clpndcoa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# ARTFR213 94
# ARTFR213: c226coa_c + 3.0 fadh2_m + 3.0 h_m + 3.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 3.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# ARTCOAL3 95
# ARTFR205 96
# ARTFR205: dlnlcgcoa_c + 2.0 fadh2_m + h_m + nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + nadp_m unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# ARTCOAL2 97
# ARTFR206 98
# ARTFR206: arachdcoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# ARTFR208 99
# ARTFR208: 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + tmndnccoa_c --> 1.25 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# ARTFR210 100
# ARTFR210: fadh2_m + h_m + lnlccoa_c + nadph_m --> 1.125 R2coa_hs_c + fad_m + nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}
# GBEZY 101
# ABAH 102
# NAR_syn_2 103
# ARTFR203 104
# ARTFR203: 2.0 fadh2_m + h_m + lnlncgcoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}
# P5CCD 105
# ARTFR202 106
# ARTFR202: 2.0 fadh2_m + h_m + lnlncacoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}
# UNGSA1 107
# ARTFR204 108
# ARTFR204: 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + strdnccoa_c --> 1.125 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}

# %%
# metabolites containing sulfur
element_id = 'so4'
so4_met = check_other_elment_production(model,element_id,rxn_grate,check_model,outputfile,unbalance_rxn)
# Out:
# so4_c 1000.0
# 1
# epo_degradation: 26.0 h2o_c + peptide_c --> ala__L_c + cys__L_c + glu__L_c + 3.0 gly_c + his__L_c + 10.0 leu__L_c + met__L_c + 3.0 pro__L_c + 2.0 ser__L_c + 2.0 trp__L_c + 2.0 val__L_c 5
# HPOXR: 2.0 h2o2_c --> 2.0 h2o_c + 2.0 o2_c 5
# SULR_syn_1: fdxo_2_2_c + h2o_c + h2s_c --> fdxrd_c + h_c + so3_c 5
# BIOMASS_SA_only_AA: 6.6 ala__L_c + 3.88 arg__L_c + 4.48 asn__L_c + 4.48 asp__L_c + 0.79 cys__L_c + 8.72 gln__L_c + 8.72 glu__L_c + 3.51 gly_c + 1.45 his__L_c + 4.06 ile__L_c + 5.21 leu__L_c + 5.45 lys__L_c + 1.94 met__L_c + 3.33 phe__L_c + 2.12 pro__L_c + 2.6 ser__L_c + 2.54 thr__L_c + 1.27 trp__L_c + 2.3 tyr__L_c + 4.12 val__L_c --> h2o_c 5
# AHSERL3: acser_c + seln_c --> ac_c + scys__L_c 5
# SELTOR_c: 6.0 fdxrd_c + 7.0 h_c + slnt_c --> 6.0 fdxox_c + 3.0 h2o_c + seln_c 5
# FPRA: fdxrd_c + h_c + nadp_c --> fdxox_c + nadph_c 5
# SIRA2: 6.0 fdxox_c + 3.0 h2o_c + h2s_c --> 6.0 fdxrd_c + 8.0 h_c + so3_c 5
# P5CCD: glu__L_c + h_c + nadh_c --> glu5sa_c + nad_c + pi_c 5
# PROTEIN: 0.488 ala__L_c + 0.281 arg__L_c + 0.229 asn__L_c + 0.229 asp__L_c + 40.0 atp_c + 0.087 cys__L_c + 0.25 gln__L_c + 0.25 glu__L_c + 0.582 gly_c + 0.09 his__L_c + 0.276 ile__L_c + 0.428 leu__L_c + 0.326 lys__L_c + 0.146 met__L_c + 0.176 phe__L_c + 0.21 pro__L_c + 0.205 ser__L_c + 0.241 thr__L_c + 0.054 trp__L_c + 0.131 tyr__L_c + 0.402 val__L_c --> 40.0 adp_c + 40.0 pi_c + protein_c 5
# ASNS3_1: asp__L_c + atp_c + gln__L_c + nh4_c --> amp_c + asn__L_c + glu__L_c + ppi_c 5
# FNRR2: fdxrd_c + h_c + nadp_c --> fdxo_2_2_c + nadph_c 5
# SLGTH: gthrd_c + h_c + slnt_c --> dgslnt_c + gthox_c + h2o_c 5
# PEPTIDEsyn: 0.748399 alatrna_c + 0.130805 argtrna_c + 0.272689 asntrna_c + 0.374015 asptrna_c + 0.017197 cystrna_c + 0.200228 glntrna_c + 0.256058 glutrna_c + 1.498961 glytrna_c + 0.067143 histrna_c + 0.087361 iletrna_c + 0.206491 leutrna_c + 0.311404 lystrna_c + 0.104726 mettrna_c + 0.13874 phetrna_c + 0.256971 protrna_c + 0.317225 sertrna_c + 0.349831 thrtrna_c + 0.087887 trptrna_c + 0.040246 tyrtrna_c + 0.284577 valtrna_c --> peptide_c + 0.748399 trnaala_c + 0.130805 trnaarg_c + 0.272689 trnaasn_c + 0.374015 trnaasp_c + 0.017197 trnacys_c + 0.200228 trnagln_c + 0.256058 trnaglu_c + 1.498961 trnagly_c + 0.067143 trnahis_c + 0.087361 trnaile_c + 0.206491 trnaleu_c + 0.311404 trnalys_c + 0.104726 trnamet_c + 0.13874 trnaphe_c + 0.256971 trnapro_c + 0.317225 trnaser_c + 0.349831 trnathr_c + 0.087887 trnatrp_c + 0.040246 trnatyr_c + 0.284577 trnaval_c 5
# 2
# SUCptspp_1: pep_c --> pyr_c + suc6p_c 5
# r1383: HC02129_c --> 6.0 glu__L_c + thf_c 5
# ATPB: atp_c --> adp_c + pi_c 5
# GLYFEM: glyclt_c + h_c --> ac_c + co2_c + h2o_c + succ_c 5
# r1382: 6.0 atp_c + 6.0 glu__L_c + 6.0 h2o_c + thf_c --> HC02129_c + 6.0 adp_c + 6.0 pi_c 5
# NALN6_1: akg_c + nal2a6o_c --> glu__L_c + n6all26d_c 5
# ASPA1: Lcyst_c + akg_c --> ac_c + glu__L_c 5
# G3POACTF: 0.041 bhdodec_c + 0.015 decacp_c + 0.048 dodecacp_c + glyc3p_c + 0.017 hepacp_c + 0.016 hepeacp_c + 0.281 hexacp_c + 0.192 hexeacp_c + 0.008 octacp_c + 0.375 octeacp_c + 0.003 penacp_c + 0.003 tetacp_c --> 0.958 ACP_c + aglp_c 5
# AGLPACTF: aglp_c + 0.041 bhdodec_c + 0.015 decacp_c + 0.048 dodecacp_c + 0.017 hepacp_c + 0.016 hepeacp_c + 0.281 hexacp_c + 0.192 hexeacp_c + 0.008 octacp_c + 0.375 octeacp_c + 0.003 penacp_c + 0.003 tetacp_c --> 0.958 ACP_c + 0.958 pa160_c 5
# 3
# PHBS_syn_1: 3hbcoa__R_c --> coa_c + phb_c 5
# OXPTNDH_1: nad_c + oxptn_c --> glutar_c + nadh_c 5
# ACCOAS: aacoa_c + coa_c --> accoa_c 5
# 4
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# FACT: 2obut_c + coa_c --> for_c + 2.0 ppcoa_c 5
# 5
# ARTFR52: hexccoa_c --> 1.625 R5coa_hs_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# RTOT_2: R2coa_hs_c + R4coa_hs_c --> 2.0 Rtotal2coa_c 5
# RTOT_3: R1coa_hs_c + R2coa_hs_c --> 2.0 Rtotal3coa_c 5
# GCLDH: fdxox_m + glyclt_m --> fdxrd_m + glx_m 5
# FAD_8: coa_c + fad_c + nad_c + tdcoa_c --> accoa_c + dodcoa_c + fadh2_c + nadh_c 5
# SULRSI: 3.0 h2o_c + 3.0 nadp_c + slnt_c --> 4.0 h_c + 3.0 nadph_c + sel_c 5
# NAR_syn_2: fdxo_2_2_c + h2o_c + no2_c --> fdxrd_c + 2.0 h_c + no3_c 5
# FRDO3r: adfdRD_c + 2.0 nad_c --> adfdOX_c + 2.0 nadh_c 5
# ARTFR11: pmtcoa_c --> R1coa_hs_c 5
# ARTFR207: arachcoa_c --> 1.25 R2coa_hs_c 5
# ARTFR46: fadh2_m + od2coa_c --> 1.125 R4coa_hs_c + fad_m 5
# RTOT5: R5coa_hs_c --> Rtotalcoa_c 5
# FRNDPR_m: 2.0 fdxrd_m + h_m + nadp_m --> 2.0 fdxox_m + nadph_m 5
# FAD_9: coa_c + dodcoa_c + fad_c + nad_c --> accoa_c + decoa_c + fadh2_c + nadh_c 5
# FAD_10: coa_c + decoa_c + fad_c + nad_c --> accoa_c + fadh2_c + nadh_c + occoa_c 5
# GLGE: malt1p_c --> 2.0 14glucan_c + pi_c 5
# GLCD: glc__D_c + nadp_c --> glcn_c + nadph_c 5
# 6
# BIOMASS_SA_nuc_only: 3.11 amp_c + 2.2 cmp_c + 0.76 damp_c + 0.53 dcmp_c + 0.6 dgmp_c + 0.73 dtmp_c + 4.01 gmp_c + 2.39 ump_c --> h2o_c 5
# ARTFR45: fadh2_m + nrvnccoa_c --> 1.5 R4coa_hs_c + fad_m 5
# ARTPLM1m: Rtotalcoa_m --> pmtcoa_m 5
# RTOT4: R4coa_hs_c --> Rtotalcoa_c 5
# AACPS4_1: ACP_h + atp_h + hdcea_h --> amp_h + h_h + hdeACP_h + ppi_h 5
# ARTFR207_cho: arachcoa_c + 0.25 coa_m --> 1.25 R2coa_cho_c 5
# RTOT_2_cho: R2coa_cho_c + R4coa_cho_c --> 2.0 Rtotal2coa_c 5
# GLUSfx: akg_c + 2.0 fdxrd_c + gln__L_c + 2.0 h_c --> 2.0 fdxox_c + 2.0 glu__L_c 5
# FNOR2_h: 2.0 fdxox_h + nadph_h --> 2.0 fdxrd_h + h_h + nadp_h 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# AMYL2: adpglc_c --> 14glucan_c + adp_c + h_c 5
# GLYOX_2: h2o_c + lgt__S_c --> gthrd_c + h_c + lac__D_c + mthgxl_c 5
# GLA: nad_c + udpgalur_c --> 2.0 h_c + nadh_c + udpglcur_c 5
# ARTFR205: dlnlcgcoa_c + 2.0 fadh2_m + h_m + nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + nadp_m 5
# RTOT2: R2coa_hs_c --> Rtotalcoa_c 5
# ARTFR46_cho: 0.125 coa_m + fadh2_m + od2coa_c --> 1.125 R4coa_cho_c + fad_m 5
# PTGFS: prostgh2_c + trdox_c --> prostgf2_c + trdrd_c 5
# CHOLESACATc_1: Rtotalcoa_c + chsterol_c --> coa_c + xolest2_hs_c 5
# LCAT23e: chsterol_e + pchol_hs_e --> lpchol_hs_e + xolest183_hs_e 5
# HDECH: 1hdecg3p_c + h2o_c --> glyc3p_c + 3.0 h_c + hdcea_c 5
# P5CDEG: e4hglu_c + nad_c --> 4hglusa_c + nadh_c 5
# CERMT: 2ameph_c + crm_cho_c --> cmp_c + crmp_cho_c 5
# FDR: nadph_c + rdxo_c --> h_c + nadp_c + rdxr_c 5
# MRF: fdxrd_c + 3.0 h_c + mlthf_c --> 5mthf_c + fdxo_2_2_c 5
# 7
# CYTK2_2: atp_c + ctp_c + dcmp_c --> adp_c + cdp_c + dcdp_c 5
# ARTFR209: adrncoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m 5
# RTOT3: R3coa_hs_c --> Rtotalcoa_c 5
# CY_focytb5_c: ficytb5_c --> focytb5_c 5
# SO3R_h: 6.0 fdxrd_h + 7.0 h_h + so3_h --> 6.0 fdxox_h + 3.0 h2o_h + h2s_h 5
# r1135: 4mzym_int2_r + 3.0 h_r + nadp_r --> HC02110_r + nadph_r 5
# r1146: HC02110_r + 2.0 h2o_r --> co2_r + 6.0 h_r + zymst_r 5
# SFRR: h_c + so3_c --> h2o_c + h2s_c 5
# ARTFR31: stcoa_c --> 1.125 R3coa_hs_c 5
# SRK: 3php_c + atp_c --> adp_c + h_c + pser__L_c 5
# 8
# ARTFR212: dcsptn1coa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m 5
# 9
# ARTFR211: clpndcoa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m 5
# 10
# ARTFR213: c226coa_c + 3.0 fadh2_m + 3.0 h_m + 3.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 3.0 nadp_m 5
# 11
# ARTFR206: arachdcoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m 5
# 12
# ARTFR208: 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + tmndnccoa_c --> 1.25 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m 5
# 13
# ARTFR210: fadh2_m + h_m + lnlccoa_c + nadph_m --> 1.125 R2coa_hs_c + fad_m + nadp_m 5
# 14
# ARTFR203: 2.0 fadh2_m + h_m + lnlncgcoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m 5
# 15
# ARTFR202: 2.0 fadh2_m + h_m + lnlncacoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m 5
# 16
# ARTFR204: 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + strdnccoa_c --> 1.125 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m 5
# epo_degradation 1
# HPOXR 2
# SULR_syn_1 3
# BIOMASS_SA_only_AA 4
# BIOMASS_SA_only_AA: 6.6 ala__L_c + 3.88 arg__L_c + 4.48 asn__L_c + 4.48 asp__L_c + 0.79 cys__L_c + 8.72 gln__L_c + 8.72 glu__L_c + 3.51 gly_c + 1.45 his__L_c + 4.06 ile__L_c + 5.21 leu__L_c + 5.45 lys__L_c + 1.94 met__L_c + 3.33 phe__L_c + 2.12 pro__L_c + 2.6 ser__L_c + 2.54 thr__L_c + 1.27 trp__L_c + 2.3 tyr__L_c + 4.12 val__L_c --> h2o_c unbalance {'charge': 3.87, 'C': -396.03000000000003, 'H': -764.4400000000002, 'N': -112.03000000000002, 'O': -201.18, 'S': -2.73}
# AHSERL3 5
# AHSERL3: acser_c + seln_c --> ac_c + scys__L_c unbalance {'charge': -1.0, 'H': -1.0, 'O': 3.0, 'S': 2.0, 'Se': -1.0}
# SELTOR_c 6
# FPRA 7
# SIRA2 8
# P5CCD 9
# PROTEIN 10
# ASNS3_1 11
# FNRR2 12
# SLGTH 13
# PEPTIDEsyn 14
# PEPTIDEsyn: 0.748399 alatrna_c + 0.130805 argtrna_c + 0.272689 asntrna_c + 0.374015 asptrna_c + 0.017197 cystrna_c + 0.200228 glntrna_c + 0.256058 glutrna_c + 1.498961 glytrna_c + 0.067143 histrna_c + 0.087361 iletrna_c + 0.206491 leutrna_c + 0.311404 lystrna_c + 0.104726 mettrna_c + 0.13874 phetrna_c + 0.256971 protrna_c + 0.317225 sertrna_c + 0.349831 thrtrna_c + 0.087887 trptrna_c + 0.040246 tyrtrna_c + 0.284577 valtrna_c --> peptide_c + 0.748399 trnaala_c + 0.130805 trnaarg_c + 0.272689 trnaasn_c + 0.374015 trnaasp_c + 0.017197 trnacys_c + 0.200228 trnagln_c + 0.256058 trnaglu_c + 1.498961 trnagly_c + 0.067143 trnahis_c + 0.087361 trnaile_c + 0.206491 trnaleu_c + 0.311404 trnalys_c + 0.104726 trnamet_c + 0.13874 trnaphe_c + 0.256971 trnapro_c + 0.317225 trnaser_c + 0.349831 trnathr_c + 0.087887 trnatrp_c + 0.040246 trnatyr_c + 0.284577 trnaval_c unbalance {'charge': -5.56309, 'C': 14.13093, 'H': 18.38021699999999, 'N': 0.8501369999999999, 'O': 10.081791, 'R': -0.27268900000000096, 'P': -0.272689, 'S': -0.121923}
# SUCptspp_1 15
# r1383 16
# ATPB 17
# GLYFEM 18
# r1382 19
# NALN6_1 20
# ASPA1 21
# ASPA1: Lcyst_c + akg_c --> ac_c + glu__L_c unbalance {'charge': 1.0, 'C': -1.0, 'H': 1.0, 'O': -4.0, 'S': -1.0}
# G3POACTF 22
# AGLPACTF 23
# PHBS_syn_1 24
# OXPTNDH_1 25
# ACCOAS 26
# ACCOAS: aacoa_c + coa_c --> accoa_c unbalance {'charge': 4.0, 'C': -23.0, 'H': -34.0, 'N': -7.0, 'O': -17.0, 'P': -3.0, 'S': -1.0}
# ARTCOAL1 27
# FACT 28
# FACT: 2obut_c + coa_c --> for_c + 2.0 ppcoa_c unbalance {'charge': -4.0, 'C': 24.0, 'H': 36.0, 'O': 17.0, 'N': 7.0, 'P': 3.0, 'S': 1.0}
# ARTFR52 29
# ARTPLM1 30
# ARTPLM2 31
# RTOT_2 32
# RTOT_3 33
# GCLDH 34
# FAD_8 35
# SULRSI 36
# NAR_syn_2 37
# FRDO3r 38
# ARTFR11 39
# ARTFR207 40
# ARTFR207: arachcoa_c --> 1.25 R2coa_hs_c unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# ARTFR46 41
# RTOT5 42
# RTOT5: R5coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# FRNDPR_m 43
# FAD_9 44
# FAD_10 45
# GLGE 46
# GLCD 47
# BIOMASS_SA_nuc_only 48
# ARTFR45 49
# ARTPLM1m 50
# RTOT4 51
# RTOT4: R4coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# AACPS4_1 52
# ARTFR207_cho 53
# RTOT_2_cho 54
# GLUSfx 55
# FNOR2_h 56
# CHOLESTle_1 57
# AMYL2 58
# GLYOX_2 59
# GLA 60
# ARTFR205 61
# ARTFR205: dlnlcgcoa_c + 2.0 fadh2_m + h_m + nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + nadp_m unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# RTOT2 62
# ARTFR46_cho 63
# PTGFS 64
# CHOLESACATc_1 65
# LCAT23e 66
# HDECH 67
# P5CDEG 68
# CERMT 69
# FDR 70
# MRF 71
# CYTK2_2 72
# ARTFR209 73
# ARTFR209: adrncoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# RTOT3 74
# RTOT3: R3coa_hs_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}
# CY_focytb5_c 75
# SO3R_h 76
# r1135 77
# r1146 78
# SFRR 79
# ARTFR31 80
# SRK 81
# ARTFR212 82
# ARTFR212: dcsptn1coa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# ARTFR211 83
# ARTFR211: clpndcoa_c + 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# ARTFR213 84
# ARTFR213: c226coa_c + 3.0 fadh2_m + 3.0 h_m + 3.0 nadph_m --> 1.375 R2coa_hs_c + 3.0 fad_m + 3.0 nadp_m unbalance {'charge': -1.5, 'X': 1.375, 'C': -12.75, 'O': 6.375, 'H': -31.375, 'N': 2.625, 'P': 1.125, 'S': 0.375}
# ARTFR206 85
# ARTFR206: arachdcoa_c + 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m --> 1.25 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# ARTFR208 86
# ARTFR208: 3.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + tmndnccoa_c --> 1.25 R2coa_hs_c + 3.0 fad_m + 2.0 nadp_m unbalance {'charge': -1.0, 'X': 1.25, 'C': -13.5, 'O': 4.25, 'H': -31.25, 'N': 1.75, 'P': 0.75, 'S': 0.25}
# ARTFR210 87
# ARTFR210: fadh2_m + h_m + lnlccoa_c + nadph_m --> 1.125 R2coa_hs_c + fad_m + nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}
# ARTFR203 88
# ARTFR203: 2.0 fadh2_m + h_m + lnlncgcoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}
# ARTFR202 89
# ARTFR202: 2.0 fadh2_m + h_m + lnlncacoa_c + nadph_m --> 1.125 R2coa_hs_c + 2.0 fad_m + nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}
# ARTFR204 90
# ARTFR204: 2.0 fadh2_m + 2.0 h_m + 2.0 nadph_m + strdnccoa_c --> 1.125 R2coa_hs_c + 2.0 fad_m + 2.0 nadp_m unbalance {'charge': -0.5, 'X': 1.125, 'C': -14.25, 'O': 2.125, 'H': -31.125, 'N': 0.875, 'P': 0.375, 'S': 0.125}

# %%
# metabolites containing oxygen
element_id = 'o2'
o2_met = check_other_elment_production(model,element_id,rxn_grate,check_model,outputfile,unbalance_rxn)
model.reactions.get_by_id('EX_o2_e').bounds = (-1000,1000)
# Out:
# o2_c 666.6666666666665
# 1
# r1383: HC02129_c --> 6.0 glu__L_c + thf_c 5
# SULRSI: 3.0 h2o_c + 3.0 nadp_c + slnt_c --> 4.0 h_c + 3.0 nadph_c + sel_c 5
# HPOXR: 2.0 h2o2_c --> 2.0 h2o_c + 2.0 o2_c 5
# GLYOX_2: h2o_c + lgt__S_c --> gthrd_c + h_c + lac__D_c + mthgxl_c 5
# r1382: 6.0 atp_c + 6.0 glu__L_c + 6.0 h2o_c + thf_c --> HC02129_c + 6.0 adp_c + 6.0 pi_c 5
# GLGE: malt1p_c --> 2.0 14glucan_c + pi_c 5
# G3POACTF: 0.041 bhdodec_c + 0.015 decacp_c + 0.048 dodecacp_c + glyc3p_c + 0.017 hepacp_c + 0.016 hepeacp_c + 0.281 hexacp_c + 0.192 hexeacp_c + 0.008 octacp_c + 0.375 octeacp_c + 0.003 penacp_c + 0.003 tetacp_c --> 0.958 ACP_c + aglp_c 5
# AGLPACTF: aglp_c + 0.041 bhdodec_c + 0.015 decacp_c + 0.048 dodecacp_c + 0.017 hepacp_c + 0.016 hepeacp_c + 0.281 hexacp_c + 0.192 hexeacp_c + 0.008 octacp_c + 0.375 octeacp_c + 0.003 penacp_c + 0.003 tetacp_c --> 0.958 ACP_c + 0.958 pa160_c 5
# CPS_1: atp_c + h_c + hco3_c + nh4_c --> adp_c + cbp_c + pi_c 5
# r1383 1
# SULRSI 2
# HPOXR 3
# HPOXR: 2.0 h2o2_c --> 2.0 h2o_c + 2.0 o2_c unbalance {'O': 2.0}
# GLYOX_2 4
# r1382 5
# GLGE 6
# G3POACTF 7
# AGLPACTF 8
# CPS_1 9

# %%
# all reactions for the infinite generation of metabolites
met_net_generation = list(set(c_met + pi_met + nh4_met + so4_met + o2_met))
cor_unri,cor_unrr,cor_balri,cor_balrr,cor_type,del_ri,del_rr,del_type = modify_delete_rxn(model,met_net_generation,balance_rxn)
# Out:
# 64
# NALN6_1: akg_c + nal2a6o_c --> glu__L_c + n6all26d_c ADAPAT: glu__L_c + nal2a6o_c <=> akg_c + n6all26d_c 1
# ACCOAS: aacoa_c + coa_c <=> accoa_c ACACT1r: 2.0 accoa_c <=> aacoa_c + coa_c 1
# FACT: 2obut_c + coa_c <=> for_c + 2.0 ppcoa_c OBTFL: 2obut_c + coa_c --> for_c + ppcoa_c 1
# CPS_1: atp_c + h_c + hco3_c + nh4_c --> adp_c + cbp_c + pi_c CBPSam_1: 2.0 atp_c + hco3_c + nh4_c --> 2.0 adp_c + cbp_c + 2.0 h_c + pi_c 1
# HPOXR: 2.0 h2o2_c --> 2.0 h2o_c + 2.0 o2_c CAT: 2.0 h2o2_c --> 2.0 h2o_c + o2_c 1
# SLGTH: gthrd_c + h_c + slnt_c --> dgslnt_c + gthox_c + h2o_c SELGTHR: 4.0 gthrd_c + 2.0 h_c + slnt_c --> dgslnt_c + gthox_c + 3.0 h2o_c 1

# %% [markdown]
# ## 2.2 infinite generation of reducing equivalents

# %%
# NADH

add_rxn(model,'ADD_nadh_c','nadh_c --> nad_c + h_c')
rxn_grate['ADD_nadh_c'] = 0

objective_reaction = 'ADD_nadh_c'
model.objective='ADD_nadh_c'
nadh_flux = model.optimize().fluxes['ADD_nadh_c']

if nadh_flux > 1e-6:
    objective_reaction = 'ADD_nadh_c'
    constraint_value = 1e-6
    grate_delete_rxn = find_infinite_rxn(model,objective_reaction,constraint_value,rxn_grate)
    outputfile = 'results/quality_control/nadh/'
    nadh_end_rxn = locating_rxn(model,check_model,objective_reaction,constraint_value,grate_delete_rxn,outputfile,unbalance_rxn)
else:
    pass

rxn = model.reactions.get_by_id('ADD_nadh_c')
model.remove_reactions([rxn])
# Out:
# 1
# OXPTNDH_1: nad_c + oxptn_c --> glutar_c + nadh_c 5
# FPRA: fdxrd_c + h_c + nadp_c --> fdxox_c + nadph_c 5
# P5CDEG: e4hglu_c + nad_c --> 4hglusa_c + nadh_c 5
# 2
# CY_focytb5_c: ficytb5_c --> focytb5_c 5
# FDR: nadph_c + rdxo_c --> h_c + nadp_c + rdxr_c 5
# 3
# SULR_syn_1: fdxo_2_2_c + h2o_c + h2s_c --> fdxrd_c + h_c + so3_c 5
# SFRR: h_c + so3_c --> h2o_c + h2s_c 5
# FNRR2: fdxrd_c + h_c + nadp_c --> fdxo_2_2_c + nadph_c 5
# 4
# PTGFS: prostgh2_c + trdox_c --> prostgf2_c + trdrd_c 5
# 5
# FRDO: fdxrd_c + nadp_c --> fdxox_c + h_c + nadph_c 4
# HYDA: 2.0 fdxrd_c --> 2.0 fdxox_c + h2_c + 2.0 h_c 4
# GULNLR: guln__L_c + 2.0 nad_c --> fruur_c + 2.0 nadh_c 4
# 6
# RE3477C: h2o_r + txa2_r --> CE1447_c + 2.0 h_c 5
# 7
# GLA: nad_c + udpgalur_c --> 2.0 h_c + nadh_c + udpglcur_c 5
# 8
# SULRSI: 3.0 h2o_c + 3.0 nadp_c + slnt_c --> 4.0 h_c + 3.0 nadph_c + sel_c 5
# ATPB: atp_c --> adp_c + pi_c 5
# MECDPDH4E: 2mecdp_c + fdxrd_c + h_c --> fdxo_2_2_c + h2mb4p_c + h2o_c 5
# SUCD2: fad_c + 2.0 h_c + mqn7_c + succ_c --> fadh2_c + fum_c + mql7_c 5
# MRF: fdxrd_c + 3.0 h_c + mlthf_c --> 5mthf_c + fdxo_2_2_c 5
# 9
# AHMMPS: air_c + 2.0 h_c --> 4ahmmp_c + gcald_c + pi_c 5
# SULRR2: h_c + nadph_c + so3_c --> h2o_c + h2s_c + nadp_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# SIRA2: 6.0 fdxox_c + 3.0 h2o_c + h2s_c --> 6.0 fdxrd_c + 8.0 h_c + so3_c 5
# 10
# BTSr: dtbt_c + s_c --> btn_c + 2.0 h_c 4
# 11
# ABAH: 2ommbl_c + amet_c --> ahcys_c + h_c + q8_c 5
# 12
# UNK2_cho: 2kmb_c + gln__L_c + 2.0 h_c --> glu__L_c + met__L_c 4
# 13
# BTS2: cys__L_c + dtbt_c --> ala__L_c + btn_c + 2.0 h_c 4
# UNK2: 2kmb_c + gln__L_c + h_c --> glu__L_c + met__L_c 4
# 14
# SO3R_h: 6.0 fdxrd_h + 7.0 h_h + so3_h --> 6.0 fdxox_h + 3.0 h2o_h + h2s_h 5
# FNOR2_h: 2.0 fdxox_h + nadph_h --> 2.0 fdxrd_h + h_h + nadp_h 5
# r0698: dcholcoa_x + 4.0 h_x + ppcoa_x --> coa_x + dhcholestancoa_x + h2o_x 5
# SULRR: h_c + nadh_c + so3_c --> h2o_c + h2s_c + nad_c 5
# 15
# HMR_2611: M00129_c + crn_c + 2.0 h_c --> coa_c + ttdcrn_c 5
# FAD_9: coa_c + dodcoa_c + fad_c + nad_c --> accoa_c + decoa_c + fadh2_c + nadh_c 5
# FAD_10: coa_c + decoa_c + fad_c + nad_c --> accoa_c + fadh2_c + nadh_c + occoa_c 5
# 16
# ACOAD23f: fad_c + hdcoa_c --> fadh2_c + hd2coa_c 5
# 17
# PYAS: aspsa_c + pyr_c --> h2o_c + h_c + thdp_c 5
# HDECH: 1hdecg3p_c + h2o_c --> glyc3p_c + 3.0 h_c + hdcea_c 5
# 18
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# ARTFR13_cho: tdcoa_c --> 0.875 R1coa_cho_c + 0.125 coa_m 5
# ACCDH: btcoa_c + fad_c --> b2coa_c + fadh2_c 5
# OGMG: 4izp_c + 3.0 h2o_c + h_c + 2.0 nad_c --> 4ogm_c + for_c + 2.0 nadh_c + nh4_c 5
# RTOT1_cho: R1coa_cho_c --> Rtotalcoa_c 5
# OXPTNDH_1 1
# FPRA 2
# FPRA: fdxrd_c + h_c + nadp_c --> fdxox_c + nadph_c unbalance {'charge': -1.0, 'R': 1.0, 'Fe': -8.0, 'S': -8.0, 'X': -1.0, 'H': -2.0}
# P5CDEG 3
# P5CDEG: e4hglu_c + nad_c --> 4hglusa_c + nadh_c unbalance {'H': 2.0, 'O': -1.0}
# CY_focytb5_c 4
# CY_focytb5_c: ficytb5_c --> focytb5_c unbalance {'charge': -1.0}
# FDR 5
# FDR: nadph_c + rdxo_c --> h_c + nadp_c + rdxr_c unbalance {'charge': 1.0}
# SULR_syn_1 6
# SFRR 7
# SFRR: h_c + so3_c --> h2o_c + h2s_c unbalance {'charge': 1.0, 'H': 3.0, 'O': -2.0}
# FNRR2 8
# FNRR2: fdxrd_c + h_c + nadp_c --> fdxo_2_2_c + nadph_c unbalance {'charge': -4.0, 'Fe': -6.0, 'S': -6.0, 'H': -2.0}
# PTGFS 9
# PTGFS: prostgh2_c + trdox_c --> prostgf2_c + trdrd_c unbalance {'H': 4.0}
# FRDO 10
# FRDO: fdxrd_c + nadp_c --> fdxox_c + h_c + nadph_c unbalance {'charge': 1.0, 'R': 1.0, 'Fe': -8.0, 'S': -8.0, 'X': -1.0}
# HYDA 11
# GULNLR 12
# GULNLR: guln__L_c + 2.0 nad_c --> fruur_c + 2.0 nadh_c unbalance {'charge': -2.0}
# RE3477C 13
# RE3477C: h2o_r + txa2_r --> CE1447_c + 2.0 h_c unbalance {'charge': 2.0}
# GLA 14
# GLA: nad_c + udpgalur_c --> 2.0 h_c + nadh_c + udpglcur_c unbalance {'charge': -2.0}
# SULRSI 15
# SULRSI: 3.0 h2o_c + 3.0 nadp_c + slnt_c --> 4.0 h_c + 3.0 nadph_c + sel_c unbalance {'charge': 1.0, 'H': 1.0, 'O': -2.0}
# ATPB 16
# MECDPDH4E 17
# MECDPDH4E: 2mecdp_c + fdxrd_c + h_c --> fdxo_2_2_c + h2mb4p_c + h2o_c unbalance {'charge': -4.0, 'H': -2.0, 'Fe': -6.0, 'S': -6.0}
# SUCD2 18
# SUCD2: fad_c + 2.0 h_c + mqn7_c + succ_c --> fadh2_c + fum_c + mql7_c unbalance {'charge': -2.0}
# MRF 19
# MRF: fdxrd_c + 3.0 h_c + mlthf_c --> 5mthf_c + fdxo_2_2_c unbalance {'charge': -4.0, 'H': -2.0, 'Fe': -6.0, 'S': -6.0}
# AHMMPS 20
# SULRR2 21
# FNOR_1 22
# SIRA2 23
# SIRA2: 6.0 fdxox_c + 3.0 h2o_c + h2s_c --> 6.0 fdxrd_c + 8.0 h_c + so3_c unbalance {'R': -6.0, 'Fe': 48.0, 'S': 48.0, 'X': 6.0, 'H': 12.0}
# BTSr 24
# BTSr: dtbt_c + s_c --> btn_c + 2.0 h_c unbalance {'charge': 2.0}
# ABAH 25
# ABAH: 2ommbl_c + amet_c --> ahcys_c + h_c + q8_c unbalance {'H': -2.0, 'O': 1.0}
# UNK2_cho 26
# UNK2_cho: 2kmb_c + gln__L_c + 2.0 h_c --> glu__L_c + met__L_c unbalance {'charge': -2.0}
# BTS2 27
# BTS2: cys__L_c + dtbt_c --> ala__L_c + btn_c + 2.0 h_c unbalance {'charge': 2.0}
# UNK2 28
# UNK2: 2kmb_c + gln__L_c + h_c --> glu__L_c + met__L_c unbalance {'charge': -1.0, 'H': 1.0}
# SO3R_h 29
# SO3R_h: 6.0 fdxrd_h + 7.0 h_h + so3_h --> 6.0 fdxox_h + 3.0 h2o_h + h2s_h unbalance {'Fe': -36.0, 'S': -36.0, 'X': -6.0, 'H': -12.0}
# FNOR2_h 30
# r0698 31
# r0698: dcholcoa_x + 4.0 h_x + ppcoa_x --> coa_x + dhcholestancoa_x + h2o_x unbalance {'charge': -4.0}
# SULRR 32
# HMR_2611 33
# HMR_2611: M00129_c + crn_c + 2.0 h_c --> coa_c + ttdcrn_c unbalance {'charge': -2.0}
# FAD_9 34
# FAD_9: coa_c + dodcoa_c + fad_c + nad_c --> accoa_c + decoa_c + fadh2_c + nadh_c unbalance {'charge': nan, 'H': -3.0, 'O': -1.0}
# FAD_10 35
# FAD_10: coa_c + decoa_c + fad_c + nad_c --> accoa_c + fadh2_c + nadh_c + occoa_c unbalance {'charge': -1.0, 'H': 3.0, 'O': 1.0}
# ACOAD23f 36
# ACOAD23f: fad_c + hdcoa_c --> fadh2_c + hd2coa_c unbalance {'H': 2.0}
# PYAS 37
# PYAS: aspsa_c + pyr_c --> h2o_c + h_c + thdp_c unbalance {'O': -1.0}
# HDECH 38
# HDECH: 1hdecg3p_c + h2o_c --> glyc3p_c + 3.0 h_c + hdcea_c unbalance {'charge': 2.0}
# ARTPLM1 39
# ARTFR13_cho 40
# ACCDH 41
# OGMG 42
# OGMG: 4izp_c + 3.0 h2o_c + h_c + 2.0 nad_c --> 4ogm_c + for_c + 2.0 nadh_c + nh4_c unbalance {'charge': nan, 'H': -1.0}
# RTOT1_cho 43
# RTOT1_cho: R1coa_cho_c --> Rtotalcoa_c unbalance {'X': -1.0, 'R': 1.0}

# %%
# NADPH
add_rxn(model,'ADD_nadph_c','nadph_c --> nadp_c + h_c')
objective_reaction = 'ADD_nadph_c'
model.objective='ADD_nadph_c'
nadph_flux = model.optimize().fluxes['ADD_nadph_c']

if nadph_flux > 1e-6:
    objective_reaction = 'ADD_nadph_c'
    constraint_value = 1e-6
    grate_delete_rxn = find_infinite_rxn(model,objective_reaction,constraint_value,rxn_grate)
    nadph_end_rxn = locating_rxn(model,check_model,objective_reaction,constraint_value,grate_delete_rxn,outputfile,unbalance_rxn)
else:
    nadph_end_rxn = []

rxn = model.reactions.get_by_id('ADD_nadph_c')
model.remove_reactions([rxn])

# %%
# fadh2

add_rxn(model,'ADD_fadh2_c','fadh2_c --> fad_c + h_c')
objective_reaction = 'ADD_fadh2_c'
model.objective='ADD_fadh2_c'
fadh2_flux = model.optimize().fluxes['ADD_fadh2_c']

if fadh2_flux > 1e-6:
    objective_reaction = 'ADD_fadh2_c'
    constraint_value = 1e-6
    grate_delete_rxn = find_infinite_rxn(model,objective_reaction,constraint_value,rxn_grate)
    fadh2_end_rxn = locating_rxn(model,check_model,objective_reaction,constraint_value,grate_delete_rxn,outputfile,unbalance_rxn)
else:
    fadh2_end_rxn = []

rxn = model.reactions.get_by_id('ADD_fadh2_c')
model.remove_reactions([rxn])

# %%
# q8h2

add_rxn(model,'ADD_q8h2_c','q8h2_c --> q8_c + h_c')
objective_reaction = 'ADD_q8h2_c'
model.objective='ADD_q8h2_c'
q8h2_flux = model.optimize().fluxes['ADD_q8h2_c']

if q8h2_flux > 1e-6:
    objective_reaction = 'ADD_q8h2_c'
    constraint_value = 1e-6
    grate_delete_rxn = find_infinite_rxn(model,objective_reaction,constraint_value,rxn_grate)
    q8h2_end_rxn = locating_rxn(model,check_model,objective_reaction,constraint_value,grate_delete_rxn,outputfile,unbalance_rxn)
else:
    q8h2_end_rxn = []

rxn = model.reactions.get_by_id('ADD_q8h2_c')
model.remove_reactions([rxn])

# %%
# 2dmmql8

add_rxn(model,'ADD_2dmmql8_c','2dmmql8_c --> 2dmmq8_c + h_c')
objective_reaction = 'ADD_2dmmql8_c'
model.objective='ADD_2dmmql8_c'
dmmql8_flux = model.optimize().fluxes['ADD_2dmmql8_c']

if dmmql8_flux > 1e-6:
    objective_reaction = 'ADD_2dmmql8_c'
    constraint_value = 1e-6
    grate_delete_rxn = find_infinite_rxn(model,objective_reaction,constraint_value,rxn_grate)
    dmmql8_end_rxn = locating_rxn(model,check_model,objective_reaction,constraint_value,grate_delete_rxn,outputfile,unbalance_rxn)
else:
    dmmql8_end_rxn = []

rxn = model.reactions.get_by_id('ADD_2dmmql8_c')
model.remove_reactions([rxn])

# %%
met_rxn = nadh_end_rxn + nadph_end_rxn + fadh2_end_rxn + q8h2_end_rxn + dmmql8_end_rxn
cor_unri,cor_unrr,cor_balri,cor_balrr,cor_type,del_ri,del_rr,del_type = modify_delete_rxn(model,met_rxn,balance_rxn)
# Out:
# P5CDEG: e4hglu_c + nad_c --> 4hglusa_c + nadh_c 4HGLSD: 4hglusa_c + h2o_c + nad_c --> e4hglu_c + 2.0 h_c + nadh_c 2
# FDR: nadph_c + rdxo_c --> h_c + nadp_c + rdxr_c RDXR: nadh_c + 2.0 rdxo_c <=> h_c + nad_c + 2.0 rdxr_c 2
# SFRR: h_c + so3_c --> h2o_c + h2s_c SULR: 5.0 h_c + 3.0 nadph_c + so3_c --> 3.0 h2o_c + h2s_c + 3.0 nadp_c 2
# GLA: nad_c + udpgalur_c --> 2.0 h_c + nadh_c + udpglcur_c UGE: udpglcur_c <=> udpgalur_c 2

# %% [markdown]
# ## 2.3 infinite generation of energy

# %%
# deleting proton gradient reactions
respiratory_rxn=[]
ATP_list=['atp','adp','h','pi','h2o','h']
for r in model.reactions:
    ATP_mets=[]
    for met in r.metabolites:
        if str(met)[-2:-1]=='_':
            ATP_mets.append(str(met)[:-2])
        elif str(met)[-3:-2]=='_':
            ATP_mets.append(str(met)[:-3])
    if sorted(ATP_mets)==sorted(ATP_list):
        respiratory_rxn.append(r.id)
        r.bounds = (0,0)

for rei in list(set(respiratory_rxn)):
    rxn = model.reactions.get_by_id(rei)
    model.remove_reactions([rxn])

# %%
# adding combined respiratory chain reactions

reaction = Reaction('ADD_respiratory1') 
model.add_reactions([reaction])
reaction.build_reaction_from_string('7.0 adp_c + 11.0 h_c + 4.0 nadh_c + 2.0 o2_c + 7.0 pi_c --> 7.0 atp_c + 11.0 h2o_c + 4.0 nad_c')

reaction = Reaction('ADD_respiratory2') 
model.add_reactions([reaction])
reaction.build_reaction_from_string('adp_c + fadh2_c + h_c + o2_c + pi_c --> atp_c + fad_c + h2o_c')

reaction = Reaction('ADD_respiratory3') 
model.add_reactions([reaction])
reaction.build_reaction_from_string('adp_c + h_c + 0.5 o2_c + pi_c + q8h2_c --> atp_c + 2.0 h2o_c + q8_c')

add_rxn(model,'ADD_h_c','h_c <=> ')

rxn_grate['ADD_respiratory1'] = 0
rxn_grate['ADD_respiratory2'] = 0
rxn_grate['ADD_respiratory3'] = 0
rxn_grate['ADD_h_c'] = 0

# %%
# atp
model.objective='ATPM'
atp_flux = model.optimize().fluxes['ATPM']

if atp_flux > 1e-6:
    objective_reaction = 'ATPM'
    constraint_value = 1e-6
    grate_delete_rxn = find_infinite_rxn(model,objective_reaction,constraint_value,rxn_grate)
    outputfile = 'results/quality_control/energy/'
    atp_rxn = locating_rxn(model,check_model,objective_reaction,constraint_value,grate_delete_rxn,outputfile,unbalance_rxn)
# Out:
# 1
# FE2Gabcpp: fe2_p + gtp_c + h2o_c --> fe2_c + gdp_c + h_c + pi_c 2
# 2
# RE2649C: h2o_c + ppcoa_c --> coa_c + h_c + ppa_c 2
# 3
# FE2GTPabc: fe2_e + gtp_c + h2o_c --> fe2_c + gdp_c + h_c + pi_c 2
# 4
# PPPPH: gbdp_c + h_c + pi_c --> gdptp_c + h2o_c 2
# PpGppP: gdp_c + ppi_c --> gbdp_c + h2o_c 2
# 5
# RE3629C: CE2089_c + accoa_c --> CE2088_c + coa_c + h_c 2
# RE3630C: CE2088_c + h2o_c --> CE2089_c + ac_c 2
# 6
# PPAAFDOR: fdxo_42_c + h2o_c + ppal_c --> fdxr_42_c + 3.0 h_c + ppa_c 2
# FRDO6r: fdxr_42_c + h_c + nad_c --> fdxo_42_c + nadh_c 2
# 7
# RE2649M: h2o_m + ppcoa_m --> coa_m + h_m + ppa_m 2
# 8
# TRDR4: gthox_c + trdrd_c --> 2.0 gthrd_c + trdox_c 2
# 9
# SHL_c: h2s_c + h_c + ser__L_c --> cys__L_c + h2o_c 2
# PLRXR: gthox_c + plrxrd_c --> 2.0 gthrd_c + plrxox_c 2
# PLRXR2: plrxox_c + trdrd_c --> plrxrd_c + trdox_c 2
# ASCTmr: accoa_m + succ_m --> ac_m + succoa_m 2
# 10
# ACKrm: ac_m + atp_m --> actp_m + adp_m 1
# RE2030M: accoa_m + met__L_m --> C02712_m + coa_m + h_m 1
# PTArm: accoa_m + pi_m --> actp_m + coa_m 1
# RE2640C: C02712_c + h2o_c --> ac_c + met__L_c 1
# 11
# PGLCNDH_1: 6p2dhglcn_c + h_c + nadph_c --> 6pgc_c + nadp_c 2
# 12
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# 13
# APSR: aps_c + trdrd_c --> amp_c + 2.0 h_c + so3_c + trdox_c 1
# GTHAMPOR: amp_c + gthox_c + h_c + so3_c --> aps_c + 2.0 gthrd_c 1
# TSULR3e: 2.0 gthrd_c + tsul_c --> gthox_c + h2s_c + so3_c 1
# CYS: h2s_c + ser__L_c --> cys__L_c + h2o_c 1
# AHSERL4: acser_c + trdrd_c + tsul_c --> ac_c + cys__L_c + h_c + so3_c + trdox_c 1
# 14
# OOR2r: akg_c + coa_c + fdxo_42_c --> co2_c + fdxr_42_c + h_c + succoa_c 2
# UMPK4: gtp_c + ump_c --> gdp_c + udp_c 2
# METR: 5mthf_c + cfesp_c --> mecfsp_c + thf_c 2
# HMR_6515: mercppyr_c + so3_c --> pyr_c + tsul_c 2
# POR: coa_c + fdxo_42_c + pyr_c --> accoa_c + co2_c + fdxr_42_c + h_c 2
# CODH_ACS: co2_c + coa_c + fdxr_42_c + h_c + mecfsp_c --> accoa_c + cfesp_c + fdxo_42_c + h2o_c 2
# MTHFR5: fdxo_42_c + h_c + mlthf_c + 2.0 nadh_c --> 5mthf_c + fdxr_42_c + 2.0 nad_c 2
# RE1530C: dgtp_c + duri_c --> dgdp_c + dump_c + h_c 2
# 4HTHRA: 4hthr_c --> gcald_c + gly_c 2
# RPEc: 2.0 ru5p__D_c --> 2.0 xu5p__D_c 2
# ACSERHS: acser_c + trdrd_c + tsul_c --> ac_c + cys__L_c + so3_c + trdox_c 2
# DGUPP: dgtp_c + uri_c --> dgdp_c + ump_c 2
# FRDO5r: fdxr_42_c + h_c + nadp_c --> fdxo_42_c + nadph_c 2
# FE2Gabcpp 1
# FE2Gabcpp: fe2_p + gtp_c + h2o_c --> fe2_c + gdp_c + h_c + pi_c direction_backward {}
# RE2649C 2
# RE2649C: h2o_c + ppcoa_c --> coa_c + h_c + ppa_c direction_backward {}
# FE2GTPabc 3
# FE2GTPabc: fe2_e + gtp_c + h2o_c --> fe2_c + gdp_c + h_c + pi_c direction_backward {}
# PPPPH 4
# PpGppP 5
# PpGppP: gdp_c + ppi_c <-- gbdp_c + h2o_c direction_forward {}
# RE3629C 6
# RE3630C 7
# RE3630C: CE2088_c + h2o_c --> CE2089_c + ac_c direction_backward {}
# PPAAFDOR 8
# PPAAFDOR: fdxo_42_c + h2o_c + ppal_c --> fdxr_42_c + 3.0 h_c + ppa_c direction_backward {}
# FRDO6r 9
# RE2649M 10
# RE2649M: h2o_m + ppcoa_m --> coa_m + h_m + ppa_m direction_backward {}
# TRDR4 11
# SHL_c 12
# PLRXR 13
# PLRXR2 14
# ASCTmr 15
# ACKrm 16
# RE2030M 17
# PTArm 18
# RE2640C 19
# RE2640C: C02712_c + h2o_c --> ac_c + met__L_c direction_backward {}
# PGLCNDH_1 20
# FNOR_1 21
# APSR 22
# GTHAMPOR 23
# TSULR3e 24
# CYS 25
# AHSERL4 26
# AHSERL4: acser_c + trdrd_c + tsul_c --> ac_c + cys__L_c + h_c + so3_c + trdox_c direction_backward {}
# OOR2r 27
# UMPK4 28
# METR 29
# HMR_6515 30
# POR 31
# CODH_ACS 32
# CODH_ACS: co2_c + coa_c + fdxr_42_c + h_c + mecfsp_c <-- accoa_c + cfesp_c + fdxo_42_c + h2o_c direction_forward {'charge': nan}
# MTHFR5 33
# RE1530C 34
# 4HTHRA 35
# 4HTHRA: 4hthr_c --> gcald_c + gly_c direction_backward {}
# RPEc 36
# ACSERHS 37
# ACSERHS: acser_c + trdrd_c + tsul_c --> ac_c + cys__L_c + so3_c + trdox_c direction_backward {'charge': -1.0, 'H': -1.0}
# DGUPP 38
# FRDO5r 39

# %%
# ctp
add_rxn(model,'ADD_ctp','ctp_c + h2o_c --> cdp_c + h_c + pi_c')
model.objective='ADD_ctp'
ctp_flux = model.optimize().fluxes['ADD_ctp']

if ctp_flux > 1e-6:
    objective_reaction = 'ADD_ctp'
    constraint_value = 1e-6
    grate_delete_rxn = find_infinite_rxn(model,objective_reaction,constraint_value,rxn_grate)
    outputfile = 'results/quality_control/energy/'
    ctp_rxn = locating_rxn(model,check_model,objective_reaction,constraint_value,grate_delete_rxn,outputfile,unbalance_rxn)
else:
    ctp_rxn = []

rxn = model.reactions.get_by_id('ADD_ctp')
model.remove_reactions([rxn])

# %%
# gtp

add_rxn(model,'ADD_gtp','gtp_c + h2o_c --> gdp_c + h_c + pi_c')
model.objective='ADD_gtp'
gtp_flux = model.optimize().fluxes['ADD_gtp']

if gtp_flux > 1e-6:
    objective_reaction = 'ADD_gtp'
    constraint_value = 1e-6
    grate_delete_rxn = find_infinite_rxn(model,objective_reaction,constraint_value,rxn_grate)
    outputfile = 'results/quality_control/energy/'
    gtp_rxn = locating_rxn(model,check_model,objective_reaction,constraint_value,grate_delete_rxn,outputfile,unbalance_rxn)
else:
    gtp_rxn = []

rxn = model.reactions.get_by_id('ADD_gtp')
model.remove_reactions([rxn])

# %%
# utp
add_rxn(model,'ADD_utp','utp_c + h2o_c --> udp_c + h_c + pi_c')
model.objective='ADD_utp'
utp_flux = model.optimize().fluxes['ADD_utp']

if utp_flux > 1e-6:
    objective_reaction = 'ADD_utp'
    constraint_value = 1e-6
    grate_delete_rxn = find_infinite_rxn(model,objective_reaction,constraint_value,rxn_grate)
    outputfile = 'results/quality_control/energy/'
    utp_rxn = locating_rxn(model,check_model,objective_reaction,constraint_value,grate_delete_rxn,outputfile,unbalance_rxn)
else:
    utp_rxn = []

rxn = model.reactions.get_by_id('ADD_utp')
model.remove_reactions([rxn])

# %%
# itp
add_rxn(model,'ADD_itp','itp_c + h2o_c --> idp_c + h_c + pi_c')
model.objective='ADD_itp'
itp_flux = model.optimize().fluxes['ADD_itp']

if itp_flux > 1e-6:
    objective_reaction = 'ADD_itp'
    constraint_value = 1e-6
    grate_delete_rxn = find_infinite_rxn(model,objective_reaction,constraint_value,rxn_grate)
    outputfile = 'results/quality_control/energy/'
    itp_rxn = locating_rxn(model,check_model,objective_reaction,constraint_value,grate_delete_rxn,outputfile,unbalance_rxn)
else:
    itp_rxn = []

rxn = model.reactions.get_by_id('ADD_itp')
model.remove_reactions([rxn])

# %%
ppi_h2o = ppi_h2o_rule(model)

acyl_h2o = ylcoa_h2o(model)

ac_rxn = ac_rule(model)

aldehyde_ate_rxn = aldehyde_rule(model)
# Out:
# 1
# 16
# 13
# 14

# %% [markdown]
# ## 2.4 metabolites with incorrect synthetic pathways

# %%
#  Determining the pathway yield of metabolites surpassed the maximum theoretical yield calculated by the ratio of the reduction degrees of substrate and product
model.reactions.get_by_id('EX_glc__D_e').bounds = (-10,1000)

over_yield_met = []
for met in model.metabolites:
    with model:
        if re.search("C[A-Z]",str(met.formula)) or re.search("C[\d]",str(met.formula)): 
            target_product = str(met.id)
            objective_reaction = 'ADD_'+target_product
            if objective_reaction in model.reactions:
                model.objective = objective_reaction
            else:
                add_rxn(model,objective_reaction,target_product + ' --> ') 
                model.objective = objective_reaction
            solution = model.optimize()
            
            if max_reduced_degree_rate(model,target_product) != 0 and not math.isnan(max_reduced_degree_rate(model,target_product)):
                if solution.fluxes[objective_reaction] != 0:
                    if (solution.fluxes[objective_reaction] - max_reduced_degree_rate(model,target_product)) > 1e-6:
                        over_yield_met.append(met.id)
                        print(target_product,solution.fluxes[objective_reaction],max_reduced_degree_rate(model,target_product))

currency_met_carbon = ['dadp', 'dutp', 'nad', 'xdp', 'imp', 'atp', 'dgtp', 'fad', 'nadp', 'idp', 'itp', 'fadh2', 'dudp', 'dgmp', 'xtp', 'dump', 'cdp', 'gtp',
                        'gdp', 'adp', 'dcdp', 'didp', 'amp', 'udp', 'dimp', 'utp', 'nadh', 'q8', 'q8h2', 'gmp', 'dtdp', 'ctp', 'ump', 'xmp', 'datp', 'dcmp',
                        'damp', 'ditp', 'dttp', 'dgdp', 'dctp', 'cmp', 'nadph', 'dtmp', 'coa', 'co2', 'fad', 'fadh2', 'q8', 'q8h2', 'mqn8', 'mql8', '2dmmql8',
                        '2dmmq8', 'q6', 'q6h2', 'fadh2', 'fad', 'mqn6', '2dmmq6', 'mql6', 'q', 'qh2', 'pqh2', 'pq', 'pqh2', 'pq', 'fadh2', 'fad', 'q10', 'q10h2',
                        'fadh2', 'fad', 'q10', 'q10h2', 'fad', 'pqh2', 'pq', 'fadh2', 'mqn7', 'mql7', 'q10', 'q10h2', 'fad', 'fad', 'pq', 'pqh2', 'pqh2', 'pqh2',
                        'pq', 'q9', 'q9h2', 'mqn11', 'mqn11', 'mqn9', 'mqn9', 'mqn10', 'mqn7', 'mqn10', 'mqn8', 'fadh2', 'pq', 'pqh2', 'pq', 'q8h2', 'q8', 'mqn4'
                        'mql4', '2dmmq4', 'mqn4', 'ficytc', 'focytc', 'focytc', 'cytcc', 'focytcc553', 'ficytcc553', 'ficytb', 'ficytC', 'focytC', 'omclo', 'omclr',
                        'omchr', 'omcho', 'ppc1o', 'ppc1r', 'focytc6', 'ficytc6', 'focytc6', 'ficytc6', 'focytC', 'ficytC', 'ficytc', 'focytc', 'ficytb5', 'focytb5',
                        'cytP450o', 'cytP450r', 'cytP450o', 'cytP450r', 'apocytc', 'cytc', 'ficytc', 'focytc', 'pqhb6l', 'hemeB3p', 'hemeB2p', 'pqb6s', 'pqhb6s',
                        'hemeX', 'hemeXp', 'pqhb6l', 'hemeB3p', 'hemeB2p', 'pqb6s', 'pqhb6s', 'focytc6', 'ficytc6', 'ficytc', 'ppcr', 'ppco', 'apocytc', 'cytc',
                        'focytcc', 'ficytcc', 'ficytb5', 'focytb5', 'HC00617', 'HC00619']
over_yield_end = []
for mi in over_yield_met:
    if mi[:-2] not in currency_met_carbon:
        over_yield_end.append(mi)
# Out:
# 2ohph_c 0.9944751381215473 0.96
# cys__L_c 17.142857142857146 13.333333333333332
# met__L_c 9.075630252100822 8.0
# udcpdp_c 2.25 0.7792207792207793
# colipa_e 0.31088082901554426 0.2884615384615385
# cys__L_e 17.14285714285715 13.333333333333332
# enlipa_e 0.4197859091863151 0.41522491349480967
# gthox_e 3.1858407079646014 2.926829268292683
# hacolipa_e 0.2777777777777778 0.25974025974025977
# halipa_e 0.3671296579575356 0.36363636363636365
# met__L_e 9.075630252100844 8.0
# o16a4colipa_e 0.17958097771865922 0.17341040462427743
# thm_e 4.302788844621513 4.285714285714286
# 14glucan_c 9.642857142857142 9.6
# 5mtr_e 7.248322147651008 7.058823529411765
# 5mtr_p 7.248322147651001 7.058823529411765
# 5mtr_c 7.248322147651008 7.058823529411765
# unaga_c 1.7088607594936702 0.7058823529411764
# unagamu_c 1.4099216710182774 0.6521739130434783
# pmtcoa_c 1.3366336633663423 1.3333333333333333
# stcoa_c 1.2587412587412588 1.25
# od2coa_c 1.2690951821386576 1.263157894736842
# acolipa_p 0.3030303030303027 0.28169014084507044
# acolipa_e 0.303030303030303 0.28169014084507044
# adocbl_c 1.0183875530410185 0.7868852459016394
# adocbl_p 1.0183875530410225 0.7868852459016394
# adocbl_e 1.0183875530410198 0.7868852459016394
# q8_c 0.9358752166377808 0.916030534351145
# q8h2_c 0.9302325581395346 0.9090909090909092
# mqn8_c 0.9270386266094419 0.8823529411764707
# mql8_c 0.9215017064846425 0.8759124087591241
# cgly_p 11.489361702127667 10.0
# cgly_c 11.489361702127624 10.0
# cgly_e 11.489361702127646 10.0
# colipa_c 0.31088082901554354 0.2884615384615385
# colipa_p 0.31088082901554404 0.2884615384615385
# cys__D_c 17.14285714285711 13.333333333333332
# cyst__L_c 7.883211678832112 7.058823529411765
# hcys__L_c 11.48936170212767 10.0
# cys__L_p 17.14285714285711 13.333333333333332
# octdp_c 1.1297071129707106 1.0714285714285714
# 2dmmql8_c 0.935875216637782 0.8955223880597014
# dmpp_c 8.780487804878057 8.571428571428571
# ipdp_c 8.780487804878051 8.571428571428571
# grdp_c 4.462809917355376 4.285714285714286
# 2dmmq8_c 0.9415867480383592 0.9022556390977443
# gthrd_p 6.242774566473987 5.7142857142857135
# gthox_p 3.1858407079646014 2.926829268292683
# eca4und_p 0.4812834224598933 0.3508771929824561
# eca4colipa_p 0.20745293891663488 0.19867549668874174
# udcpdp_p 1.2537438183464513 0.7792207792207793
# eca2und_p 0.7929515418502205 0.4838709677419355
# unagamuf_p 1.1726384364820848 0.5970149253731343
# eca3und_p 0.599001663893512 0.4067796610169491
# unagamuf_c 1.1726384364820848 0.5970149253731343
# 3hodcoa_c 1.2690951821386567 1.263157894736842
# hmgth_c 5.654450261780097 5.217391304347826
# Sfglutth_c 5.869565217391308 5.454545454545454
# mso3_c 31.764705882352892 30.0
# gicolipa_c 0.33994334277620386 0.3278688524590164
# gagicolipa_c 0.3287671232876712 0.31746031746031744
# icolipa_c 0.3519061583577714 0.3389830508474576
# ggagicolipa_c 0.318302387267905 0.3076923076923077
# gggagicolipa_c 0.30848329048843276 0.29850746268656714
# glucys_c 7.499999999999996 6.666666666666666
# lgt__S_c 4.757709251101309 4.444444444444445
# gthrd_c 6.242774566473976 5.7142857142857135
# frdp_c 2.991689750692526 2.8571428571428568
# gthox_c 3.185840707964603 2.926829268292683
# gtspmd_c 3.1213872832369933 3.0
# gthrd_e 6.242774566473987 5.7142857142857135
# 3ophb_c 0.9944751381215475 0.9523809523809523
# mmet_c 7.500000000000011 6.666666666666666
# h2mb4p_c 9.310344827586112 9.230769230769232
# lipa_p 0.42725913266386595 0.4225352112676056
# met__D_c 9.075630252101405 8.0
# met__L_p 9.075630252100819 8.0
# uaagmda_c 0.8933002481388996 0.5150214592274678
# o16a4colipa_p 0.17958097771866355 0.17341040462427743
# o16aund_p 0.96170970614412 0.5381165919282511
# o16a2und_p 0.6115515288788984 0.410958904109589
# aragund_c 1.3722998729351328 0.6417112299465242
# garagund_c 1.2013348164638178 0.6030150753768844
# 2omph_c 0.9720972097206726 0.9375
# 2ommbl_c 0.9507042253521332 0.9230769230769231
# 2omhmbl_c 0.9507042253521955 0.9302325581395349
# 2ombzl_c 0.9720972097212268 0.9448818897637795
# 2oph_c 0.994475138121544 0.9523809523809523
# enlipa_p 0.4197859091864373 0.41522491349480967
# 4ppcys_c 4.408163265307089 4.137931034482759
# pan4p_c 4.408163265305632 4.137931034482759
# rhcys_c 5.744680851063777 5.454545454545454
# dgslnt_c 3.0594900849858426 2.926829268292683
# thm_p 4.302788844621546 4.285714285714286
# thm_c 4.302788844621319 4.285714285714286
# uLa4fn_c 1.8336162987972615 0.7272727272727273
# uLa4n_c 1.8685121107255545 0.7317073170731707
# dkmpp_c 7.248322147594536 7.058823529411765
# 2kmb_c 9.642857142856712 8.571428571428571
# eca4colipa_e 0.20745293891662087 0.19867549668874174
# lipa_e 0.4272591326639823 0.4225352112676056
# 5mdru1p_c 7.248322147650583 7.058823529411765
# 5mdr1p_c 7.248322147653084 7.058823529411765
# 4mpetz_c 8.059701492540398 7.058823529411765
# 2hpmhmbq_m 1.2026726057906907 1.2
# q6_m 1.1700975081257987 1.1650485436893203
# 2hp6mp_m 1.2371134020522256 1.2
# 2hp6mbq_m 1.2371134020619063 1.2244897959183674
# 2mbac_c 7.500000000000114 6.315789473684211
# 2mbac_e 7.5 6.315789473684211
# 2mbald_c 10.90909090909156 8.571428571428571
# 2mbald_e 10.909090909089855 8.571428571428571
# 3dh5hpb_c 1.2735849056603237 1.2371134020618557
# 3dh5hpb_m 1.2735849056606412 1.2371134020618557
# 3ohodcoa_x 1.2796208530800186 1.276595744680851
# pmtcoa_x 1.3366336633662286 1.3333333333333333
# hexccoa_x 1.0055865921788163 1.0
# ch4s_c 19.636363636351916 17.142857142857142
# 2mbtoh_c 9.999999999999734 8.0
# ttccoa_c 1.0588235294116286 1.0526315789473684
# hexccoa_c 1.0055865921790428 1.0
# cyst__L_x 7.883211678832148 7.058823529411765
# hcys__L_x 11.489361702109022 10.0
# dolmanp_r 0.7520891364902518 0.4301075268817205
# dolp_r 0.8157099697885997 0.449438202247191
# dolp_c 0.815709969788486 0.449438202247191
# 2mbtoh_e 9.99999999999261 8.0
# q6h2_m 1.170097508125668 1.153846153846154
# frdp_m 2.99168975069288 2.8571428571428568
# ggdp_c 2.2500000000003695 2.142857142857143
# pendp_c 1.8030050083485354 1.7142857142857144
# gthox_m 3.185840707964985 2.926829268292683
# gthrd_m 6.2427745664742815 5.7142857142857135
# hexdp_c 1.5041782729804565 1.4285714285714284
# hexdp_m 1.5041782729803828 1.4285714285714284
# ipdp_m 8.780487804877453 8.571428571428571
# lanost_c 1.4835164835163348 1.4285714285714284
# met__L_m 9.07563025210078 8.0
# pendp_m 1.8030050083470883 1.7142857142857144
# ttccoa_x 1.0588235294117627 1.0526315789473684
# stcoa_x 1.2587412587413382 1.25
# pan4p_m 4.40816326530618 4.137931034482759
# sql_r 1.4979195561717298 1.4117647058823528
# Ssq23epx_r 1.4835164835163481 1.4285714285714284
# sql_c 1.4979195561720644 1.4117647058823528
# 4mhetz_c 7.8832116788287285 7.058823529411765
# hepdp_c 1.290322580645892 1.2244897959183674
# decdp_c 0.9045226130664109 0.8571428571428572
# cysi__L_p 9.23076923076826 7.058823529411765
# cysi__L_c 9.230769230769283 7.058823529411765
# udcpp_c 2.249999999999901 0.7792207792207793
# colipa20Oag_e 0.08370795225547455 0.08356545961002786
# scys__L_c 15.652173913043498 13.333333333333332
# udcpo4_e 1.2537438183463792 0.5825242718446602
# udcpo5_e 1.203449889684553 0.5714285714285714
# 3ophb_5_c 1.273584905660563 1.2244897959183674
# 3ophb_5_m 1.2735849056604138 1.2244897959183674
# hkmpp_c 7.2483221476479684 7.058823529411765
# dhmtp_c 7.24832214765047 7.058823529411765
# mcbtt_c 1.8274111675121958 1.1650485436893203
# uaaAgla_c 0.8933002481388286 0.5150214592274678
# uaGgla_c 1.0179076343072269 0.5529953917050692
# uaAgla_c 1.0179076343075013 0.5529953917050692
# uaaGgla_c 0.8933002481389529 0.5150214592274678
# uaaAgtla_c 0.8903544929922873 0.5150214592274678
# ragund_c 1.4380825565912048 0.6557377049180328
# arachcoa_c 1.18421052631588 1.1764705882352942
# 4met2obut_c 9.642857142859953 8.571428571428571
# colipa20Oag_p 0.08370795225547545 0.08356545961002786
# udcdp20Oag_p 0.10865191146881231 0.10221465076660988
# udcdpgalrmnmanabe_c 1.1332633788038322 0.5853658536585367
# udcdpgalrmnmanabe_p 1.133263378804119 0.5853658536585367
# udcdpgal_c 1.8120805369125321 0.7228915662650602
# udcdpgalrmn_c 1.5104895104895917 0.6703910614525139
# udcdpgalrmnman_c 1.3059250302300853 0.6282722513089005
# udcdp2Oag_p 0.757363253856326 0.46875
# udcdp3Oag_p 0.5687203791467843 0.3908794788273615
# udcdp4Oag_p 0.4553119730184534 0.33519553072625696
# udcdp8Oag_p 0.25328330206374744 0.21352313167259787
# udcdp9Oag_p 0.22799240025332584 0.1957585644371941
# udcdp12Oag_p 0.17543859649120785 0.15665796344647517
# udcdp13Oag_p 0.16292050082969048 0.14687882496940025
# udcdp14Oag_p 0.15206983948183073 0.1382488479262673
# udcdp15Oag_p 0.14257425742572308 0.1305767138193689
# udcdp16Oag_p 0.13419483101380505 0.12371134020618556
# udcdp17Oag_p 0.12674568712592174 0.11753183153770813
# udcdp18Oag_p 0.12008005336891282 0.11194029850746268
# udcdp19Oag_p 0.11408049012359661 0.10685663401602849
# udcpgrm_c 1.3059250302298635 0.625
# udcpo4_c 1.253743818346437 0.5825242718446602
# udcpg_c 1.8120805369126503 0.7228915662650602
# udcpgr_c 1.5104895104896912 0.6666666666666666
# udcpo5_p 1.2034498896837602 0.5714285714285714
# udcpo5_c 1.2034498896836205 0.5714285714285714
# udcpo4_p 1.25374381834632 0.5825242718446602
# uLa4n_p 1.8685121107265203 0.7317073170731707
# udcpp_p 1.253743818345811 0.7792207792207793
# caro_c 1.1688311688310193 1.1111111111111112
# bcryptox_c 1.160042964555302 1.1214953271028036
# zeax_c 1.1513859275052416 1.1320754716981132
# pqh2_u 0.873080032336323 0.8275862068965517
# pq_u 0.8780487804879734 0.8333333333333333
# mercppyr_c 20.0 15.0
# phytoe_c 1.1344537815126186 1.0714285714285714
# phytof_c 1.1428571428572027 1.0810810810810811
# prephytedp_c 1.129707112970875 1.0714285714285714
# zcarote_c 1.1513859275053804 1.0909090909090908
# gtocophe_c 1.5606936416185135 1.5384615384615385
# avite1_c 1.5062761506281674 1.4814814814814814
# dtocophe_c 1.6191904047468983 1.6
# bvite_c 1.5606936416184958 1.5384615384615385
# 23dmphol_c 1.5606936416186272 1.5384615384615385
# 2m6phol_c 1.6191904047971803 1.6
# phdp_c 2.155688622754386 2.0338983050847457
# echin_c 1.1688311688310478 1.1320754716981132
# gcarote_c 1.1688311688311614 1.1111111111111112
# phllqne_c 1.5062761506276277 1.4457831325301205
# dpterol_c 1.4979195561720644 1.4117647058823528
# 13_cis_oretn_n 2.37362637362628 2.3529411764705883
# avite1_e 1.497919556171837 1.4814814814814814
# mercplaccys_e 9.230769230767862 7.058823529411765
# phllqne_e 1.506276150627624 1.4457831325301205
# retinol_e 2.3027718550108602 2.2222222222222223
# retinol_9_cis_e 2.283298097251418 2.2222222222222223
# retinol_cis_11_e 2.2832980972516452 2.2222222222222223
# retn_e 2.3736263736263936 2.307692307692308
# retnglc_e 1.9529837251359652 1.935483870967742
# 3dphb_m 0.8157099697885336 0.7792207792207793
# 3dpdhb_m 0.8114199849737731 0.7843137254901961
# arachcoa_m 1.1842105263156668 1.1764705882352942
# pmtcoa_m 1.3366336633666833 1.3333333333333333
# chito2pdol_U_c 0.039208567798152676 0.0375
# mpdol_U_c 0.03767660910518231 0.03614457831325301
# dolmanp_U_r 0.04208065458795986 0.04
# dolp_U_r 0.043929225137281966 0.041666666666666664
# stcoa_m 1.258741258735654 1.25
# caro_e 1.168831168830934 1.1111111111111112
# 2dpmhobq_m 0.7780979827088892 0.7692307692307693
# q10_m 0.7643312101912131 0.7547169811320754
# 2dp6mobq_m 0.7964601769911811 0.7792207792207793
# 2dp6mobq_me_m 0.7820419985519891 0.7643312101910827
# 2dp6mep_m 0.7964601769911468 0.7692307692307693
# q10h2_m 0.7605633802816502 0.75
# cysam_c 15.65217391253384 13.333333333333332
# thcys_c 15.0 10.0
# cysi__L_e 9.230769230769283 7.058823529411765
# decdp_m 0.9045226130655138 0.8571428571428572
# dedoldp__L_c 0.041951522684898684 0.03968253968253968
# dedolp__L_c 0.04195152268488616 0.03968253968253968
# dedoldp_U_c 0.04419889502762728 0.041811846689895474
# dedolp_U_c 0.044198895027623225 0.041811846689895474
# dedol__L_c 0.04195152268489748 0.03968253968253968
# dedol_U_c 0.04419889502762425 0.041811846689895474
# 3dpdhb_me_m 0.7964601769911497 0.7692307692307693
# dmpp_x 8.78048780484221 8.571428571428571
# ipdp_x 8.780487804877453 8.571428571428571
# grdp_x 4.462809917354999 4.285714285714286
# doldp__L_r 0.04081015719469839 0.03955174686882004
# dolp__L_r 0.04188644120385205 0.03955174686882004
# dolglcp__L_c 0.04020250148898152 0.03804692454026633
# dolglcp__L_r 0.040202501488983716 0.03804692454026633
# dolglcp_U_c 0.04208065458796473 0.04
# dolglcp_U_r 0.04208065458793092 0.04
# dolichol__L_r 0.041886441203848795 0.03955174686882004
# dolichol__L_c 0.041886441203848615 0.03955174686882004
# dolichol_U_r 0.04407263823708263 0.041666666666666664
# dolichol_U_c 0.04407263823709684 0.041666666666666664
# dolmanp_U_c 0.042080654587964436 0.04
# m8mpdol__L_r 0.027817844632179362 0.027063599458728015
# g1m8mpdol__L_r 0.027037852994189232 0.02635046113306983
# g2m8mpdol__L_r 0.02630040911747263 0.025673940949935813
# g2m8mpdol_U_r 0.02709143358836117 0.02654867256637168
# g3m8mpdol_U_r 0.026351104062454764 0.02586206896551724
# m5mpdol__L_r 0.03045341755019706 0.029455081001472753
# dolmanp__L_r 0.04020250148896594 0.03804692454026633
# m6mpdol__L_r 0.029521102121143023 0.02861230329041488
# m5mpdol_U_r 0.03151904275498757 0.030612244897959183
# m6mpdol_U_r 0.03052140737600553 0.0297029702970297
# m7mpdol__L_r 0.028644175684281264 0.027816411682892905
# dolp_U_c 0.044000814830234124 0.041666666666666664
# od2coa_m 1.2690951821386989 1.263157894736842
# arachcoa_x 1.1842105263151552 1.1764705882352942
# lgnccoa_x 1.0588235294119386 1.0526315789473684
# frdp_x 2.991689750692558 2.8571428571428568
# ttc_ggdp_c 2.249999999999999 2.142857142857143
# m2mpdol__L_c 0.03364066782955485 0.03231017770597738
# m3mpdol__L_c 0.03250662171923336 0.03129890453834116
# m3mpdol_U_c 0.03372365339578506 0.03260869565217391
# m4mpdol_U_c 0.03258410016593828 0.031578947368421054
# m1mpdol__L_c 0.034856700232378045 0.0333889816360601
# dolp__L_c 0.041951522684894715 0.03955174686882004
# naglc2p__L_c 0.039612676056340175 0.03757044458359424
# chito2pdol__L_c 0.037573058725286046 0.03577817531305903
# naglc2p_U_c 0.041434874352580545 0.039473684210526314
# glyc__S_c 26.666666666669506 24.0
# glyc__S_e 26.66666666666228 24.0
# lgnccoa_c 1.0588235294117112 1.0526315789473684
# lanost_r 1.483516483516496 1.4285714285714284
# retinol_c 2.302771855010519 2.2222222222222223
# retinol_cis_11_c 2.302771855010633 2.2222222222222223
# retinol_9_cis_c 2.302771855010633 2.2222222222222223
# m4mpdol_U_r 0.03258410016593832 0.031578947368421054
# mercplac_c 17.142857142857224 13.333333333333332
# mercplaccys_c 9.230769230798533 7.058823529411765
# ptth_c 4.408163265305916 4.137931034482759
# retinal_c 2.337662337662323 2.2641509433962264
# retn_c 2.373626373625484 2.307692307692308
# retinal_cis_13_c 2.337662337662664 2.2641509433962264
# 13_cis_retn_c 2.373626373625484 2.307692307692308
# retinal_11_cis_c 2.3376623376620955 2.2641509433962264
# retinal_cis_9_c 2.3376623376536827 2.2641509433962264
# 13_cis_retn_n 2.3736263736261662 2.307692307692308
# retinol_cis_13_c 2.302771855010519 2.2222222222222223
# retnglc_r 1.9529837251355104 1.935483870967742
# retnglc_c 1.9529837251356668 1.935483870967742
# retn_r 2.3736263736263936 2.307692307692308
# 13_cis_retn_r 2.373626373626621 2.307692307692308
# thm_m 4.302788844621542 4.285714285714286
# q10_c 0.7643312101933972 0.7547169811320754
# q10h2_c 0.7605633802816101 0.75
# ch4s_e 19.63636363636317 17.142857142857142
# udcpp_e 0.9334485738979704 0.7792207792207793
# udcpdp_e 0.9334485738980423 0.7792207792207793
# acaro_h 1.134453781512807 1.1111111111111112
# caro_u 1.1344537815125728 1.1111111111111112
# frdp_h 2.991689750692558 2.8571428571428568
# pmtcoa_h 1.3366336633607716 1.3333333333333333
# pmtcoa_s 1.3366336633660012 1.3333333333333333
# retinal_h 2.268907563025209 2.2641509433962264
# retinal_s 2.2689075630252105 2.2641509433962264
# caro_h 1.1344537815126143 1.1111111111111112
# ggdp_h 2.250000000000034 2.142857142857143
# ggdp_u 2.25 2.142857142857143
# gthox_h 3.185840707963962 2.926829268292683
# gthox_u 3.1858407079607787 2.926829268292683
# phdp_h 2.155688622754802 2.0338983050847457
# phdp_u 2.155688622754619 2.0338983050847457
# gthrd_u 6.242774566474509 5.7142857142857135
# Ssq23epx_c 1.483516483516496 1.4285714285714284
# cyart_c 1.4835164835163823 1.4285714285714284
# menecyart_c 1.4342629482072546 1.3793103448275863
# ipdp_h 8.780487804878248 8.571428571428571
# dmpp_h 8.780487804877794 8.571428571428571
# 2m6phol_h 1.6191904047976209 1.6
# dtocophe_h 1.6191904047975072 1.6
# bvite_h 1.5606936416184318 1.5384615384615385
# avite1_h 1.5062761506275693 1.4814814814814814
# gtocophe_h 1.5606936416184838 1.5384615384615385
# 3ohodcoa_c 1.2796208530800186 1.276595744680851
# bcryptox_u 1.1261730969761174 1.1214953271028036
# dcaro_h 1.1344537815123772 1.1111111111111112
# pqh2_h 0.8530805687203633 0.8275862068965517
# lycop_h 1.1344537815128604 1.1111111111111112
# scys__L_m 15.652173913039405 13.333333333333332
# hcys__L_h 11.489361702126644 10.0
# cys__L_h 17.142857142856997 13.333333333333332
# glucys_h 7.499999999999545 6.666666666666666
# gthrd_h 6.242774566473827 5.7142857142857135
# ocdccoa_c 1.2587412587413382 1.25
# pa18111Z160_h 1.153846153846319 1.1483253588516746
# cdp12dgr18111Z160_h 1.0084033613442784 1.00418410041841
# hcys__L_m 11.48936170213301 10.0
# doldp_c 0.8138658628484647 0.7741935483870968
# dolpglc_c 0.7520891364901611 0.718562874251497
# dolmanp_c 0.7520891364898132 0.4301075268817205
# phytol_h 2.173038229376246 2.0338983050847457
# retpalm_11_cis_s 1.228070175438266 1.2
# retinol_s 2.236024844720465 2.2222222222222223
# retac_s 2.0809248554913893 2.0689655172413794
# dhretinol_s 2.204081632653015 2.1818181818181817
# retpalm_s 1.2316715542519887 1.2
# 2mhop_m 3.0945558739251737 3.076923076923077
# 2mhob_m 2.8877005347594604 2.8571428571428568
# strcoa_c 1.252900232018754 1.25
# met_L_ala__L_c 6.315789473686465 5.7142857142857135
# 12d3k5m_c 7.248322147651038 7.058823529411765
# cyst__L_e 7.883211678832822 7.058823529411765
# mqn7_c 1.0256410256410262 0.9836065573770492
# mql7_c 1.0188679245281946 0.975609756097561
# 2h3k5m_c 7.248322147650356 7.058823529411765
# gly_met__L_c 7.297297297298769 6.666666666666666
# thr_L_met__L_c 5.4271356783966604 5.217391304347826
# met_L_met__L_c 4.46280991735523 4.0
# metox__R_c 9.075630252100382 8.571428571428571
# 13_cis_retnglc_r 1.9529837251328672 1.935483870967742
# hcys__L_e 11.489361702127894 10.0
# dedoldp_c 0.8225437928407117 0.45112781954887216
# dedolp_c 0.8225437928408887 0.45112781954887216
# dedol_c 0.8225437928410161 0.45112781954887216
# dolichol_c 0.818181818175795 0.449438202247191
# docoscoa_c 1.118012422359925 1.1111111111111112
# docoscoa_x 1.1134020618550977 1.1111111111111112
# doldp_r 0.7736389684871948 0.449438202247191
# g3m8mpdol_r 0.36388140161724636 0.27088036117381487
# dolglcp_c 0.7520891364902541 0.4301075268817205
# dolglcp_r 0.752089136490223 0.4301075268817205
# g1m8mpdol_r 0.3935860058308265 0.2863961813842482
# m8mpdol_r 0.4103343465045658 0.29484029484029484
# g2m8mpdol_r 0.3781512605042549 0.27842227378190254
# dolichol_r 0.8181818181815288 0.449438202247191
# m4mpdol_r 0.4945054945055099 0.3342618384401114
# m5mpdol_r 0.470383275261284 0.3234501347708895
# m7mpdol_r 0.4285714285714714 0.3037974683544304
# ptth_e 4.268774703554868 4.137931034482759
# q10_e 0.764331210191358 0.7547169811320754
# q10h2_e 0.7605633802817238 0.75
# slfcys_e 14.999999999999943 12.0
# frdp_r 2.991689750692558 2.8571428571428568
# m2mpdol_c 0.5510204081632363 0.35820895522388063
# m3mpdol_c 0.5212355212355707 0.345821325648415
# m1mpdol_c 0.5844155844155453 0.37151702786377705
# naglc2p_c 0.731707317073178 0.42402826855123676
# chito2pdol_c 0.6650246305421222 0.4013377926421405
# m4mpdol_c 0.49450549450553927 0.3342618384401114
# pmtcoa_r 1.3366336633657738 1.3333333333333333
# pan4p_e 4.268774703582039 4.137931034482759
# CE2243_c 1.1933701657459435 1.188118811881188
# CE2247_c 1.193370165731153 1.188118811881188
# CE2250_c 1.1344537815125004 1.1320754716981132
# CE2246_c 1.1261730969935435 1.1214953271028036
# CE2249_c 1.0661401776898174 1.0619469026548671
# CE2253_c 1.073558648111657 1.0714285714285714
# CE2245_c 1.066140177689249 1.0619469026548671
# docoscoa_m 1.118012422360266 1.1111111111111112
# gthrd_x 6.242774566469961 5.7142857142857135
# gthrd_r 6.242774566474168 5.7142857142857135
# retinal_cis_13_r 2.3376623376625503 2.2641509433962264
# retinal_cis_9_r 2.337662337662323 2.2641509433962264
# retinal_r 2.3376623376602765 2.2641509433962264
# CE1617_c 2.3736263736261662 2.307692307692308
# CE5594_c 2.3736263736964247 2.307692307692308
# CE1401_c 11.489361702129145 10.0
# C02712_m 6.9677419354825965 6.315789473684211
# CE1665_c 4.218750000000403 4.0
# CE1617_r 2.37362637362628 2.307692307692308
# CE5756_r 1.9529837251359368 1.935483870967742
# CE5082_m 6.242774566467801 5.7142857142857135
# cyst__L_m 7.8832116788308895 7.058823529411765
# CE1310_m 10.909090909091692 9.230769230769232
# cys__L_m 17.142857142857224 13.333333333333332
# CE5956_c 2.2500000000000315 2.142857142857143
# slfcys_c 15.000000000000227 12.0
# 4ppcys_m 4.408163265306147 4.137931034482759
# lanost_x 1.483516483516496 1.4285714285714284
# 2mba_c 12.000000000000227 9.230769230769232
# 2mba_e 12.000000000000227 9.230769230769232
# 2h3mb_e 9.999999999999659 7.058823529411765
# dmtphllqne_c 1.5606936416184567 1.5
# cthzp_c 7.297297297295643 7.058823529411765
# 3nphb_c 0.8962655601659529 0.8571428571428572
# npdp_c 1.0046511627907269 0.9523809523809523
# phytfl_c 1.1428571428571033 1.0810810810810811
# pq_um 0.8702659145848969 0.8333333333333333
# pqh2_um 0.8653846153845852 0.8275862068965517
# 2m6sbenzq_c 0.8830744071958634 0.8450704225352113
# pqh2_c 0.8653846153843148 0.8275862068965517
# pqh2_cm 0.8653846153846143 0.8275862068965517
# dczcaro_c 1.151385927505089 1.0909090909090908
# tczcaro_c 1.1513859275054366 1.0909090909090908
# lycop_c 1.168831168831135 1.1111111111111112
# ttclyco_c 1.1688311688312043 1.1111111111111112
# 2c4mthzep_c 7.297297297297338 7.058823529411765
# unagam_c 1.3846153846153841 0.6451612903225806
# pq_cm 0.8653846153846134 0.8333333333333333
# q9_m 0.8346213292115601 0.8275862068965517
# q9h2_m 0.8301306687163788 0.821917808219178
# nacglc2p_c 0.7317073170731667 0.7017543859649122
# phyto_h 1.1344537815125508 1.0714285714285714
# 3oeicoscoa_c 1.2026726057906671 1.2
# 3heicoscoa_c 1.1933701657459324 1.188118811881188
# eicos2coa_c 1.1933701657458187 1.188118811881188
# behencoa_c 1.118012422360266 1.1111111111111112
# docos2coa_c 1.1261730969761174 1.1214953271028036
# 3ottccoa_c 1.0735586481114296 1.0714285714285714
# 3httccoa_c 1.0661401776899964 1.0619469026548671
# ttc2coa_c 1.0661401776900017 1.0619469026548671
# ttc2coa_x 1.0661401776906354 1.0619469026548671
# eicos2coa_x 1.1933701657451365 1.188118811881188
# 5mtr_m 7.248322147652743 7.058823529411765
# mercppyr_m 19.999999999998835 15.0
# chito2pdpl_c 0.6650246305419011 0.6417112299465242
# mpdol_c 0.6221198156682038 0.38585209003215437
# m5mpdol_c 0.470383275264907 0.4633204633204633
# m6mpdol_c 0.44850498338871087 0.44280442804428044
# g1m8mpdol_c 0.39358600583088904 0.3908794788273615
# m8mpdol_c 0.4103343465045455 0.4067796610169491
# g2m8mpdol_c 0.3781512605042039 0.3761755485893417
# g3m8mpdol_c 0.3638814016172505 0.3625377643504532
# grdp_m 4.462809917355571 4.285714285714286
# 2np6mep_m 0.8730800323363787 0.8450704225352113
# me3dhnpdh_m 0.8730800323362694 0.8450704225352113
# gcarote_h 1.1344537815127413 1.1111111111111112
# 2m6sbenzq_h 0.8702659145848202 0.8450704225352113
# dmtphllqne_h 1.5428571428572786 1.5
# phllqne_h 1.489655172414086 1.4457831325301205
# mthb_c 9.075630252101519 8.0
# dmshb_c 7.5 6.666666666666666
# dmsp_c 8.307692307694992 7.5
# HC01118_r 1.5041782729822444 1.4285714285714284
# stcoa_r 1.258741258741793 1.25
# CE1261_c 4.675324675324873 4.615384615384616
# 13_cis_retnglc_c 1.9529837251358053 1.935483870967742
# C05109_c 1.4693877551019483 1.4117647058823528
# 3hodcoa_m 1.2690951821388126 1.263157894736842
# retinal_e 2.337662337662323 2.2641509433962264
# pcholste_hs_e 1.7910447761190653 1.6326530612244896
# peste_hs_e 2.068965517241395 1.875
# pchol2linl_hs_e 1.7910447761196338 1.6783216783216783
# pe2linl_hs_e 2.068965517241292 1.935483870967742
# pcholn19_hs_e 1.79104477611952 1.5686274509803921
# pcholn201_hs_e 1.7910447761198232 1.5286624203821655
# pcholn205_hs_e 1.7910447761194064 1.610738255033557
# pcholn224_hs_e 1.7910447761192927 1.47239263803681
# pe203_hs_e 2.068965517240656 1.7910447761194028
# pe226_hs_e 2.0689655172427592 1.6901408450704225
# pe224_hs_e 2.0689655172410752 1.6666666666666665
# pedh203_hs_e 2.0689655172412813 1.7910447761194028
# pe17_hs_e 2.0689655172409402 1.9672131147540983
# pcholn203_hs_e 1.7910447761194632 1.5686274509803921
# pcholn24_hs_e 1.7910447761189516 1.3114754098360657
# pcholn261_hs_e 1.7910447761196338 1.2435233160621761
# pcholdoc_hs_e 1.7910447761195578 1.3114754098360657
# pcholeic_hs_e 1.7910447761196338 1.5483870967741935
# pcholet_hs_e 1.7910447761198327 1.5686274509803921
# pcholhep_hs_e 1.791044776120657 1.702127659574468
# pchollinl_hs_e 1.7910447761187243 1.6783216783216783
# pelinl_hs_e 2.0689655172415087 1.935483870967742
# sphmyln181221_hs_c 1.0810810810811375 0.933852140077821
# sphmyln18122_hs_c 1.0810810810810836 0.9266409266409266
# sphmyln18123_hs_c 1.0810810810806646 0.9056603773584905
# sphmyln1824_hs_c 1.081081081081152 0.8791208791208792
# sphmyln1825_hs_c 1.081081081081642 0.860215053763441
# sphmyln18116_hs_c 1.0810810810825835 1.0762331838565022
# sphmyln18118_hs_c 1.0810810810810665 1.0212765957446808
# sphmyln181181_hs_c 1.0810810810810427 1.0300429184549356
# magarachi_hs_e 2.2641509433958618 1.9672131147540983
# pcholole_hs_c 1.7910447761192927 1.6551724137931034
# peole_hs_c 2.0689655172415087 1.9047619047619047
# pcholpalm_hs_c 1.7910447761196338 1.777777777777778
# pcholste_hs_c 1.7910447761179284 1.6326530612244896
# pchol2palm_hs_c 1.7910447761193826 1.777777777777778
# pcholn183_hs_c 1.7910447761194064 1.702127659574468
# pcholn1836_hs_c 1.7910447761192927 1.702127659574468
# pcholn19_hs_c 1.7910447761194064 1.5686274509803921
# pcholn204_hs_c 1.791044776119179 1.589403973509934
# pcholn205_hs_c 1.7910447761196644 1.610738255033557
# pcholn2254_hs_c 1.7910447761192927 1.4906832298136647
# pe203_hs_c 2.0689655172411676 1.7910447761194028
# pe224_hs_c 2.0689655172412813 1.6666666666666665
# pe17_hs_c 2.068965517241395 1.9672131147540983
# pailar_hs_c 1.8461538461539249 1.643835616438356
# pcholn24_hs_c 1.7910447761199748 1.3114754098360657
# pcholn261_hs_c 1.791044776118838 1.2435233160621761
# pcholn281_hs_c 1.7910447761196338 1.1707317073170733
# pcholn28_hs_c 1.79104477611952 1.1594202898550725
# pcholdoc_hs_c 1.7910447761187178 1.3114754098360657
# pcholeic_hs_c 1.79104477611952 1.5483870967741935
# pcholet_hs_c 1.7910447761189516 1.5686274509803921
# pchollinl_hs_c 1.791044776119577 1.6783216783216783
# pelinl_hs_c 2.068965517241395 1.935483870967742
# 4mtob_c 9.642857142857423 8.571428571428571
# pear_hs_e 2.068965517242077 1.8181818181818183
# aracheth_e 2.0689655172409402 2.0338983050847457
# C02712_c 6.967741935484241 6.315789473684211
# C02712_e 6.967741935482688 6.315789473684211
# diholineth_e 2.0689655172397465 2.0
# docteteth_e 2.0689655172409402 1.8461538461538463
# maglinl_hs_e 2.264150943396089 2.1052631578947367
# magole_hs_e 2.2641509433963165 2.0689655172413794
# magste_hs_e 2.2641509433959754 2.0338983050847457
# pailar_hs_e 1.8461538461540064 1.643835616438356
# pchol2ole_hs_e 1.7910447761198316 1.6551724137931034
# pchol2palm_hs_e 1.7910447761194899 1.777777777777778
# pchol2ste_hs_e 1.7910447761194441 1.6326530612244896
# pcholn204_hs_e 1.791044776117855 1.589403973509934
# pcholn225_hs_e 1.791044776119501 1.4906832298136647
# pcholn28_hs_e 1.7910447761197865 1.1594202898550725
# sphmyln180241_hs_e 1.0810810810809077 0.8856088560885609
# sphmyln18117_hs_e 1.0810810810812086 1.0480349344978166
# sphmyln18118_hs_e 1.0810810810807538 1.0212765957446808
# sphmyln18120_hs_e 1.0810810810810696 0.9716599190283401
# sphmyln181201_hs_e 1.0810810810811706 0.9795918367346939
# sphmyln18123_hs_e 1.0810810810814928 0.9056603773584905
# sphmyln1824_hs_e 1.081081081080967 0.8791208791208792
# xolest204_hs_e 0.9292035398227227 0.9230769230769231
# alaargcys_e 5.0000000000003775 4.615384615384616
# argargmet_e 3.282674772036671 3.2432432432432434
# argcysser_e 5.167464114833017 4.8
# argpromet_e 3.364485981308917 3.2432432432432434
# asncyscys_e 5.999999999999886 5.0
# asnmetpro_e 3.94160583941607 3.75
# cysaspphe_e 3.612040133779942 3.428571428571429
# cyscys_e 8.571428571427802 6.666666666666666
# cysleuthr_e 4.000000000000691 3.75
# cystyrasn_e 3.6486486486487504 3.5294117647058827
# hiscyscys_e 4.655172413792911 4.285714285714286
# metglyarg_e 4.337349397589833 4.137931034482759
# metmetile_e 2.9268292682926074 2.6666666666666665
# mettrpphe_e 2.0769230769228244 2.0689655172413794
# pheasnmet_e 2.9916897506926716 2.926829268292683
# sercysarg_e 5.167464114832484 4.8
# thrmetarg_e 3.6000000000000227 3.5294117647058827
# trpmetval_e 2.477064220183479 2.4
# tyrvalmet_e 2.727272727272748 2.608695652173913
# argargmet_c 3.2826747720365574 3.2432432432432434
# argcysgly_e 5.654450261780141 5.217391304347826
# argcysgly_c 5.654450261782069 5.217391304347826
# argpromet_c 3.364485981308326 3.2432432432432434
# argvalcys_e 3.9999999999998863 3.75
# argvalcys_c 4.000000000000227 3.75
# asnmetpro_c 3.941605839416056 3.75
# aspmetasp_e 4.75770925110055 4.444444444444445
# aspmetasp_c 4.757709251102256 4.444444444444445
# cysasnmet_e 4.5378151260505035 4.0
# cysasnmet_c 4.5378151260507025 4.0
# cysglnmet_e 4.137931034483358 3.6363636363636367
# cysglnmet_c 4.13793103448279 3.6363636363636367
# cysleuthr_c 4.000000000000256 3.75
# cyssermet_e 4.800000000000412 4.137931034482759
# cyssermet_c 4.799999999999793 4.137931034482759
# cystyrasn_c 3.6486486486490435 3.5294117647058827
# glylyscys_e 5.0 4.615384615384616
# glylyscys_c 4.999999999999858 4.615384615384616
# metasntyr_e 3.050847457627107 3.0
# metasntyr_c 3.050847457719249 3.0
# metglyarg_c 4.337349397590202 4.137931034482759
# metmetile_c 2.926829268292863 2.6666666666666665
# metphearg_e 2.6470588235286527 2.608695652173913
# metphearg_c 2.647058823529414 2.608695652173913
# mettrpphe_c 2.0769230769230944 2.0689655172413794
# pheasnmet_c 2.9916897506924442 2.926829268292683
# procys_e 6.666666666666572 6.0
# procys_c 6.6666666666664876 6.0
# trpmetval_c 2.4770642201837063 2.4
# tyrcysgly_e 4.106463878327233 3.870967741935484
# tyrcysgly_c 4.106463878328167 3.870967741935484
# tyrcysthr_e 3.4394904458599265 3.333333333333333
# tyrcysthr_c 3.4394904458599243 3.333333333333333
# tyrvalmet_c 2.72727272727127 2.608695652173913
# alaargcys_c 4.999999999998636 4.615384615384616
# argcysser_c 5.167464114832455 4.8
# cysaspphe_c 3.612040133779212 3.428571428571429
# cyscys_c 8.571428571429124 6.666666666666666
# cysglutrp_c 3.0252100840342564 2.926829268292683
# proargcys_c 4.106463878326508 3.870967741935484
# thrmetarg_c 3.5999999999976353 3.5294117647058827
# Lhcystin_e 5.9668508287293776 5.217391304347826
# mqn7_e 1.025641025640554 0.9836065573770492
# mqn8_e 0.9270386266093738 0.8823529411764707
# pcholn226_hs_e 1.79104477611968 1.5094339622641508
# pcholn226_hs_c 1.7910447761196338 1.5094339622641508
# pchol2ole_hs_c 1.79104477611952 1.6551724137931034
# pcholn224_hs_c 1.7910447761190653 1.47239263803681
# pe226_hs_c 2.0689655172429866 1.6901408450704225
# pedh203_hs_c 2.068965517241258 1.7910447761194028
# pcholpalm_hs_e 1.791044776119347 1.777777777777778
# peste_hs_c 2.068965517240713 1.875
# sphmyln180241_hs_c 1.0810810810809632 0.8856088560885609
# sphmyln18116_hs_e 1.0810810810813052 1.0762331838565022
# sphmyln181181_hs_e 1.0810810810808675 1.0300429184549356
# sphmyln18120_hs_c 1.0810810810808391 0.9716599190283401
# sphmyln181201_hs_c 1.0810810810810658 0.9795918367346939
# sphmyln181221_hs_e 1.0810810810811702 0.933852140077821
# sphmyln1825_hs_e 1.081081081081095 0.860215053763441
# pchol2linl_hs_c 1.7910447761194064 1.6783216783216783
# pcholar_hs_e 1.7910447761194064 1.589403973509934
# pcholar_hs_c 1.7910447761192927 1.589403973509934
# pcholn183_hs_e 1.7910447761196144 1.702127659574468
# pcholn201_hs_c 1.7910447761194082 1.5286624203821655
# pcholn225_hs_c 1.7910447761201738 1.4906832298136647
# pcholn2254_hs_e 1.7910447761201738 1.4906832298136647
# pear_hs_c 2.068965517241135 1.8181818181818183
# sphmyln18122_hs_e 1.0810810810809315 0.9266409266409266
# CE1310_c 10.909090909090839 9.230769230769232
# CE1310_e 10.90909090908941 9.230769230769232
# sql_e 1.497919556171985 1.4117647058823528
# CE1617_e 2.3736263736261662 2.307692307692308
# CE1401_e 11.48936170212744 10.0
# glucys_e 7.297297297301611 6.666666666666666
# CE1261_e 4.675324675324873 4.615384615384616
# M00127_c 1.2690951821386989 1.263157894736842
# gthox_r 3.185840707939633 2.926829268292683
# M00939_c 1.4693877551132932 1.4457831325301205
# M00940_c 1.455525606468882 1.4285714285714284
# CE2248_c 1.2690951821385852 1.263157894736842
# 3ohxccoa_c 1.0188679245285357 1.0169491525423728
# M00783_c 1.0121836925864045 1.0084033613445378
# M00049_c 1.0121836925962953 1.0084033613445378
# M00127_m 1.26909518213904 1.263157894736842
# docoscoa_r 1.118012422360266 1.1111111111111112
# CE2247_m 1.193370165745542 1.188118811881188
# CE2251_m 1.20267260579065 1.2
# M00245_c 7.248322147649816 7.058823529411765
# retinol_r 2.3027718550107465 2.2222222222222223
# M00658_m 0.792369772560528 0.7692307692307693
# M01165_m 0.7780979827090555 0.7547169811320754
# M00770_m 0.7741935483868261 0.759493670886076
# doldp__L_c 0.04195152268490419 0.03955174686882004
# lgt__S_m 4.757709251101171 4.444444444444445
# HC01118_c 1.5041782729804822 1.4285714285714284
# lgt_s_c 4.757709251104984 4.444444444444445
# aglaa_e 1.0843373493971171 0.5700712589073634
# pepm_w 0.8095952023988389 0.48289738430583495
# gly_met_c 7.499999999981824 6.666666666666666
# bsh_c 4.675324675324568 4.444444444444445
# 2dmmq7_c 1.0505836575874647 1.0084033613445378
# psqldp_c 1.504178272980539 1.4285714285714284
# gly_cys_c 11.999999999999318 10.0
# lip2_c 0.8933002481389565 0.5139186295503212
# lip2g_c 0.8752025931928961 0.507399577167019
# lip2g3_c 0.8411214953272292 0.49484536082474223
# metsox_R__L_c 9.07563025210061 8.571428571428571
# PG_ST_w 0.10663507109003834 0.09917355371900827
# pepd_w 0.49360146252287507 0.35036496350364965
# udcpdp_w 0.8933002481387007 0.7792207792207793
# udcpp_w 0.8933002481389813 0.7792207792207793
# nacetlbdgl_c 1.3846153846153395 0.6451612903225806
# uagmda_c 1.0179076343073064 0.5529953917050692
# pq_y 0.8780487804876126 0.8333333333333333
# pqh2_y 0.873080032335363 0.8275862068965517
# 3hechin_c 1.1600429645542931 1.1428571428571428
# 5mdru1p_e 7.24832214765047 7.058823529411765
# pq_c 0.8780487804877841 0.8333333333333333
# q8h2_m 0.9137055837566226 0.9090909090909092
# ddcpdp_c 0.7541899441370106 0.7142857142857142
# doldp12_c 0.7505211952745512 0.7100591715976332
# mqn4_m 1.536273115220613 1.4814814814814814
# mql4_m 1.5211267605633338 1.4634146341463414
# dol12manp_c 0.6963249516441105 0.6629834254143646
# dol12manp_r 0.6963249516439645 0.6629834254143646
# doldp11_c 2.217659137577357 0.7741935483870968
# dolp11_c 2.217659137577776 0.7741935483870968
# dolp12_c 0.7505211952744957 0.7100591715976332
# dolp11_r 2.2176591375764723 0.7741935483870968
# dolp12_r 0.7505211952744967 0.7100591715976332
# lgt__S_h 4.675324675324418 4.444444444444445
# dol11manp_r 1.8030050083472133 0.718562874251497
# octdp_m 1.129707112970775 1.0714285714285714
# 3ophb_m 0.9944751381215298 0.9523809523809523
# 2ohph_m 0.9881061299174405 0.96
# 2omph_m 0.9660107334525918 0.9375
# 2ommbl_m 0.9391304347826717 0.9230769230769231
# 2omhmbl_m 0.9334485738980902 0.9302325581395349
# 2ombzl_m 0.9600000000002069 0.9448818897637795
# 2oph_m 0.9944751381214515 0.9523809523809523
# chito2pdol_L_dolp12_c 0.6210465784933821 0.5970149253731343
# gthox_x 3.1858407079644167 2.926829268292683
# cmylphosph_c 270.00000000003774 -120.0
# h23k5mt1pp_c 7.248322147652175 7.058823529411765
# m5t23dopp_c 7.248322147652061 7.058823529411765
# abdmagdpu_c 1.3846153846153584 0.6451612903225806
# ibtol_c 9.99999999999999 8.0
# ibtol_e 10.000000000000512 8.0
# pbng_c 11.999999999982037 6.0
# fe3mcbtt_e 1.8274111675122673 1.1822660098522166
# hcys__L_p 11.48936170212653 10.0
# fe3mcbtt_c 1.8151260504200586 1.1822660098522166
# mcbtt_e 1.827411167512679 1.1650485436893203
# fe3mcbtt_p 1.8274111675128741 1.1822660098522166
# mcbtt_p 1.8274111675127822 1.1650485436893203
# unquivo_c 1.6901408450702435 0.7017543859649122
# unquivo_p 1.690140845070431 0.7017543859649122
# udcpo4min_e 1.3059250302296164 0.625
# udcpo4min_p 1.3059250302297443 0.625
# udcpo4min_c 1.3059250302299006 0.625
# OA1_3_19_ST_p 0.4875846501128366 0.35398230088495575
# udcdpgal_a1_3_rmn_a1_4_man_p 1.3059250302297956 0.6282722513089005
# OA55__L_p 0.07753050969133256 0.07540056550424128
# udcdpglcnac_b1_3_glc_a1_4_fuc_a1_3_acper_p 1.0609037328093507 0.5673758865248226
# LPS38_ST_e 0.16309272123201307 0.16150740242261102
# LPS38_ST_p 0.16309272123225327 0.16150740242261102
# OA9_46_27_ST_p 0.37961335676622326 0.293398533007335
# udcdpgal_a1_3_rmn_a1_4_man_a1_3_tyv_p 1.1332633788037967 0.5853658536585367
# udcdpgalnac_c 1.708860759493632 0.7058823529411764
# udcpdpgalnac_b1_4_glc_b1_3_gal3_a1_4_rmn_a1_3_qui3nac_c 0.955752212389342 0.5357142857142857
# udcpdpgalnac_b1_3_gal3_b1_4_ribf_qui3nac_c 0.7747489239598447 0.4838709677419355
# udcdpglcnac_a1_3_quinac_a1_3_glc_b1_4_man_c 1.0682492581604492 0.5687203791469194
# udcdpglcnac_a1_3_quinac_a1_3_glc_b1_4_man_p 1.0682492581602787 0.5687203791469194
# OA35_ST_p 0.29834254143649447 0.24291497975708504
# udcdpglcnac_a1_3_gal_a1_4_glc_a1_3col_a1_6col_p 0.9747292418773483 0.5405405405405406
# OA43__L_p 0.06523708849290075 0.06386375731772219
# OA18__L_p 0.08517350157742612 0.08253094910591471
# udcdpgal_a1_3_man_a1_2_man_b1_2_acrmn_a1_3_abe_p 0.9809264305177614 0.5429864253393666
# LPS8_ST_e 0.16496105086300017 0.1626016260162602
# LPS8_ST_p 0.16496105086300972 0.1626016260162602
# udcdpglcnac_a1_3_galnac_b1_4_rib_b1_3_qui4N_c 1.0112359550561152 0.5504587155963303
# udcdpglcnac_a1_3_galnac_b1_4_rib_b1_3_qui4N_p 1.0112359550561412 0.5504587155963303
# LPS62_ST_e 0.16223524109962 0.16042780748663105
# LPS62_ST_p 0.16223524109963516 0.16042780748663105
# LPS9_ST_p 0.18598243499226896 0.182370820668693
# OA9_ST_p 0.3796133567661684 0.293398533007335
# OA57__L_p 0.06455469216973991 0.06302521008403361
# udcdpgalnac_a1_3_glc_a1_4_rmn_a1_2_rmn_b1_2_glcnac_p 0.9557522123893705 0.5357142857142857
# LPS47_ST_e 0.17874875868920903 0.17569546120058566
# LPS47_ST_p 0.17874875868919596 0.17569546120058566
# LPS9_46_27_ST_e 0.18598243499222755 0.182370820668693
# LPS9_46_27_ST_p 0.18598243499196343 0.182370820668693
# OA9_46__L_p 0.08776919951239061 0.08397480755773268
# OA43_ST_p 0.29228687415417626 0.24048096192384769
# udcdpglcnac_a1_3_galnac_b1_3_gal_a1_3_gal_a1_2_fuc_p 0.9617097061440705 0.5381165919282511
# LPS17_ST_p 0.2016053761433696 0.19736842105263158
# OA17_ST_p 0.45093945720250517 0.3342618384401114
# udcpdpgalnac_b1_3_gal3_b1_4_ribf_qui3nac_p 0.7747489239597058 0.4838709677419355
# LPS3_10_ST_e 0.20160537614336765 0.19736842105263158
# OA47__L_p 0.08011869436198149 0.07722007722007722
# udcdpglcnac_b1_3_gal_a1_2_fuc_b1_4_rib_a1_3_fucac_b1_4_glc_p 0.8910891089108767 0.5217391304347826
# udcdpgalnac_a1_3_galnac_a1_4_glc_b1_4_gal_a1_4_fuc3nac_c 0.9318377911993423 0.5286343612334802
# OA59__L_p 0.07851690294438299 0.0759974667511083
# udcdpglcnac_a1_3_rmn_a1_4_glcnac_b1_3_gal_p 1.0682492581602645 0.5687203791469194
# LPS56_ST_e 0.16922594797863655 0.16597510373443983
# LPS56_ST_p 0.16922594797869206 0.16597510373443983
# OA53__L_p 0.07851690294440848 0.0759974667511083
# OA52__L_p 0.06737367436057651 0.06651884700665188
# udcdpglcnac_b1_3_gal_a1_4_glcnac_b1_4_gal_b1_4_rib_p 0.980036297640694 0.5454545454545454
# LPS59_ST_e 0.17713629653931068 0.1744186046511628
# LPS59_ST_p 0.1771362965391835 0.1744186046511628
# OA16__L_p 0.06455469216976079 0.06302521008403361
# udcpdpglcnacc_b1_3_glc_b1_3_man_a1_3_fuc3nfo_c 1.0953346855983943 0.576923076923077
# udcpdpglcnacc_b1_3_glc_b1_3_man_a1_3_fuc3nfo_p 1.095334685599802 0.576923076923077
# udcdpgalnac_b1_3_gal_a1_4_gal_b1_3_galnac_a1_3_glcnac_c 0.937500000000001 0.5309734513274336
# udcdpgalnac_b1_3_gal_a1_4_gal_b1_3_galnac_a1_3_glcnac_p 0.9375 0.5309734513274336
# udcpdpgalnac_a1_3_fucnam_c 1.3722998729354003 0.6417112299465242
# LPS41_ST_p 0.1771362965392882 0.1744186046511628
# OA41_ST_p 0.3444976076555501 0.2733485193621868
# LPS2_ST_p 0.18598243499228642 0.182370820668693
# OA2_ST_p 0.37961335676627644 0.293398533007335
# udcdpgal_a1_3_rmn_a1_4_man_c 1.3059250302294743 0.6282722513089005
# udcdpgal_a1_3_rmn_c 1.5104895104890232 0.6703910614525139
# udcdpgal_a1_3_man_a1_2_man_b1_2_rmn_c 1.150159744409054 0.5911330049261083
# udcdpgal_a1_3_man_a1_2_man_c 1.3170731707302714 0.631578947368421
# OA51__L_p 0.06250000000000114 0.06141248720573183
# OA63__L_p 0.06187338871383669 0.0606366851945427
# udcdpgalnac_a1_3_galnac_a1_4_glc_b1_4_gal_a1_4_fuc3nac_p 0.9318377911992646 0.5286343612334802
# udcdpglcnac_b1_3_galf_b1_6_mannac_a1_3_gal_a1_4_galf_c 0.980036297640669 0.5454545454545454
# udcdpglcnac_b1_3_galf_b1_6_mannac_a1_3_gal_a1_4_galf_p 0.9800362976406569 0.5454545454545454
# udcdpgal_a1_3_rmn_a1_4_man_a1_3_par_c 1.1332633788035764 0.5853658536585367
# udcdpgal_a1_3_rmn_a1_4_man_a1_3_tyv_c 1.133263378803705 0.5853658536585367
# OA38_ST_p 0.2950819672130229 0.24291497975708504
# udcdpgalnac_b1_3_glc_b1_2_glcnac_b1_4_gal_b1_4_gal_p 0.9677419354837568 0.5405405405405406
# OA41__L_p 0.07851690294438479 0.0759974667511083
# OA28ac__L_p 0.06455469216974728 0.06302521008403361
# udcpdpgalnac_b1_4_glc_b1_3_gal3_a1_4_rmn_a1_3_qui3nac_p 0.9557522123893847 0.5357142857142857
# LPS7_ST_p 0.18361101666100765 0.1809954751131222
# OA7_ST_p 0.36986301369865937 0.2898550724637681
# udcdpgal_a1_3_man_a1_2_man_b1_2_acrmn_c 1.1076923076923388 0.5797101449275363
# udcdpgal_a1_3_man_a1_2_man_b1_2_acrmn_a1_3_abe_c 0.9809264305178687 0.5429864253393666
# OA9_46_27__L_p 0.08776919951238825 0.08397480755773268
# OA11__L_p 0.08401400233372282 0.08113590263691683
# udcpdglcnac_a1_3_rmn_a1_4_gal_b1_4_man_p 1.1076923076933667 0.5797101449275363
# LPS28ac_ST_p 0.16138673042432872 0.1593625498007968
# OA28ac_ST_p 0.28954423592494893 0.23809523809523808
# LPS6_14_ST_p 0.1836110166610034 0.1809954751131222
# OA6_14_ST_p 0.3698630136985912 0.2898550724637681
# udcdpglcnac_b1_3_gal_a1_4_glcnac_b1_4_gal_b1_4_rib_c 0.980036297640666 0.5454545454545454
# udcdpglcnac_a1_3_galnac_b1_3_gal_b1_3_glcnac_a1_4_glc_c 0.9374999999854907 0.5309734513274336
# udcdpgalnac_a13_gal_b1_3_b13_gal_a12_c 0.9557522123894557 0.5357142857142857
# LPS57_ST_e 0.16138673042440504 0.1593625498007968
# LPS57_ST_p 0.1613867304243901 0.1593625498007968
# OA28ab_ST_p 0.21386138613862615 0.19230769230769232
# LPS65_ST_e 0.17815902342469175 0.17569546120058566
# LPS7_ST_e 0.18361101666102908 0.1809954751131222
# udcdpglcnac_a1_3_gal_a1_2_rmn_a1_2_rmn_b1_2_mannac_c 0.9557522123893136 0.5357142857142857
# udcdpglcnac_a1_3_gal_a1_2_rmn_a1_2_rmn_b1_2_mannac_p 0.9557522123906982 0.5357142857142857
# LPS35_ST_e 0.16408386507639094 0.16150740242261102
# LPS35_ST_p 0.16408386508659326 0.16150740242261102
# udcdpgal_a1_3_rmn_a1_4_man_a1_3_abe_c 1.1332633788037327 0.5853658536585367
# LPS30_ST_e 0.17612524461839785 0.17106200997861726
# LPS13_ST_p 0.1771362965392787 0.1744186046511628
# OA13_ST_p 0.3444976076554909 0.2733485193621868
# OA35__L_p 0.06674907292954231 0.06472491909385114
# LPS39_ST_p 0.17612524461838872 0.17316017316017315
# OA39_ST_p 0.34069400630923147 0.2702702702702703
# udcpdpglcnac_a1_3_galnac_b1_3_gal_a1_2_fuc_c 1.0682492581602503 0.5687203791469194
# udcpdpglcnac_a1_3_galnac_b1_3_gal_a1_2_fuc_p 1.0682492581606695 0.5687203791469194
# OA48_ST_p 0.3385579937304258 0.2702702702702703
# udcpdpgalnac_a1_3_fucnam_a2_3_neu5acOac_p 1.056751467710427 0.5660377358490566
# OA45_ST_p 0.2608695652173871 0.2247191011235955
# LPS18_ST_p 0.18361101666096147 0.1809954751131222
# OA18_ST_p 0.3698630136986375 0.2898550724637681
# LPS63_ST_e 0.1579640193067672 0.15625
# LPS63_ST_p 0.1579640193067282 0.15625
# OA63_ST_p 0.27870967741938557 0.23121387283236994
# OA48__L_p 0.0769779044903415 0.07481296758104738
# LPS30__L_e 0.06460489322244467 0.06310807257428346
# LPS30__L_p 0.06460489322246758 0.06310807257428346
# udcdpgalnac_a1_3_fuc_a1_3_man_a1_6_galnac_a1_3_fuc_c 0.9557522123893472 0.5357142857142857
# OA13__L_p 0.078516902944383 0.0759974667511083
# udcdpglcnac_a1_3_gal_b1_3_glcnac_a1_4_glc_a1_6_glc_p 0.9963099630996313 0.5607476635514018
# OA58_ST_p 0.3059490084985756 0.24793388429752067
# udcdpglcnac_a1_3_quinac_a1_3_glcnac_b1_6_quinac_p 0.9908256880732906 0.5454545454545454
# OA16_ST_p 0.28954423592493467 0.23809523809523808
# udcdpgalnac_a1_3_fuc_a1_3_man_a1_6_galnac_a1_3_fuc_p 0.955752212389342 0.5357142857142857
# LPS48_ST_p 0.17555266579974027 0.17316017316017315
# LPS30_ST_p 0.1761252446182187 0.17106200997861726
# OA30_ST_p 0.34069400630916025 0.2687569988801792
# udcdpgalnac_a13_gal_b1_3_b13_gal_a12_p 0.9557522123899673 0.5357142857142857
# LPS65_ST_p 0.17815902342458664 0.17569546120058566
# OA65_ST_p 0.34838709677424506 0.2764976958525346
# OA4__L_p 0.08776919951243599 0.08397480755773268
# OA47_ST_p 0.35064935064938896 0.2764976958525346
# udcdpglcnac_a1_3_fucnam_a1_3_gal_O_6_ribt_p 1.0800000000011907 0.5714285714285714
# LPS1_3_19_ST_p 0.20861502800850054 0.2040816326530612
# udcpdglcnac_b1_3_man_a1_2_man_a1_2_man_p 1.115702479338828 0.5825242718446602
# LPS48_ST_e 0.17555266579969353 0.17316017316017315
# OA38__L_p 0.06593406593405092 0.06472491909385114
# OA9_46_ST_p 0.37961335676482694 0.293398533007335
# LPS3_10_ST_p 0.2016053761433696 0.19736842105263158
# LPS30_VL_e 0.01886726529471389 0.018745606498476917
# LPS30_VL_p 0.018867265294711714 0.018745606498476917
# udcdpgal_a1_3_rmn_a1_4_manac_p 1.2514484356894608 0.6153846153846154
# udcdpglcnac_a1_3_gal_b1_3_glcnac_a1_4_glc_a1_6_glc_c 0.9963099630996268 0.5607476635514018
# udcdpgal_a1_3_rmn_a1_4_man_a1_3_par_p 1.1332633788037825 0.5853658536585367
# udcdpglcnac_b1_3_gal_a1_2_fuc_b1_4_rib_a1_3_fuc_b1_4_glc_c 0.9183673469387346 0.5309734513274336
# LPS52_ST_p 0.1648351648351536 0.1637107776261937
# OA52_ST_p 0.30083565459634654 0.24793388429752067
# LPS42_ST_e 0.1613867304242892 0.1593625498007968
# LPS42_ST_p 0.16138673042435886 0.1593625498007968
# udcpdglcnac_b1_3_man_a1_2_man_a1_2_man_c 1.1157024793388644 0.5825242718446602
# udcdpglcnac_a1_3_rmn_a1_2_rmn_a1_3_rmn_a1_2_galnacan_c 0.9617097061442337 0.5381165919282511
# udcdpglcnac_a1_3_rmn_a1_2_rmn_a1_3_rmn_a1_2_galnacan_p 0.961709706144461 0.5381165919282511
# LPS4_ST_e 0.18598243499224765 0.182370820668693
# LPS9_46_ST_p 0.18598243499228495 0.182370820668693
# udcpdpgalnac_a1_3_fucnam_a2_3_neu5ac_c 1.0953346855997286 0.576923076923077
# udcdpglcnac_a1_3_galnac_b1_3_gal_b1_3_glcnac_a1_4_glc_p 0.9374999999998863 0.5309734513274336
# udcdpgalnac_a1_3_fuc_a1_3_man_a1_3_quinac_c 1.0609037328093753 0.5660377358490566
# udcdpgalnac_a1_3_fuc_a1_3_man_a1_3_quinac_p 1.0609037328094093 0.5660377358490566
# OA66_ST_p 0.2950819672131155 0.24291497975708504
# udcdpgalnac_a1_3_b1_3_glc_a1_4_gal_a1_6_gal_p 0.9677419354838577 0.5405405405405406
# LPS11_ST_e 0.1825249281730521 0.17964071856287425
# LPS11_ST_p 0.18252492817307886 0.17964071856287425
# udcdpglcnac_b1_4_glcnac_a1_3_man_b1_4_man_p 1.0756972111553154 0.5714285714285714
# LPS21_ST_p 0.15877683034401643 0.15727391874180863
# OA21_ST_p 0.28125000000000716 0.23346303501945526
# LPS51_ST_e 0.1587768303441513 0.15727391874180863
# LPS51_ST_p 0.15877683034400794 0.15727391874180863
# OA67_c 0.3808180535951872 0.29556650246305416
# OA67_p 0.3808180535967782 0.29556650246305416
# udcdpgalnac_a1_3_glc_a1_4_rmn_a1_2_rmn_b1_2_glcnac_c 0.9557522123893705 0.5357142857142857
# LPS52_ST_e 0.1648351648351632 0.1637107776261937
# LPS41_ST_e 0.1771362965392927 0.1744186046511628
# LPS40_ST_e 0.1587768303439716 0.15727391874180863
# OA40__L_p 0.0625000000000127 0.06141248720573183
# OA9__L_p 0.08776919951238497 0.08397480755773268
# LPS40_ST_p 0.1587768303440271 0.15727391874180863
# OA40_ST_p 0.28124999999991857 0.23346303501945526
# udcpdglcnac_b1_3_man_a1_2_man_a_2_man_b1_2_man_c 1.1157024793386654 0.5825242718446602
# udcpdglcnac_b1_3_man_a1_2_man_a_2_man_b1_2_man_p 1.1157024793387733 0.5825242718446602
# LPS39_ST_e 0.17612524461839343 0.17316017316017315
# udcdpglcnac_b1_3_gal_a1_2_fuc_b1_4_rib_a1_3_fucac_b1_4_glc_c 0.8910891089108759 0.5217391304347826
# OA50__L_p 0.06455469216975572 0.06302521008403361
# udcdpglcnac_a1_3_galnac_a1_4_glc_b1_6_fuc3nac_b1_3_glc_c 0.9318377911955196 0.5286343612334802
# udcpdglcnac_a1_3_rmn_a1_4_gal_b1_4_man_c 1.107692307692318 0.5797101449275363
# OA51_ST_p 0.2812500000000185 0.23346303501945526
# OA7__L_p 0.08517350157728629 0.08253094910591471
# udcdpgal_a1_3_rmn_a1_4_manac_c 1.251448435689575 0.6153846153846154
# udcdpgalnac_b1_3_glc_b1_2_glcnac_b1_4_gal_b1_4_gal_c 0.9677419354837206 0.5405405405405406
# OA2__L_p 0.0877691995123962 0.08397480755773268
# OA62__L_p 0.06523708849289131 0.06386375731772219
# LPS67_e 0.18627112797515336 0.183206106870229
# LPS21_ST_e 0.1587768303440185 0.15727391874180863
# OA30__L_p 0.07851690294438309 0.07423445716053201
# OA8__L_p 0.06747891283975889 0.06560962274466922
# LPS54_e 0.1721389862927345 0.17167381974248927
# LPS54_p 0.17213898629253777 0.17167381974248927
# OA54_p 0.3260869565217377 0.26666666666666666
# OA44_ST_p 0.3085714285713948 0.2643171806167401
# OA6_14__L_p 0.08517350157728742 0.08253094910591471
# OA42__L_p 0.06455469216975415 0.06302521008403361
# OA56__L_p 0.07114624505929638 0.06841505131128849
# udcdpgal_b1_3_galf_a1_3_gal_c 1.317073170732557 0.631578947368421
# LPS18_ST_e 0.18361101666097568 0.1809954751131222
# OA11_ST_p 0.36548223350248477 0.2863961813842482
# OA66__L_p 0.06593406593406315 0.06472491909385114
# udcdpgal_a1_3_man_c 1.5254237288183021 0.6741573033707865
# LPS9_ST_e 0.18598243499224687 0.182370820668693
# LPS6_14_ST_e 0.18361101666099935 0.1809954751131222
# OA65__L_p 0.07952871870398383 0.07722007722007722
# LPS66_ST_e 0.16309272123226182 0.16150740242261102
# LPS66_ST_p 0.16309272123225094 0.16150740242261102
# udcdpglcnac_a1_3_gal_a1_4_glc_a1_3col_a1_6col_c 0.9747292418775858 0.5405405405405406
# LPS13_ST_e 0.17713629653924273 0.1744186046511628
# metsox_S__L_c 9.07563025209447 8.571428571428571
# o16a4und_p 0.35386631716903594 0.27906976744186046
# o16a3und_p 0.4483188044830873 0.332409972299169
# o16aund_c 0.9617097061443807 0.5381165919282511
# gfgaragund_c 1.0682492581602503 0.5687203791469194
# 2hpmmbq_m 1.202672605790743 1.188118811881188
# 2mbald_m 10.909090909088832 8.571428571428571
# 2mbtoh_m 9.999999999998067 8.0
# 3hph5mb_m 1.2371134020619383 1.2
# lanost_e 1.483516483516496 1.4285714285714284
# lanostest_SC_c 0.025091479351796116 0.025039123630672924
# udcdp5Oag_p 0.3796133567663721 0.293398533007335
# udcdp6Oag_p 0.3254972875226567 0.2608695652173913
# udcdp7Oag_p 0.2848852545501966 0.23483365949119372
# udcdp10Oag_p 0.20729366602686988 0.18072289156626506
# udcdp11Oag_p 0.19004047158191414 0.16783216783216784
# dptne_c 1.4979195561720549 1.4117647058823528
# neuspn_c 1.1428571428570962 1.1009174311926606
# 13_cis_retnglc_e 1.9529837251356525 1.935483870967742
# mpdol__L_c 0.03616394320921834 0.03454231433506045
# g3m8mpdol__L_r 0.025602124028070408 0.025031289111389236
# doldp_U_r 0.04274688303979896 0.041666666666666664
# dolmanp__L_c 0.04020250148897625 0.03804692454026633
# m8mpdol_U_r 0.028704318936877717 0.02803738317757009
# g1m8mpdol_U_r 0.02787456445992398 0.027272727272727275
# m4mpdol__L_r 0.03144654088050571 0.030349013657056147
# m7mpdol_U_r 0.02958498835775887 0.028846153846153848
# m2mpdol_U_c 0.03494580165022309 0.033707865168539325
# m4mpdol__L_c 0.03144654088049558 0.030349013657056147
# m1mpdol_U_c 0.03625986234681646 0.03488372093023256
# ipdp_r 8.780487804876998 8.571428571428571
# 13_cis_oretn_c 2.37362637362628 2.3529411764705883
# retn_n 2.373626373635034 2.307692307692308
# grdp_h 4.462809917350739 4.285714285714286
# acaro_u 1.134453781512739 1.1111111111111112
# gcarote_u 1.1344537815125832 1.1111111111111112
# cyeuol_c 1.4342629482070495 1.4285714285714284
# obfool_c 1.4342629482072091 1.4285714285714284
# 23dmphol_h 1.5606936416180643 1.5384615384615385
# zxan_u 1.1261730969760464 1.1214953271028036
# crpxan_u 1.1261730969762311 1.1214953271028036
# ecaro_h 1.1344537815126503 1.1111111111111112
# scys__L_h 14.794520547959394 13.333333333333332
# cyst__L_h 7.883211678836005 7.058823529411765
# mercppyr_h 20.00000000000054 15.0
# cpp3_h 1.592920353982393 1.5094339622641508
# 3mtp_c 9.642857142859452 8.571428571428571
# hemeC_c 1.315468940316748 1.3043478260869565
# ala_L_met__L_c 6.242774566474964 5.7142857142857135
# ser_L_met__L_c 6.506024096385733 6.0
# met_L_phe__L_c 3.517915309449762 3.428571428571429
# met_L_tyr__L_c 3.6000000000008043 3.5294117647058827
# gly_cys__L_c 11.999999999999488 10.0
# metox_c 9.075630252098563 8.571428571428571
# cysam_e 14.025974025974733 13.333333333333332
# m6mpdol_r 0.4485049833887315 0.31331592689295035
# CE2251_c 1.2026726057904398 1.2
# CE2242_c 1.1261730969765722 1.1214953271028036
# CE1761_c 2.2689075630248112 2.2641509433962264
# CE1761_r 2.2689075630250386 2.2641509433962264
# CE5014_c 2.302771855010292 2.2222222222222223
# CE7047_c 1.5606936416178314 1.5584415584415585
# CE6219_c 1.5606936416183999 1.5584415584415585
# CE7101_c 1.560693641618215 1.5584415584415585
# ptth_m 4.408163265305575 4.137931034482759
# HC02121_c 5.654450261780312 5.217391304347826
# 2h3mb_c 10.0 7.058823529411765
# acmet_c 6.967741935484469 6.315789473684211
# udcpgl_c 1.8120805369186122 0.7228915662650602
# phyto_c 1.134453781513049 1.0714285714285714
# phptna_c 0.8866995073892576 0.8823529411764707
# npdp_m 1.0046511627916823 0.9523809523809523
# 3odocoscoa_c 1.1344537815120739 1.1320754716981132
# 3hdcscoa_c 1.1261730969764305 1.1214953271028036
# ocdccoa_m 1.2587412587411109 1.25
# 3ohodcoa_m 1.2796208530813828 1.276595744680851
# m7mpdol_c 0.4285714285714345 0.42402826855123676
# npdp_h 1.0046511627911485 0.9523809523809523
# 3nphb_m 0.8962655601662117 0.8571428571428572
# 3npdhb_m 0.8910891089106698 0.8633093525179857
# 2np6mobq_m 0.8730800323363088 0.8571428571428572
# me2np6mobq_m 0.8557844690966725 0.8391608391608392
# 2npmhmobq_m 0.8510638297868912 0.8450704225352113
# 2c4mthzep_h 7.297297297297746 7.058823529411765
# cthzp_h 7.297297297297064 7.058823529411765
# pcholole_hs_e 1.7910447761200672 1.6551724137931034
# peole_hs_e 2.0689655172429298 1.9047619047619047
# pailste_hs_e 1.8461538461548344 1.6901408450704225
# pcholn1836_hs_e 1.7910447761200394 1.702127659574468
# pcholn281_hs_e 1.7910447761196242 1.1707317073170733
# sphmyln18121_hs_c 1.0810810810811269 0.9486166007905138
# sphmyln18117_hs_c 1.0810810810811518 1.0480349344978166
# pe2linl_hs_c 2.0689655172411676 1.935483870967742
# pchol2ste_hs_c 1.791044776119681 1.6326530612244896
# pcholn203_hs_c 1.7910447761193793 1.5686274509803921
# pcholhep_hs_c 1.7910447761330488 1.702127659574468
# 3mtp_e 9.642857142856997 8.571428571428571
# docohxeth_e 2.068965517241395 1.9047619047619047
# sphmyln18121_hs_e 1.0810810810806806 0.9486166007905138
# asnphecys_e 3.5643564356435036 3.428571428571429
# cysgluhis_e 4.320000000000027 4.285714285714286
# cysglutrp_e 3.0252100840356877 2.926829268292683
# glumet_e 5.454545454549418 5.0
# metargleu_e 3.0594900849856876 2.926829268292683
# metglntyr_e 2.879999999999999 2.7906976744186047
# proargcys_e 4.1064638783264655 3.870967741935484
# proasncys_e 4.999999999982151 4.615384615384616
# thrtyrmet_e 2.903225806451035 2.8571428571428568
# asncyscys_c 6.000000000002212 5.0
# asnphecys_c 3.5643564356435653 3.428571428571429
# cysgluhis_c 4.3199999999991405 4.285714285714286
# glumet_c 5.454545454548281 5.0
# hiscyscys_c 4.655172413794617 4.285714285714286
# metargleu_c 3.059490084985441 2.926829268292683
# metglntyr_c 2.8799999999998844 2.7906976744186047
# proasncys_c 4.999999999999801 4.615384615384616
# sercysarg_c 5.167464114833535 4.8
# thrtyrmet_c 2.9032258064515455 2.8571428571428568
# Lhcystin_c 5.966850828729434 5.217391304347826
# 13_cis_retn_e 2.3736263736263936 2.307692307692308
# CE2243_m 1.1933701657458187 1.188118811881188
# dolichol__L_e 0.04188644120383742 0.03955174686882004
# pepm_c 0.8095952023988744 0.48289738430583495
# updpamaglaa_c 1.0179076343069982 0.5517241379310345
# PG__L_w 0.026873693639891793 0.026797677534613665
# 2m6solbzq_c 0.8962655601660171 0.8450704225352113
# 2dmmq4_c 1.5929203539822083 1.5384615384615385
# mqn4_c 1.5362731152205242 1.4814814814814814
# dol11manp_c 1.8030050083473128 0.718562874251497
# naglc2p_L_dolp11_c 1.690140845070431 0.7017543859649122
# naglc2p_L_dolp12_c 0.6788183532366624 0.6486486486486487
# chito2pdol_L_dolp11_c 1.3722998729351445 0.6417112299465242
# trpox_c 2.0650095602298393 2.0
# trprd_c 2.065009560229729 1.9672131147540983
# d12h5mtp_c 7.248322147650924 7.058823529411765
# lacgth_c 4.757709251102824 4.444444444444445
# ival_c 17.142857142856656 9.230769230769232
# ival_e 17.14285714285529 9.230769230769232
# rhma13unaga_c 1.4304635761589433 0.6557377049180328
# 3_rhma13unaga_c 1.0789210789210983 0.5741626794258373
# OA3_10__L_p 0.10740924912979154 0.10178117048346057
# LPS17_ST_e 0.2016053761433625 0.19736842105263158
# OA21__L_p 0.06250000000001163 0.06141248720573183
# LPS55_ST_p 0.17612524461826431 0.17378711078928313
# udcpdpgalnac_a1_3_fucnam_a2_3_neu5acOac_c 1.0567514677263432 0.5660377358490566
# OA3_10_ST_p 0.45093945720254536 0.3342618384401114
# OA57_ST_p 0.28954423592465445 0.23809523809523808
# LPS50_ST_e 0.16138673042439677 0.1593625498007968
# LPS50_ST_p 0.1613867304243237 0.1593625498007968
# udcdpgalnac_b1_3_man_a1_2_man_a1_2_man_p 1.1157024793389456 0.5825242718446602
# OA62_ST_p 0.2922868741542634 0.24048096192384769
# LPS43_ST_e 0.16223524109957455 0.16042780748663105
# LPS43_ST_p 0.16223524109952336 0.16042780748663105
# LPS58_ST_e 0.16635859519408702 0.1637107776261937
# LPS58_ST_p 0.16635859519420496 0.1637107776261937
# LPS67_p 0.1862711279752056 0.183206106870229
# udcdpgalnac_a1_3_b1_3_glc_a1_4_gal_a1_6_gal_c 0.9677419354838623 0.5405405405405406
# udcdpglcnac_b1_4_glcnac_a1_3_man_b1_4_man_c 1.0756972111554726 0.5714285714285714
# OA1_3_19__L_p 0.11796832332059591 0.11121408711770157
# udcdpgal_a1_3_rmn_a1_4_man_a1_3_abe_p 1.133263378837981 0.5853658536585367
# LPS28ac_ST_e 0.16138673042433993 0.1593625498007968
# OA56_ST_p 0.3157894736840035 0.25316455696202533
# OA39__L_p 0.07753050969130745 0.07481296758104738
# udcdpglcnac_b1_3_glc_a1_4_fuc_a1_3_acper_c 1.0609037328094368 0.5673758865248226
# OA60_ST_p 0.35880398671096714 0.2830188679245283
# OA17__L_p 0.10740924912979231 0.10178117048346057
# udcdpglcnac_a1_3_rmn_b1_4_galnac_a1_4_galf_p 1.0682492581602787 0.5687203791469194
# OA59_ST_p 0.3444976076555975 0.2733485193621868
# udcdpglcnac_b1_6_mannac_b1_3_mannac_b1_4_10_c 0.32608695652165665 0.26666666666666666
# udcdpglcnac_b1_6_mannac_c 1.4099216710221327 0.6521739130434783
# udcdpglcnac_a1_3_rmn_b1_4_galnac_a1_4_galf_c 1.0682492581606298 0.5687203791469194
# udcdpglcnac_a1_3_rmn_a1_4_glcnac_b1_3_gal_c 1.0682492581602336 0.5687203791469194
# udcdpglcnac_a1_3_quinac_a1_3_glcnac_b1_6_quinac_c 0.9908256880734143 0.5454545454545454
# LPS55_ST_e 0.1761252446183832 0.17378711078928313
# udcdpgalnac_b1_3_glc_b1_4_man_b1_2_glcnac_a1_3_galnac_p 0.9374999999999787 0.5309734513274336
# OA4_ST_p 0.3796133567661059 0.293398533007335
# OA55_ST_p 0.34069400630916297 0.2718006795016987
# OA8_ST_p 0.30125523012551514 0.24539877300613497
# LPS9_46_ST_e 0.18598243499225475 0.182370820668693
# OA50_ST_p 0.28954423592468237 0.23809523809523808
# LPS60_ST_p 0.18084393837913934 0.17830609212481424
# OA58__L_p 0.06865861411315934 0.06651884700665188
# OA42_ST_p 0.289544235924943 0.23809523809523808
# udcdpglcnac_b1_3_glc_c 1.4516129032258789 0.6593406593406593
# udcdpgalnac_b1_3_man_a1_2_man_a1_2_man_c 1.115702479338747 0.5825242718446602
# LPS53_ST_e 0.17713629653934504 0.1744186046511628
# LPS53_ST_p 0.17713629653927576 0.1744186046511628
# LPS16_ST_e 0.16138673042445362 0.1593625498007968
# udcdpglcnac_a1_3_galnac_b1_3_gal_a1_3_gal_a1_2_fuc_c 0.9617097061442241 0.5381165919282511
# udcdpglcnac_a1_3_fucnam_a1_3_gal_O_6_ribt_c 1.0799999999998173 0.5714285714285714
# udcdpgalnac_b1_3_glc_b1_4_man_b1_2_glcnac_a1_3_galnac_c 0.9374999999999893 0.5309734513274336
# LPS2_ST_e 0.18598243499215528 0.182370820668693
# LPS4_ST_p 0.1859824349922965 0.182370820668693
# OA60__L_p 0.08225437928408326 0.07978723404255318
# LPS16_ST_p 0.16138673042439677 0.1593625498007968
# OA53_ST_p 0.3444976076554684 0.2733485193621868
# LPS1_3_19_ST_e 0.20861502800856613 0.2040816326530612
# LPS60_ST_e 0.18084393837913737 0.17830609212481424

# %%
# Determining reactions leading to incorrect metabolic pathways

end_rxn_list = []
with model:
    for target_product in over_yield_end:
        objective_reaction = 'ADD_'+target_product
        if objective_reaction in model.reactions:
            model.objective = objective_reaction
            rxn_grate[objective_reaction] = 0
        else:
            add_rxn(model,objective_reaction,target_product + ' --> ') #加入目标函数反应
            model.objective = objective_reaction
            rxn_grate[objective_reaction] = 0
        solution = model.optimize()
        constraint_value = max_reduced_degree_rate(model,target_product)

        if constraint_value > 0 and not math.isnan(constraint_value):
            if (solution.fluxes[objective_reaction] - max_reduced_degree_rate(model,target_product))>1e-6:
                
                grate_delete_rxn = find_infinite_rxn(model,objective_reaction,constraint_value,rxn_grate)
                outputfile = 'results/quality_control/pathway/'
                end_rxn = locating_rxn(model,check_model,objective_reaction,constraint_value,grate_delete_rxn,outputfile,unbalance_rxn)
                for ri in end_rxn:
                    end_rxn_list.append(ri)
# Out:
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# 2
# MECDPDH: 2mecdp_c + h_c --> h2mb4p_c + h2o_c 4
# ARTCOAL2 1
# ARTCOAL1 2
# MECDPDH 3
# MECDPDH: 2mecdp_c + h_c --> h2mb4p_c + h2o_c unbalance {'charge': -2.0}
# 1
# NP1_2: nicrns_c + pi_c --> nac_c + r1p_c 5
# SULRR2: h_c + nadph_c + so3_c --> h2o_c + h2s_c + nadp_c 5
# 2
# SULRR: h_c + nadh_c + so3_c --> h2o_c + h2s_c + nad_c 5
# NP1_2 1
# SULRR2 2
# SULRR2: h_c + nadph_c + so3_c --> h2o_c + h2s_c + nadp_c unbalance {'charge': 2.0, 'H': 2.0, 'O': -2.0}
# SULRR 3
# SULRR: h_c + nadh_c + so3_c --> h2o_c + h2s_c + nad_c unbalance {'charge': 2.0, 'H': 2.0, 'O': -2.0}
# 1
# FDIPDC: frdp_c + ipdp_c --> ppi_c + udcpdp_c 5
# FDIPDC 1
# FDIPDC: frdp_c + ipdp_c --> ppi_c + udcpdp_c unbalance {'C': 35.0, 'H': 56.0}
# 1
# GLUSfx: akg_c + 2.0 fdxrd_c + gln__L_c + 2.0 h_c --> 2.0 fdxox_c + 2.0 glu__L_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# 2
# GALR1TRA2: gagggicolipaAR1_c + udpgal_c --> colipa_c + h_c + udp_c 4
# HEPKA2: atp_c + hphhlipa_c --> adp_c + h_c + icolipaAR1_c 4
# 3
# MOAT3C_2: ckdo_c + phphhlipa_c --> cmp_c + h_c + icolipa_c 5
# GLUSfx 1
# FNOR_1 2
# GALR1TRA2 3
# HEPKA2 4
# HEPKA2: atp_c + hphhlipa_c --> adp_c + h_c + icolipaAR1_c unbalance {'charge': 10.0, 'H': -20.0}
# MOAT3C_2 5
# MOAT3C_2: ckdo_c + phphhlipa_c --> cmp_c + h_c + icolipa_c unbalance {'C': 6.0, 'H': 10.0, 'O': 4.0}
# 1
# GLUSfx: akg_c + 2.0 fdxrd_c + gln__L_c + 2.0 h_c --> 2.0 fdxox_c + 2.0 glu__L_c 5
# EDTXS_core: 0.6267 lipaA_p + 0.05 lipaB_p + 0.3133 lipaF_p --> lipa_p 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# EDTXSF120: lipaA_p + pa120_p --> 12dgr120_p + lipaF_p 5
# GLUSfx 1
# EDTXS_core 2
# EDTXS_core: 0.6267 lipaA_p + 0.05 lipaB_p + 0.3133 lipaF_p --> lipa_p unbalance {'charge': nan, 'C': 1.1999999999999886, 'H': 2.1599999999999966, 'N': 0.019999999999999796, 'O': -0.5499000000000009, 'P': -0.29330000000000034}
# FNOR_1 3
# EDTXSF120 4
# 1
# GLGE: malt1p_c --> 2.0 14glucan_c + pi_c 5
# 2
# AMYL2: adpglc_c --> 14glucan_c + adp_c + h_c 5
# GLGE 1
# GLGE: malt1p_c --> 2.0 14glucan_c + pi_c unbalance {'H': 2.0, 'R': 2.0}
# AMYL2 2
# AMYL2: adpglc_c --> 14glucan_c + adp_c + h_c unbalance {'H': 1.0, 'R': 1.0}
# 1
# GLUSfx: akg_c + 2.0 fdxrd_c + gln__L_c + 2.0 h_c --> 2.0 fdxox_c + 2.0 glu__L_c 5
# CLGAL: atp_c + cobya_c + gln__L_c + h2o_c --> adp_c + co2dam_c + glu__L_c + pi_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# PGAL: h2o_c + 4.0 ppbng_c --> hmbil_c + 4.0 nh4_c 5
# ACARP: adocbl_c + h2o_c --> adcobdam_c + pi_c 5
# GLUSfx 1
# CLGAL 2
# FNOR_1 3
# PGAL 4
# ACARP 5
# ACARP: adocbl_c + h2o_c --> adcobdam_c + pi_c unbalance {'charge': -6.0, 'C': -17.0, 'H': -33.0, 'N': -7.0, 'O': 1.0}
# 1
# THZPSN2_SC: achms_c + cys__L_c + gly_c + h_c + r5p_c --> 4abut_c + 4mpetz_c + ac_c + co2_c + 3.0 h2o_c + nh4_c + pyr_c 5
# 2
# THZPSN1_SC: achms_c + cys__L_c + gly_c + h_c + xu5p__D_c --> 4abut_c + 4mpetz_c + ac_c + co2_c + 3.0 h2o_c + nh4_c + pyr_c 4
# THZPSN2_SC 1
# THZPSN2_SC: achms_c + cys__L_c + gly_c + h_c + r5p_c --> 4abut_c + 4mpetz_c + ac_c + co2_c + 3.0 h2o_c + nh4_c + pyr_c unbalance {'charge': -2.0}
# THZPSN1_SC 2
# THZPSN1_SC: achms_c + cys__L_c + gly_c + h_c + xu5p__D_c --> 4abut_c + 4mpetz_c + ac_c + co2_c + 3.0 h2o_c + nh4_c + pyr_c unbalance {'charge': -2.0}
# 1
# 3MOPDC_2: 3mob_c + 3.0 h_c --> 2mbald_c + co2_c 5
# 2
# SR4: 2mbald_c + coa_c + nad_c --> 3.0 h_c + ibcoa_c + nadh_c 5
# 3MOPDC_2 1
# 3MOPDC_2: 3mob_c + 3.0 h_c --> 2mbald_c + co2_c unbalance {'charge': -2.0, 'C': 1.0}
# SR4 2
# SR4: 2mbald_c + coa_c + nad_c --> 3.0 h_c + ibcoa_c + nadh_c unbalance {'charge': 2.0, 'C': -1.0}
# 1
# DHDDS_c: frdp_c + 8.0 ipdp_c --> dedoldp_c + 8.0 ppi_c 5
# 2
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# DEDOLDPS: 7.0 ipdp_c + ttc_ggdp_c --> dedoldp_c + 7.0 ppi_c 5
# DHDDS_c 1
# DHDDS_c: frdp_c + 8.0 ipdp_c --> dedoldp_c + 8.0 ppi_c unbalance {'C': 40.0, 'H': 64.0}
# ARTCOAL1 2
# DEDOLDPS 3
# DEDOLDPS: 7.0 ipdp_c + ttc_ggdp_c --> dedoldp_c + 7.0 ppi_c unbalance {'C': 40.0, 'H': 64.0}
# 1
# MX15PSL: 2h3k5m_c + h_c --> ch4s_c + dxyl5p_c 5
# DM1PE_2: 5mdru1p_c --> 2h3k5m_c 5
# MX15PSL 1
# MX15PSL: 2h3k5m_c + h_c --> ch4s_c + dxyl5p_c unbalance {'H': 4.0, 'O': 1.0}
# DM1PE_2 2
# 1
# UDCPRT: dtdprmn_c + udcpg_c --> dtdp_c + h_c + udcpgr_c 5
# OA4VL_ST: 100.0 udcpo4_p --> OA_ST_p + 99.0 h_p + 99.0 udcpdp_p 5
# GLUSfx: akg_c + 2.0 fdxrd_c + gln__L_c + 2.0 h_c --> 2.0 fdxox_c + 2.0 glu__L_c 5
# OA4L_ST: 25.0 udcpo4_p --> OA_ST_p + 24.0 h_p + 24.0 udcpdp_p 5
# MECDPDHf: 2mecdp_c + 2.0 fdxrd_c + h_c --> 2.0 fdxox_c + h2mb4p_c + h2o_c 5
# HEPTA2: adphep_LD_c + hlipaA_c --> adp_c + h_c + hhlipaA_c 5
# HEPTA3: adphep_LD_c + phhlipaA_c --> adp_c + h_c + hphhlipa_c 5
# OALmin_ST: OA_STmin_p + colipamin_p --> colipaOAmin_e + h_p + udcpdp_p 5
# OA4VLmin_ST: 100.0 udcpo4min_p --> OA_STmin_p + 99.0 h_p + 99.0 udcpdp_p 5
# UDCPRT 1
# OA4VL_ST 2
# OA4VL_ST: 100.0 udcpo4_p --> OA_ST_p + 99.0 h_p + 99.0 udcpdp_p unbalance {'charge': 2.0, 'H': -4290.0, 'C': -2455.0, 'O': -1707.0, 'P': -2.0}
# GLUSfx 3
# OA4L_ST 4
# MECDPDHf 5
# HEPTA2 6
# HEPTA3 7
# OALmin_ST 8
# OA4VLmin_ST 9
# 1
# MBTA1: acac_c + h_c + n6hlys_c + n6hlysmal_c + nadh_c + salc_c + thr__L_c --> 6.0 h2o_c + mcbtt_c + nad_c 5
# MBTA1 1
# MBTA1: acac_c + h_c + n6hlys_c + n6hlysmal_c + nadh_c + salc_c + thr__L_c --> 6.0 h2o_c + mcbtt_c + nad_c unbalance {'charge': nan, 'C': 13.0, 'H': 32.0, 'O': -2.0}
# 1
# GGT_L: 17.6 ipdp_c + ttc_ggdp_c --> 0.1 dedoldp__L_c + 17.6 ppi_c 5
# HMR_7255: dedoldp__L_c + 20.0 h_c --> doldp__L_c 5
# GGT_L 1
# HMR_7255 2
# HMR_7255: dedoldp__L_c + 20.0 h_c --> doldp__L_c unbalance {'charge': -20.0}
# 1
# HPYRR2x_1: 3.0 h_c + 2.0 hpyr_c + nadh_c --> 2.0 glyc__S_c + nad_c 5
# HPYRR2x_1 1
# HPYRR2x_1: 3.0 h_c + 2.0 hpyr_c + nadh_c --> 2.0 glyc__S_c + nad_c unbalance {'charge': -2.0}
# 1
# AGPAT18111Z160h: 1odec11eg3p_h + palmACP_h --> ACP_h + pa18111Z160_h 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# AGPAT18111Z160h 1
# AGPAT18111Z160h: 1odec11eg3p_h + palmACP_h --> ACP_h + pa18111Z160_h unbalance {'charge': -1.0}
# FNOR_1 2
# 1
# 2H3MBDH: 3mob_c + h_c + nadh_c --> 2h3mb_c + nad_c 5
# 2H3MBDH 1
# 2H3MBDH: 3mob_c + h_c + nadh_c --> 2h3mb_c + nad_c unbalance {'charge': -2.0, 'C': 1.0, 'H': -1.0, 'O': 3.0, 'P': 1.0, 'S': 1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLSTE_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholste_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT15e: chsterol_e + pchol_hs_e --> pcholste_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLSTE_HSPLA2 3
# PCHOLSTE_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholste_hs_c unbalance {'C': 17.0, 'R': -1.0, 'H': 36.0}
# HMR_0653 4
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# LCAT15e 8
# LCAT15e: chsterol_e + pchol_hs_e --> pcholste_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 36.0, 'R': -1.0}
# ARTCOAL1 9
# 1
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT16e: chsterol_e + pe_hs_e --> peste_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# ARTPLM2 1
# CHOLESTle_1 2
# LCAT16e 3
# LCAT16e: chsterol_e + pe_hs_e --> peste_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 35.0, 'R': -1.0}
# ARTCOAL1 4
# FNOR_1 5
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# PCHOL2LINL_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pchol2linl_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT18e: chsterol_e + pchol_hs_e --> pchol2linl_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# HMR_0653 3
# PCHOL2LINL_HSPLA2 4
# PCHOL2LINL_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pchol2linl_hs_c unbalance {'C': 17.0, 'R': -1.0, 'H': 32.0}
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# LCAT18e 8
# LCAT18e: chsterol_e + pchol_hs_e --> pchol2linl_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 32.0, 'R': -1.0}
# ARTCOAL1 9
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# PE2LINL_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pe2linl_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT19e: chsterol_e + pe_hs_e --> pe2linl_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# FNOR_1 3
# PE2LINL_HSPLA2 4
# PE2LINL_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pe2linl_hs_c unbalance {'C': 17.0, 'R': -1.0, 'H': 31.0}
# ARTPLM2 5
# CHOLESTle_1 6
# LCAT19e 7
# LCAT19e: chsterol_e + pe_hs_e --> pe2linl_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 31.0, 'R': -1.0}
# ARTCOAL1 8
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLN19_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn19_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT32e: chsterol_e + pchol_hs_e --> pcholn19_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLN19_HSPLA2 3
# PCHOLN19_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn19_hs_c unbalance {'C': 18.0, 'R': -1.0, 'H': 38.0}
# ARTPLM2 4
# CHOLESTle_1 5
# LCAT32e 6
# LCAT32e: chsterol_e + pchol_hs_e --> pcholn19_hs_e + xolest2_hs_e unbalance {'C': 18.0, 'H': 38.0, 'R': -1.0}
# ARTCOAL1 7
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# PCHOLN201_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn201_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT33e: chsterol_e + pchol_hs_e --> pcholn201_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# HMR_0653 3
# PCHOLN201_HSPLA2 4
# PCHOLN201_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn201_hs_c unbalance {'C': 19.0, 'R': -1.0, 'H': 38.0}
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# LCAT33e 8
# LCAT33e: chsterol_e + pchol_hs_e --> pcholn201_hs_e + xolest2_hs_e unbalance {'C': 19.0, 'H': 38.0, 'R': -1.0}
# ARTCOAL1 9
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLN205_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn205_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT35e: chsterol_e + pchol_hs_e --> pcholn205_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLN205_HSPLA2 3
# PCHOLN205_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn205_hs_c unbalance {'C': 19.0, 'R': -1.0, 'H': 30.0}
# HMR_0653 4
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# LCAT35e 8
# LCAT35e: chsterol_e + pchol_hs_e --> pcholn205_hs_e + xolest2_hs_e unbalance {'C': 19.0, 'H': 30.0, 'R': -1.0}
# ARTCOAL1 9
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# PCHOLN224_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn224_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT36e: chsterol_e + pchol_hs_e --> pcholn224_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# HMR_0653 3
# PCHOLN224_HSPLA2 4
# PCHOLN224_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn224_hs_c unbalance {'C': 21.0, 'R': -1.0, 'H': 36.0}
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# LCAT36e 8
# LCAT36e: chsterol_e + pchol_hs_e --> pcholn224_hs_e + xolest2_hs_e unbalance {'C': 21.0, 'H': 36.0, 'R': -1.0}
# ARTCOAL1 9
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PE203_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pe203_hs_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT40e: chsterol_e + pe_hs_e --> pe203_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PE203_HSPLA2 3
# PE203_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pe203_hs_c unbalance {'C': 19.0, 'R': -1.0, 'H': 33.0}
# FNOR_1 4
# ARTPLM2 5
# CHOLESTle_1 6
# LCAT40e 7
# LCAT40e: chsterol_e + pe_hs_e --> pe203_hs_e + xolest2_hs_e unbalance {'C': 19.0, 'H': 33.0, 'R': -1.0}
# ARTCOAL1 8
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# PE226_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pe226_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT41e: chsterol_e + pe_hs_e --> pe226_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# FNOR_1 3
# PE226_HSPLA2 4
# PE226_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pe226_hs_c unbalance {'C': 21.0, 'R': -1.0, 'H': 33.0}
# ARTPLM2 5
# CHOLESTle_1 6
# LCAT41e 7
# LCAT41e: chsterol_e + pe_hs_e --> pe226_hs_e + xolest2_hs_e unbalance {'C': 21.0, 'H': 33.0, 'R': -1.0}
# ARTCOAL1 8
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PE224_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pe224_hs_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT42e: chsterol_e + pe_hs_e --> pe224_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PE224_HSPLA2 3
# PE224_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pe224_hs_c unbalance {'C': 21.0, 'R': -1.0, 'H': 35.0}
# FNOR_1 4
# ARTPLM2 5
# CHOLESTle_1 6
# LCAT42e 7
# LCAT42e: chsterol_e + pe_hs_e --> pe224_hs_e + xolest2_hs_e unbalance {'C': 21.0, 'H': 35.0, 'R': -1.0}
# ARTCOAL1 8
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# PEDH203_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pedh203_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT43e: chsterol_e + pe_hs_e --> pedh203_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# FNOR_1 3
# PEDH203_HSPLA2 4
# PEDH203_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pedh203_hs_c unbalance {'C': 19.0, 'R': -1.0, 'H': 33.0}
# ARTPLM2 5
# CHOLESTle_1 6
# LCAT43e 7
# LCAT43e: chsterol_e + pe_hs_e --> pedh203_hs_e + xolest2_hs_e unbalance {'C': 19.0, 'H': 33.0, 'R': -1.0}
# ARTCOAL1 8
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PEDH17_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pe17_hs_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT48e: chsterol_e + pe_hs_e --> pe17_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PEDH17_HSPLA2 3
# PEDH17_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pe17_hs_c unbalance {'C': 16.0, 'R': -1.0, 'H': 33.0}
# FNOR_1 4
# ARTPLM2 5
# CHOLESTle_1 6
# LCAT48e 7
# LCAT48e: chsterol_e + pe_hs_e --> pe17_hs_e + xolest2_hs_e unbalance {'C': 16.0, 'H': 33.0, 'R': -1.0}
# ARTCOAL1 8
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# PCHOLN203_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn203_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT49e: chsterol_e + pchol_hs_e --> pcholn203_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# HMR_0653 3
# PCHOLN203_HSPLA2 4
# PCHOLN203_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn203_hs_c unbalance {'C': 19.0, 'R': -1.0, 'H': 34.0}
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# LCAT49e 8
# LCAT49e: chsterol_e + pchol_hs_e --> pcholn203_hs_e + xolest2_hs_e unbalance {'C': 19.0, 'H': 34.0, 'R': -1.0}
# ARTCOAL1 9
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLN24_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn24_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT50e: chsterol_e + pchol_hs_e --> pcholn24_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLN24_HSPLA2 3
# PCHOLN24_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn24_hs_c unbalance {'C': 23.0, 'R': -1.0, 'H': 48.0}
# HMR_0653 4
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# LCAT50e 8
# LCAT50e: chsterol_e + pchol_hs_e --> pcholn24_hs_e + xolest2_hs_e unbalance {'C': 23.0, 'H': 48.0, 'R': -1.0}
# ARTCOAL1 9
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLN261_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn261_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT51e: chsterol_e + pchol_hs_e --> pcholn261_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLN261_HSPLA2 3
# PCHOLN261_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn261_hs_c unbalance {'C': 25.0, 'R': -1.0, 'H': 50.0}
# ARTPLM2 4
# CHOLESTle_1 5
# LCAT51e 6
# LCAT51e: chsterol_e + pchol_hs_e --> pcholn261_hs_e + xolest2_hs_e unbalance {'C': 25.0, 'H': 50.0, 'R': -1.0}
# ARTCOAL1 7
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLDOC_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholdoc_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT57e: chsterol_e + pchol_hs_e --> pcholdoc_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLDOC_HSPLA2 3
# PCHOLDOC_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholdoc_hs_c unbalance {'C': 25.0, 'R': -1.0, 'H': 40.0}
# ARTPLM2 4
# CHOLESTle_1 5
# LCAT57e 6
# LCAT57e: chsterol_e + pchol_hs_e --> pcholdoc_hs_e + xolest2_hs_e unbalance {'C': 25.0, 'H': 40.0, 'R': -1.0}
# ARTCOAL1 7
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLDEIC_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholeic_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT5e: chsterol_e + pchol_hs_e --> pcholeic_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLDEIC_HSPLA2 3
# PCHOLDEIC_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholeic_hs_c unbalance {'C': 19.0, 'R': -1.0, 'H': 36.0}
# HMR_0653 4
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# LCAT5e 8
# LCAT5e: chsterol_e + pchol_hs_e --> pcholeic_hs_e + xolest2_hs_e unbalance {'C': 19.0, 'H': 36.0, 'R': -1.0}
# ARTCOAL1 9
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLDET_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholet_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT6e: chsterol_e + pchol_hs_e --> pcholet_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLDET_HSPLA2 3
# PCHOLDET_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholet_hs_c unbalance {'C': 19.0, 'R': -1.0, 'H': 34.0}
# HMR_0653 4
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# LCAT6e 8
# LCAT6e: chsterol_e + pchol_hs_e --> pcholet_hs_e + xolest2_hs_e unbalance {'C': 19.0, 'H': 34.0, 'R': -1.0}
# ARTCOAL1 9
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLHEP_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholhep_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT7e: chsterol_e + pchol_hs_e --> pcholhep_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLHEP_HSPLA2 3
# PCHOLHEP_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholhep_hs_c unbalance {'C': 16.0, 'R': -1.0, 'H': 34.0}
# ARTPLM2 4
# CHOLESTle_1 5
# LCAT7e 6
# LCAT7e: chsterol_e + pchol_hs_e --> pcholhep_hs_e + xolest2_hs_e unbalance {'C': 16.0, 'H': 34.0, 'R': -1.0}
# ARTCOAL1 7
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLLINL_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pchollinl_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT8e: chsterol_e + pchol_hs_e --> pchollinl_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLLINL_HSPLA2 3
# PCHOLLINL_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pchollinl_hs_c unbalance {'C': 17.0, 'R': -1.0, 'H': 32.0}
# ARTPLM2 4
# CHOLESTle_1 5
# LCAT8e 6
# LCAT8e: chsterol_e + pchol_hs_e --> pchollinl_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 32.0, 'R': -1.0}
# ARTCOAL1 7
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PELINL_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pelinl_hs_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# LCAT9e: chsterol_e + pe_hs_e --> pelinl_hs_e + xolest2_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PELINL_HSPLA2 3
# PELINL_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pelinl_hs_c unbalance {'C': 17.0, 'R': -1.0, 'H': 31.0}
# FNOR_1 4
# ARTPLM2 5
# CHOLESTle_1 6
# LCAT9e 7
# LCAT9e: chsterol_e + pe_hs_e --> pelinl_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 31.0, 'R': -1.0}
# ARTCOAL1 8
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# SMS11: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln181221_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# ARTPLM1 1
# SMS11 2
# SMS11: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln181221_hs_c unbalance {'C': 21.0, 'H': 42.0, 'R': -1.0}
# HMR_0653 3
# HMR_0657 4
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# SMS12: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18122_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# ARTPLM1 1
# SMS12 2
# SMS12: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18122_hs_c unbalance {'C': 21.0, 'H': 44.0, 'R': -1.0}
# HMR_0653 3
# HMR_0657 4
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# SMS16: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18123_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# ARTPLM1 1
# SMS16 2
# SMS16: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18123_hs_c unbalance {'C': 22.0, 'H': 46.0, 'R': -1.0}
# HMR_0653 3
# HMR_0657 4
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# SMS14: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln1824_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# ARTPLM1 1
# SMS14 2
# SMS14: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln1824_hs_c unbalance {'C': 23.0, 'H': 50.0, 'R': -1.0}
# HMR_0653 3
# HMR_0657 4
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# SMS15: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln1825_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# ARTPLM1 1
# SMS15 2
# SMS15: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln1825_hs_c unbalance {'C': 24.0, 'H': 52.0, 'R': -1.0}
# HMR_0653 3
# HMR_0657 4
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# SMS4: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18116_hs_c 5
# ARTPLM1 1
# SMS4 2
# SMS4: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18116_hs_c unbalance {'C': 15.0, 'H': 32.0, 'R': -1.0}
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# SMS6: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18118_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# ARTPLM1 1
# SMS6 2
# SMS6: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18118_hs_c unbalance {'C': 17.0, 'H': 36.0, 'R': -1.0}
# HMR_0653 3
# HMR_0657 4
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# SMS7: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln181181_hs_c 5
# ARTPLM1 1
# SMS7 2
# SMS7: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln181181_hs_c unbalance {'C': 17.0, 'H': 34.0, 'R': -1.0}
# 1
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# LPS7e: dag_hs_e + h2o_e --> Rtotal_e + h_e + magarachi_hs_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# ARTPLM2 1
# LPS7e 2
# LPS7e: dag_hs_e + h2o_e --> Rtotal_e + h_e + magarachi_hs_e unbalance {'C': 19.0, 'R': -2.0, 'H': 31.0}
# ARTCOAL1 3
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLOLE_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholole_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT11e: chsterol_e + pchol_hs_e --> pcholole_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLOLE_HSPLA2 3
# PCHOLOLE_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholole_hs_c unbalance {'C': 17.0, 'R': -1.0, 'H': 34.0}
# HMR_0653 4
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# ARTCOAL1 8
# LCAT11e 9
# LCAT11e: chsterol_e + pchol_hs_e --> pcholole_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 34.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PEOLE_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + peole_hs_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT12e: chsterol_e + pe_hs_e --> peole_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# PEOLE_HSPLA2 3
# PEOLE_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + peole_hs_c unbalance {'C': 17.0, 'R': -1.0, 'H': 33.0}
# FNOR_1 4
# ARTPLM2 5
# CHOLESTle_1 6
# ARTCOAL1 7
# LCAT12e 8
# LCAT12e: chsterol_e + pe_hs_e --> peole_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 33.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLPALM_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholpalm_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT14e: chsterol_e + pchol_hs_e --> pcholpalm_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLPALM_HSPLA2 3
# PCHOLPALM_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholpalm_hs_c unbalance {'C': 15.0, 'R': -1.0, 'H': 32.0}
# HMR_0653 4
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# ARTCOAL1 8
# LCAT14e 9
# LCAT14e: chsterol_e + pchol_hs_e --> pcholpalm_hs_e + xolest2_hs_e unbalance {'C': 15.0, 'H': 32.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOL2PALM_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pchol2palm_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT21e: chsterol_e + pchol_hs_e --> pchol2palm_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOL2PALM_HSPLA2 3
# PCHOL2PALM_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pchol2palm_hs_c unbalance {'C': 15.0, 'R': -1.0, 'H': 32.0}
# HMR_0653 4
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# ARTCOAL1 8
# LCAT21e 9
# LCAT21e: chsterol_e + pchol_hs_e --> pchol2palm_hs_e + xolest2_hs_e unbalance {'C': 15.0, 'H': 32.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLN183_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn183_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT30e: chsterol_e + pchol_hs_e --> pcholn183_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLN183_HSPLA2 3
# PCHOLN183_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn183_hs_c unbalance {'C': 17.0, 'R': -1.0, 'H': 30.0}
# HMR_0653 4
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# ARTCOAL1 8
# LCAT30e 9
# LCAT30e: chsterol_e + pchol_hs_e --> pcholn183_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 30.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLN1836_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn1836_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT31e: chsterol_e + pchol_hs_e --> pcholn1836_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLN1836_HSPLA2 3
# PCHOLN1836_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn1836_hs_c unbalance {'C': 17.0, 'R': -1.0, 'H': 30.0}
# HMR_0653 4
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# ARTCOAL1 8
# LCAT31e 9
# LCAT31e: chsterol_e + pchol_hs_e --> pcholn1836_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 30.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLN204_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn204_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT34e: chsterol_e + pchol_hs_e --> pcholn204_hs_e + xolest2_hs_e 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLN204_HSPLA2 3
# PCHOLN204_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn204_hs_c unbalance {'C': 19.0, 'R': -1.0, 'H': 32.0}
# ARTPLM2 4
# CHOLESTle_1 5
# HMR_0653 6
# ARTCOAL1 7
# LCAT34e 8
# LCAT34e: chsterol_e + pchol_hs_e --> pcholn204_hs_e + xolest2_hs_e unbalance {'C': 19.0, 'H': 32.0, 'R': -1.0}
# HMR_0657 9
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLN2254_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn2254_hs_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT38e: chsterol_e + pchol_hs_e --> pcholn2254_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLN2254_HSPLA2 3
# PCHOLN2254_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn2254_hs_c unbalance {'C': 21.0, 'R': -1.0, 'H': 34.0}
# HMR_0653 4
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# ARTCOAL1 8
# LCAT38e 9
# LCAT38e: chsterol_e + pchol_hs_e --> pcholn2254_hs_e + xolest2_hs_e unbalance {'C': 21.0, 'H': 34.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PAILAR_HSPLA2: h2o_c + pail_hs_c --> Rtotal2_c + h_c + pailar_hs_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# ARTCOAL2 1
# ARTPLM1 2
# PAILAR_HSPLA2 3
# PAILAR_HSPLA2: h2o_c + pail_hs_c --> Rtotal2_c + h_c + pailar_hs_c unbalance {'C': 19.0, 'R': -1.0, 'H': 31.0}
# FNOR_1 4
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLN281_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn281_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT52e: chsterol_e + pchol_hs_e --> pcholn281_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLN281_HSPLA2 3
# PCHOLN281_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn281_hs_c unbalance {'C': 27.0, 'R': -1.0, 'H': 54.0}
# ARTPLM2 4
# CHOLESTle_1 5
# ARTCOAL1 6
# LCAT52e 7
# LCAT52e: chsterol_e + pchol_hs_e --> pcholn281_hs_e + xolest2_hs_e unbalance {'C': 27.0, 'H': 54.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLN28_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn28_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT53e: chsterol_e + pchol_hs_e --> pcholn28_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLN28_HSPLA2 3
# PCHOLN28_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn28_hs_c unbalance {'C': 27.0, 'R': -1.0, 'H': 56.0}
# ARTPLM2 4
# CHOLESTle_1 5
# ARTCOAL1 6
# LCAT53e 7
# LCAT53e: chsterol_e + pchol_hs_e --> pcholn28_hs_e + xolest2_hs_e unbalance {'C': 27.0, 'H': 56.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# PEAR_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pear_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT3e: chsterol_e + pe_hs_e --> pear_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# FNOR_1 3
# PEAR_HSPLA2 4
# PEAR_HSPLA2: h2o_c + pe_hs_c --> Rtotal2_c + h_c + pear_hs_c unbalance {'C': 19.0, 'R': -1.0, 'H': 31.0}
# ARTPLM2 5
# CHOLESTle_1 6
# ARTCOAL1 7
# LCAT3e 8
# LCAT3e: chsterol_e + pe_hs_e --> pear_hs_e + xolest2_hs_e unbalance {'C': 19.0, 'H': 31.0, 'R': -1.0}
# 1
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# MAGLINL_HSe: dag_hs_e + h2o_e --> Rtotal_e + h_e + maglinl_hs_e 5
# ARTPLM2 1
# ARTCOAL1 2
# MAGLINL_HSe 3
# MAGLINL_HSe: dag_hs_e + h2o_e --> Rtotal_e + h_e + maglinl_hs_e unbalance {'C': 17.0, 'R': -2.0, 'H': 31.0}
# 1
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# MAGOLE_HSe: dag_hs_e + h2o_e --> Rtotal_e + h_e + magole_hs_e 5
# ARTPLM2 1
# ARTCOAL1 2
# MAGOLE_HSe 3
# MAGOLE_HSe: dag_hs_e + h2o_e --> Rtotal_e + h_e + magole_hs_e unbalance {'C': 17.0, 'R': -2.0, 'H': 33.0}
# 1
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LPS6e: dag_hs_e + h2o_e --> Rtotal_e + h_e + magste_hs_e 5
# ARTPLM2 1
# ARTCOAL1 2
# LPS6e 3
# LPS6e: dag_hs_e + h2o_e --> Rtotal_e + h_e + magste_hs_e unbalance {'C': 17.0, 'R': -2.0, 'H': 35.0}
# 1
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# LCAT4e: chsterol_e + pail_hs_e --> pailar_hs_e + xolest2_hs_e 5
# ARTPLM2 1
# CHOLESTle_1 2
# ARTCOAL1 3
# FNOR_1 4
# LCAT4e 5
# LCAT4e: chsterol_e + pail_hs_e --> pailar_hs_e + xolest2_hs_e unbalance {'C': 19.0, 'H': 31.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# PCHOL2OLE_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pchol2ole_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT20e: chsterol_e + pchol_hs_e --> pchol2ole_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# HMR_0653 3
# PCHOL2OLE_HSPLA2 4
# PCHOL2OLE_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pchol2ole_hs_c unbalance {'C': 17.0, 'R': -1.0, 'H': 34.0}
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# ARTCOAL1 8
# LCAT20e 9
# LCAT20e: chsterol_e + pchol_hs_e --> pchol2ole_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 34.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# PCHOL2STE_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pchol2ste_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT22e: chsterol_e + pchol_hs_e --> pchol2ste_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# HMR_0653 3
# PCHOL2STE_HSPLA2 4
# PCHOL2STE_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pchol2ste_hs_c unbalance {'C': 17.0, 'R': -1.0, 'H': 36.0}
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# ARTCOAL1 8
# LCAT22e 9
# LCAT22e: chsterol_e + pchol_hs_e --> pchol2ste_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 36.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# PCHOLN225_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn225_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT37e: chsterol_e + pchol_hs_e --> pcholn225_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# PCHOLN225_HSPLA2 3
# PCHOLN225_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn225_hs_c unbalance {'C': 21.0, 'R': -1.0, 'H': 34.0}
# ARTPLM2 4
# CHOLESTle_1 5
# ARTCOAL1 6
# LCAT37e 7
# LCAT37e: chsterol_e + pchol_hs_e --> pcholn225_hs_e + xolest2_hs_e unbalance {'C': 21.0, 'H': 34.0, 'R': -1.0}
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# SMS13: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln180241_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# ARTPLM1 1
# HMR_0653 2
# SMS13 3
# SMS13: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln180241_hs_c unbalance {'C': 23.0, 'H': 48.0, 'R': -1.0}
# HMR_0657 4
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# SMS5: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18117_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# ARTPLM1 1
# HMR_0653 2
# SMS5 3
# SMS5: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18117_hs_c unbalance {'C': 16.0, 'H': 34.0, 'R': -1.0}
# HMR_0657 4
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# SMS9: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18120_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# ARTPLM1 1
# HMR_0653 2
# SMS9 3
# SMS9: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18120_hs_c unbalance {'C': 19.0, 'H': 40.0, 'R': -1.0}
# HMR_0657 4
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# SMS8: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln181201_hs_c 5
# ARTPLM1 1
# SMS8 2
# SMS8: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln181201_hs_c unbalance {'C': 19.0, 'H': 38.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# PCHOLN226_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn226_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT39e: chsterol_e + pchol_hs_e --> pcholn226_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# HMR_0653 3
# PCHOLN226_HSPLA2 4
# PCHOLN226_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholn226_hs_c unbalance {'C': 21.0, 'R': -1.0, 'H': 32.0}
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# ARTCOAL1 8
# LCAT39e 9
# LCAT39e: chsterol_e + pchol_hs_e --> pcholn226_hs_e + xolest2_hs_e unbalance {'C': 21.0, 'H': 32.0, 'R': -1.0}
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# PCHOLAR_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholar_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# 2
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# LCAT2e: chsterol_e + pchol_hs_e --> pcholar_hs_e + xolest2_hs_e 5
# ARTCOAL2 1
# ARTPLM1 2
# HMR_0653 3
# PCHOLAR_HSPLA2 4
# PCHOLAR_HSPLA2: h2o_c + pchol_hs_c --> Rtotal2_c + h_c + pcholar_hs_c unbalance {'C': 19.0, 'R': -1.0, 'H': 32.0}
# HMR_0657 5
# ARTPLM2 6
# CHOLESTle_1 7
# ARTCOAL1 8
# LCAT2e 9
# LCAT2e: chsterol_e + pchol_hs_e --> pcholar_hs_e + xolest2_hs_e unbalance {'C': 19.0, 'H': 32.0, 'R': -1.0}
# 1
# AH5L: 5aop_c --> h2o_c + pbng_c 5
# AH5L 1
# AH5L: 5aop_c --> h2o_c + pbng_c unbalance {'C': 5.0, 'H': 7.0, 'N': 1.0, 'O': 2.0}
# 1
# GLUSfx: akg_c + 2.0 fdxrd_c + gln__L_c + 2.0 h_c --> 2.0 fdxox_c + 2.0 glu__L_c 5
# OA30LL: OA30__L_p + colipa_p --> LPS30__L_p + h_p + udcpdp_p 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# OA30PL: 25.0 udcpdpglcnac_a1_3_galnac_b1_3_gal_a1_2_fuc_p --> OA30__L_p + 24.0 udcpdp_p 5
# GLUSfx 1
# OA30LL 2
# ARTCOAL1 3
# FNOR_1 4
# OA30PL 5
# OA30PL: 25.0 udcpdpglcnac_a1_3_galnac_b1_3_gal_a1_2_fuc_p --> OA30__L_p + 24.0 udcpdp_p unbalance {'charge': -25.0, 'O': -25.0}
# 1
# GLUSfx: akg_c + 2.0 fdxrd_c + gln__L_c + 2.0 h_c --> 2.0 fdxox_c + 2.0 glu__L_c 5
# OA30LVL: OA30_VL_p + colipa_p --> LPS30_VL_p + h_p + udcpdp_p 5
# ARTCOAL3: Rtotal3_c + coa_c --> Rtotal3coa_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# OA30PVL: 100.0 udcdpglcnac_b1_3_glc_a1_4_fuc_a1_3_acper_p --> OA30_VL_p + 99.0 udcpdp_p 5
# GTLOA30: gdpacper_c + gdpfuc_c + udcdpglcnac_b1_3_glc_c --> 2.0 gdp_c + udcdpglcnac_b1_3_glc_a1_4_fuc_a1_3_acper_c 5
# GLUSfx 1
# OA30LVL 2
# ARTCOAL3 3
# FNOR_1 4
# OA30PVL 5
# GTLOA30 6
# GTLOA30: gdpacper_c + gdpfuc_c + udcdpglcnac_b1_3_glc_c --> 2.0 gdp_c + udcdpglcnac_b1_3_glc_a1_4_fuc_a1_3_acper_c unbalance {'charge': 1.0}
# 1
# GLTS_h: akg_h + 2.0 fdxrd_h + gln__L_h + 2.0 h_h --> 2.0 fdxox_h + 2.0 glu__L_h 5
# ARTCOAL3: Rtotal3_c + coa_c --> Rtotal3coa_c 5
# CPP3O: cpppg3_h + 6.0 nadp_h --> cpp3_h + 6.0 nadph_h 5
# GLTS_h 1
# ARTCOAL3 2
# CPP3O 3
# CPP3O: cpppg3_h + 6.0 nadp_h --> cpp3_h + 6.0 nadph_h unbalance {'charge': -7.0, 'H': 4.0}
# 1
# ARTPLM2: Rtotal2coa_c --> pmtcoa_c 5
# CHOLESTle_1: h2o_e + xolest2_hs_e --> Rtotal_e + chsterol_e + h_e 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# LCAT17e: chsterol_e + pail_hs_e --> pailste_hs_e + xolest2_hs_e 5
# ARTPLM2 1
# CHOLESTle_1 2
# ARTCOAL1 3
# FNOR_1 4
# LCAT17e 5
# LCAT17e: chsterol_e + pail_hs_e --> pailste_hs_e + xolest2_hs_e unbalance {'C': 17.0, 'H': 35.0, 'R': -1.0}
# 1
# ARTPLM1: Rtotalcoa_c --> pmtcoa_c 5
# HMR_0653: amet_c + pe_hs_c --> M02686_c + ahcys_c + 2.0 h_c 5
# SMS10: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18121_hs_c 5
# HMR_0657: M02758_c + amet_c --> ahcys_c + pchol_hs_c 5
# ARTPLM1 1
# HMR_0653 2
# SMS10 3
# SMS10: crm_hs_c + pchol_hs_c --> dag_hs_c + sphmyln18121_hs_c unbalance {'C': 20.0, 'H': 42.0, 'R': -1.0}
# HMR_0657 4
# 1
# ARTCOAL2: Rtotal2_c + coa_c --> Rtotal2coa_c 5
# ARTCOAL1: Rtotal_c + coa_c --> Rtotalcoa_c 5
# PQBS1: 3nphb_c --> 2m6solbzq_c + h2o_c 5
# ARTCOAL2 1
# ARTCOAL1 2
# PQBS1 3
# PQBS1: 3nphb_c --> 2m6solbzq_c + h2o_c unbalance {'charge': 1.0, 'H': 5.0}
# 1
# r1383: HC02129_c --> 6.0 glu__L_c + thf_c 5
# r1382: 6.0 atp_c + 6.0 glu__L_c + 6.0 h2o_c + thf_c --> HC02129_c + 6.0 adp_c + 6.0 pi_c 5
# FNOR_1: 2.0 fdxrd_c + h_c + nadp_c --> 2.0 fdxox_c + nadph_c 5
# IPPT: adp_c + ppap_c --> atp_c + ival_c 5
# r1383 1
# r1382 2
# FNOR_1 3
# IPPT 4
# IPPT: adp_c + ppap_c --> atp_c + ival_c unbalance {'charge': 1.0, 'C': 2.0, 'H': 5.0}

# %%
balance_rxn,chargenan_rxn,H_balance_rxn,H2O_balance_rxn,unbalance_rxn = check_rxn_balance_number(model)
cor_unri,cor_unrr,cor_balri,cor_balrr,cor_type,del_ri,del_rr,del_type = modify_delete_rxn(model,end_rxn_list,balance_rxn)
# Out:
# MECDPDH: 2mecdp_c + h_c --> h2mb4p_c + h2o_c MECDPDH_syn: 2mecdp_c + nadph_c --> h2mb4p_c + h2o_c + nadp_c 2
# SULRR2: h_c + nadph_c + so3_c --> h2o_c + h2s_c + nadp_c SFRR: 5.0 h_c + 3.0 nadph_c + so3_c --> 3.0 h2o_c + h2s_c + 3.0 nadp_c 1
# SULRR: h_c + nadh_c + so3_c --> h2o_c + h2s_c + nad_c SO3R: 5.0 h_c + 3.0 nadh_c + so3_c --> 3.0 h2o_c + h2s_c + 3.0 nad_c 1
# FDIPDC: frdp_c + ipdp_c --> ppi_c + udcpdp_c UDCPDPS: frdp_c + 8.0 ipdp_c --> 8.0 ppi_c + udcpdp_c 1
# HPYRR2x_1: 3.0 h_c + 2.0 hpyr_c + nadh_c --> 2.0 glyc__S_c + nad_c HPYRR2x: h_c + hpyr_c + nadh_c --> glyc__S_c + nad_c 1

# %%
direction_df = pd.read_excel('data/direction_check-20220428.xlsx',sheet_name='check_end',index_col='r1id')
for rxn1 in model.reactions:
    if rxn1.id in list(direction_df.index):
        rxn1.bounds = eval(direction_df.loc[rxn1.id,'r2bounds'])

# %%
model_dic = model_to_dict(model, sort=False)
with open('model/CSMN.json', 'w') as f:
    json.dump(model_dic,f)
